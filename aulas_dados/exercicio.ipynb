# %%
import pandas as pd
dados = pd.read_csv('/home/youx/youxlab-treino-git/aulas_dados/datasets/GasPricesinBrazil_2004-2019_preprocessado_final.csv')
dados
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103387   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 103388   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 103389   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 103390   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 103391   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
#7.1
df = pd.DataFrame(dados)
grupo = df.groupby('PRODUTO')
grupo

# %%
grupo['REGIÃO'].value_counts().to_frame()
# Out:
#                                count
# PRODUTO          REGIÃO
# ETANOL HIDRATADO NORDESTE       7046
#                  NORTE          5177
#                  SUDESTE        3137
#                  CENTRO OESTE   3122
#                  SUL            2353
# GASOLINA COMUM   NORDESTE       7063
#                  NORTE          5464
#                  SUDESTE        3140
#                  CENTRO OESTE   3134
#                  SUL            2354
# GLP              NORDESTE       6410
#                  NORTE          5327
#                  SUDESTE        3137
#                  CENTRO OESTE   3098
#                  SUL            2343
# GNV              NORDESTE       5176
#                  SUDESTE        2841
#                  SUL            1899
#                  CENTRO OESTE    847
#                  NORTE           243
# ÓLEO DIESEL      NORDESTE       7061
#                  NORTE          5465
#                  SUDESTE        3140
# ...

# %%
df_gasolina_etanol_2018 = df.query('(PRODUTO == "GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO") and ESTADO == "SAO PAULO"')
df_gasolina_etanol_2018
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 103058   2019-06-09  2019-06-15  SUDESTE  SAO PAULO    GASOLINA COMUM
# 103123   2019-06-16  2019-06-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 103204   2019-06-16  2019-06-22  SUDESTE  SAO PAULO    GASOLINA COMUM
# 103269   2019-06-23  2019-06-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 103350   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
#7.2
df_gasolina_2018 = df.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO"')
df_gasolina_2018.head()
# Out:
#       DATA INICIAL  DATA FINAL   REGIÃO     ESTADO         PRODUTO  \
# 12003   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  GASOLINA COMUM
# 12030   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  GASOLINA COMUM
# 12057   2004-05-23  2004-05-29  SUDESTE  SAO PAULO  GASOLINA COMUM
# 12084   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  GASOLINA COMUM
# 12111   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  GASOLINA COMUM
#
#        NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 12003                          4107              R$/l                1.891
# 12030                          4133              R$/l                1.888
# 12057                          4139              R$/l                1.894
# 12084                          4139              R$/l                1.912
# 12111                          4138              R$/l                1.919
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %%
df_gasolina_etanol_2018.head()
# Out:
#     DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23    2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50    2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77    2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                           4047              R$/l                0.768
# 50                           4066              R$/l                0.766
# 77                           4077              R$/l                0.823
# 104                          4073              R$/l                0.887
# 131                          4082              R$/l                0.894
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# ...

# %%
df_gasolina_2018.shape
# Out:
# (785, 20)

# %%
df_gasolina_etanol_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count          1570.000000
# mean              2.323946
# std               0.776569
# min               0.766000
# 25%               1.791500
# 50%               2.399000
# 75%               2.706750
# max               4.512000

# %%
df_gasolina_etanol_2018.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min    25%    50%    75%    max
# PRODUTO
# ETANOL HIDRATADO  785.0  1.802243  0.539164  0.766  1.303  1.791  2.179  2.986
# GASOLINA COMUM    785.0  2.845648  0.609221  1.888  2.411  2.638  3.177  4.512
