# %%
import pandas as pd
livros = pd.read_csv(r"/home/youx/youxlab-treino-git/aulas_dados/datasets/livros.csv",sep=',')
estoque = pd.read_csv(r"/home/youx/youxlab-treino-git/aulas_dados/datasets/estoque.csv", sep=',')
livros
# Out:
#             Nome do Livro                      Autor                Editora  \
# 0     Cem Anos de Solidão     Gabriel García Márquez                 Record
# 1            Dom Casmurro           Machado de Assis                  Ática
# 2  A Revolução dos Bichos              George Orwell   Companhia das Letras
# 3             Metamorfose                Franz Kafka              Principis
# 4   A morte de Ivan Ilich               Liev Tolstói              Principis
# 5      O pequeno principe   Antonie de Saint-Exupéry             HarperKids
#
#    Data de Lançamento           ISBN
# 0          1967-05-30  9788535914849
# 1          1899-01-01  9788508108512
# 2          1945-08-17  9788535914840
# 3          2019-11-27    85943118782
# 4          2023-06-20     655552894X
# 5          2023-08-15     6584956247

# %%
estoque
# Out:
#             ISBN   Quantidade  Data de Chegada       Nome do Comprador
# 0  9788535914849           10       2023-03-12      Biblioteca Central
# 1  9788508108512            5       2023-04-01   Secretaria de Cultura
# 2  9788535914840            8       2023-05-15      Biblioteca Central
# 3    85943118782          999       2019-11-27   Secretaria de Cultura
# 4     655552894X           30       2023-06-20      Biblioteca Central
# 5     6584956247           20       2023-08-15   Secretaria de Cultura

# %%
estoque['ISBN'] = estoque['ISBN'].astype(str)
livros['ISBN'] = livros['ISBN'].astype(str)

merge = pd.merge(estoque, livros, on='ISBN')
merge.head(5)
# Out:
#             ISBN   Quantidade  Data de Chegada       Nome do Comprador  \
# 0  9788535914849           10       2023-03-12      Biblioteca Central
# 1  9788508108512            5       2023-04-01   Secretaria de Cultura
# 2  9788535914840            8       2023-05-15      Biblioteca Central
# 3    85943118782          999       2019-11-27   Secretaria de Cultura
# 4     655552894X           30       2023-06-20      Biblioteca Central
#
#             Nome do Livro                    Autor                Editora  \
# 0     Cem Anos de Solidão   Gabriel García Márquez                 Record
# 1            Dom Casmurro         Machado de Assis                  Ática
# 2  A Revolução dos Bichos            George Orwell   Companhia das Letras
# 3             Metamorfose              Franz Kafka              Principis
# 4   A morte de Ivan Ilich             Liev Tolstói              Principis
#
#    Data de Lançamento
# 0          1967-05-30
# 1          1899-01-01
# 2          1945-08-17
# ...
