# %%
import pandas as pd
data = pd.read_csv('/home/youx/youxlab-treino-git/aulas_dados/datasets/GasPricesinBrazil_2004-2019.csv', sep=';')
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.query('ANO != 2019')
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103064      103064   2018-12-30  2019-01-05      NORDESTE
# 103065      103065   2018-12-30  2019-01-05           SUL
# 103066      103066   2018-12-30  2019-01-05           SUL
# 103067      103067   2018-12-30  2019-01-05       SUDESTE
# 103068      103068   2018-12-30  2019-01-05      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
grupos = data.groupby('PRODUTO')
grupos

# %%
# 7.1 EXERCICIO
grupos['REGIÃO'].value_counts().to_frame().reset_index()
# Out:
#              PRODUTO        REGIÃO  count
# 0   ETANOL HIDRATADO      NORDESTE   7064
# 1   ETANOL HIDRATADO         NORTE   5404
# 2   ETANOL HIDRATADO  CENTRO OESTE   3140
# 3   ETANOL HIDRATADO       SUDESTE   3140
# 4   ETANOL HIDRATADO           SUL   2354
# 5     GASOLINA COMUM      NORDESTE   7065
# 6     GASOLINA COMUM         NORTE   5494
# 7     GASOLINA COMUM  CENTRO OESTE   3140
# 8     GASOLINA COMUM       SUDESTE   3140
# 9     GASOLINA COMUM           SUL   2355
# 10               GLP      NORDESTE   7061
# 11               GLP         NORTE   5494
# 12               GLP       SUDESTE   3139
# 13               GLP  CENTRO OESTE   3137
# 14               GLP           SUL   2355
# 15               GNV      NORDESTE   5575
# 16               GNV       SUDESTE   3136
# 17               GNV           SUL   2343
# 18               GNV  CENTRO OESTE   1523
# 19               GNV         NORTE    457
# 20       ÓLEO DIESEL      NORDESTE   7065
# ...

# %%
# 7.2 EXERCICIO
gasolina_sp = data.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_sp.describe()
# Out:
#           Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count      52.000000                     52.000000            52.000000
# mean    99196.096154                   1610.211538             4.202769
# std      2279.595314                    213.627432             0.180672
# min     95351.000000                    102.000000             3.970000
# 25%     97281.250000                   1639.000000             4.008000
# 50%     99196.500000                   1642.000000             4.202000
# 75%    101116.250000                   1644.000000             4.336250
# max    103025.000000                   1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# ...

# %%
gasolina_sp.shape
# Out:
# (52, 21)

# %%
# 7.3 EXERCICIO
gasolinaAndEtanol_sp = data.query('(PRODUTO == "GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO") and ESTADO == "SAO PAULO" and ANO == 2018')
gasolinaAndEtanol_sp.describe()
# Out:
#           Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count     104.000000                    104.000000           104.000000
# mean    99155.605769                   1620.557692             3.457337
# std      2268.863632                    213.422086             0.766239
# min     95270.000000                    102.000000             2.393000
# 25%     97220.500000                   1641.000000             2.726000
# 50%     99156.000000                   1647.000000             3.431000
# 75%    101096.000000                   1662.000000             4.199000
# max    103025.000000                   1665.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count             104.000000            104.000000            104.000000
# mean                0.167760              2.958663              4.318058
# std                 0.021546              0.736680              0.681788
# ...
