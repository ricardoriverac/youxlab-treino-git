# %%
import pandas as pd

# %%
dados = pd.read_csv("/home/youx/youxlab-treino-git/dadosDiciplina/aula23,24/GasPricesinBrazil_2004-2019.csv",sep=';')
dados
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
dados.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
dados_grupo = dados.groupby('REGIÃO')
dados_grupo

# %%
dados_grupo.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14,
# ...

# %%
dados_grupo.get_group('CENTRO OESTE')
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 27              27   2004-05-16  2004-05-22  CENTRO OESTE    DISTRITO FEDERAL
# ...            ...          ...         ...           ...                 ...
# 106787      106787   2019-06-23  2019-06-29  CENTRO OESTE    DISTRITO FEDERAL
# 106789      106789   2019-06-23  2019-06-29  CENTRO OESTE               GOIAS
# 106791      106791   2019-06-23  2019-06-29  CENTRO OESTE         MATO GROSSO
# 106792      106792   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
# 106812      106812   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
#
# ...

# %%
dados_grupo.describe()
# Out:
#              Unnamed: 0                                                       \
#                   count          mean           std   min       25%      50%
# REGIÃO
# CENTRO OESTE    15429.0  53417.968955  30938.517860   0.0  26021.00  54240.0
# NORDESTE        36869.0  53538.276248  30636.581838   4.0  27645.00  53027.0
# NORTE           24702.0  52805.662214  31594.475085  13.0  23848.25  54009.5
# SUDESTE         17047.0  53749.005104  30386.889753  20.0  28766.50  52829.0
# SUL             12776.0  53754.692001  30391.714995  24.0  28743.75  52859.5
#
#                                  NÚMERO DE POSTOS PESQUISADOS              \
#                    75%       max                        count        mean
# REGIÃO
# CENTRO OESTE  80018.00  106812.0                      15429.0  137.263983
# NORDESTE      80098.00  106822.0                      36869.0  123.194364
# NORTE         80299.50  106807.0                      24702.0   66.249899
# ...

# %%
dados.groupby('REGIÃO').describe()
# Out:
#              Unnamed: 0                                                       \
#                   count          mean           std   min       25%      50%
# REGIÃO
# CENTRO OESTE    15429.0  53417.968955  30938.517860   0.0  26021.00  54240.0
# NORDESTE        36869.0  53538.276248  30636.581838   4.0  27645.00  53027.0
# NORTE           24702.0  52805.662214  31594.475085  13.0  23848.25  54009.5
# SUDESTE         17047.0  53749.005104  30386.889753  20.0  28766.50  52829.0
# SUL             12776.0  53754.692001  30391.714995  24.0  28743.75  52859.5
#
#                                  NÚMERO DE POSTOS PESQUISADOS              \
#                    75%       max                        count        mean
# REGIÃO
# CENTRO OESTE  80018.00  106812.0                      15429.0  137.263983
# NORDESTE      80098.00  106822.0                      36869.0  123.194364
# NORTE         80299.50  106807.0                      24702.0   66.249899
# ...

# %%
dados_grupo = dados.groupby(['REGIÃO','PRODUTO'])
dados_grupo

# %%
dados_grupo.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA COMUM'): [12064, 12065, 12066, 12067, 12091, 12092, 12093, 12094, 12118, 12119, 12120, 12121, 12145, 12146, 12147, 12148, 12172, 12173, 12174, 12175, 12199, 12200, 12201, 12202, 12226, 12227, 12228, 12229, 12253, 12254, 12255, 12256, 12280, 12281, 12282, 12283, 12307, 12308, 12309, 12310, 12334, 12335, 12336, 12337, 12361, 12362, 12363, 12364, 12388, 12389, 12390, 12391, 12415, 12416, 12417, 12418, 12442, 12443, 12444, 12445, 12469, 12470, 1
# ...

# %%
dados_grupo.mean(numeric_only=True)
# Out:
#                                  Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  38402.603822                    154.982484
#              GASOLINA COMUM    45308.938854                    155.204777
#              GLP               52169.625120                    200.619063
#              GNV               58737.694682                      2.880499
#              ÓLEO DIESEL       63212.966879                    131.744268
#              ÓLEO DIESEL S10   81341.186064                     71.498888
# NORDESTE     ETANOL HIDRATADO  38399.334088                    153.857022
#              GASOLINA COMUM    45314.135173                    174.003255
#              GLP               52190.285229                    126.175754
#              GNV               57442.697220                     16.719462
#              ÓLEO DIESEL       63218.163199                    135.465110
# ...

# %%
dados_grupo['PREÇO MÉDIO REVENDA'].mean()
# Out:
# REGIÃO        PRODUTO
# CENTRO OESTE  ETANOL HIDRATADO     2.135950
#               GASOLINA COMUM       3.078123
#               GLP                 48.181149
#               GNV                  2.004153
#               ÓLEO DIESEL          2.481534
#               ÓLEO DIESEL S10      3.241185
# NORDESTE      ETANOL HIDRATADO     2.322075
#               GASOLINA COMUM       3.002337
#               GLP                 42.221312
#               GNV                  1.925318
#               ÓLEO DIESEL          2.347550
#               ÓLEO DIESEL S10      3.041957
# NORTE         ETANOL HIDRATADO     2.530796
#               GASOLINA COMUM       3.149212
#               GLP                 47.174539
#               GNV                  2.000190
#               ÓLEO DIESEL          2.569905
#               ÓLEO DIESEL S10      3.310619
# SUDESTE       ETANOL HIDRATADO     2.164832
#               GASOLINA COMUM       3.000565
#               GLP                 42.077813
# ...

# %%
dados_grupo['PREÇO MÉDIO REVENDA'].agg([min,max])
# Out:
# /tmp/ipykernel_8063/1942750576.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   dados_grupo['PREÇO MÉDIO REVENDA'].agg([min,max])
# /tmp/ipykernel_8063/1942750576.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   dados_grupo['PREÇO MÉDIO REVENDA'].agg([min,max])
#                                   min     max
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO   1.162   3.999
#              GASOLINA COMUM     1.936   4.963
#              GLP               28.791  99.357
#              GNV                1.097   3.890
#              ÓLEO DIESEL        1.435   4.162
# ...
