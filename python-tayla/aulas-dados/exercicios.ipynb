# %% [markdown]
# # Exercícios

# %%
import pandas as pd
data = pd.read_csv('/home/youx/teste_git/youxlab-treino-git/python-tayla/aulas-dados/datasets/GasPricesinBrazil_2004-2019.csv',sep=';')
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.query('ANO != 2019')
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103064      103064   2018-12-30  2019-01-05      NORDESTE
# 103065      103065   2018-12-30  2019-01-05           SUL
# 103066      103066   2018-12-30  2019-01-05           SUL
# 103067      103067   2018-12-30  2019-01-05       SUDESTE
# 103068      103068   2018-12-30  2019-01-05      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
df = data.query('ANO != 2019')
df
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103064      103064   2018-12-30  2019-01-05      NORDESTE
# 103065      103065   2018-12-30  2019-01-05           SUL
# 103066      103066   2018-12-30  2019-01-05           SUL
# 103067      103067   2018-12-30  2019-01-05       SUDESTE
# 103068      103068   2018-12-30  2019-01-05      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
# Qual a quantidade de registros de cada produto em cada região?
grupos = df.groupby('PRODUTO')
grupos

# %%
grupos['REGIÃO'].value_counts().to_frame()
# Out:
#                                count
# PRODUTO          REGIÃO
# ETANOL HIDRATADO NORDESTE       6839
#                  NORTE          5244
#                  CENTRO OESTE   3040
#                  SUDESTE        3040
#                  SUL            2279
# GASOLINA COMUM   NORDESTE       6840
#                  NORTE          5319
#                  CENTRO OESTE   3040
#                  SUDESTE        3040
#                  SUL            2280
# GLP              NORDESTE       6836
#                  NORTE          5319
#                  SUDESTE        3039
#                  CENTRO OESTE   3037
#                  SUL            2280
# GNV              NORDESTE       5398
#                  SUDESTE        3036
#                  SUL            2269
#                  CENTRO OESTE   1493
#                  NORTE           444
# ÓLEO DIESEL      NORDESTE       6840
#                  NORTE          5319
#                  CENTRO OESTE   3040
# ...

# %%
# Como os preços da Gasolina Comum em SP variaram em 2018?
gasolinaSP = data.query('ESTADO == "SAO PAULO" and PRODUTO == "GASOLINA COMUM" and ANO == 2018')
gasolinaSP.head()
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 95351       95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 95502       95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 95654       95654   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# 95806       95806   2018-01-28  2018-02-03  SUDESTE  SAO PAULO
# 95958       95958   2018-02-04  2018-02-10  SUDESTE  SAO PAULO
#
#               PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 95351  GASOLINA COMUM                          1641              R$/l
# 95502  GASOLINA COMUM                          1648              R$/l
# 95654  GASOLINA COMUM                          1648              R$/l
# 95806  GASOLINA COMUM                          1644              R$/l
# 95958  GASOLINA COMUM                          1646              R$/l
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 95351                3.988                  0.156  ...                 4.599
# ...

# %%
data['PRODUTO'].unique()
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL',
#        'ÓLEO DIESEL S10'], dtype=object)

# %%
gasolinaSP.describe()
# Out:
#           Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count      52.000000                     52.000000            52.000000
# mean    99196.096154                   1610.211538             4.202769
# std      2279.595314                    213.627432             0.180672
# min     95351.000000                    102.000000             3.970000
# 25%     97281.250000                   1639.000000             4.008000
# 50%     99196.500000                   1642.000000             4.202000
# 75%    101116.250000                   1644.000000             4.336250
# max    103025.000000                   1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# ...

# %%
gasolinaSP['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %%
# Como os preços da Gasolina Comum e do Etanol em SP variaram em 2018?
gasolinaEtanolSP = data.query('PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"] and ESTADO == "SAO PAULO" and ANO == 2018')
gasolinaEtanolSP
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 95270        95270   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 95351        95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 95421        95421   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 95502        95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 95573        95573   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# ...            ...          ...         ...      ...        ...
# 102724      102724   2018-12-16  2018-12-22  SUDESTE  SAO PAULO
# 102793      102793   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 102874      102874   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 102944      102944   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
# 103025      103025   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 95270   ETANOL HIDRATADO                          1664              R$/l
# ...

# %%
gasolinaEtanolSP['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count           104.000000
# mean              3.457337
# std               0.766239
# min               2.393000
# 25%               2.726000
# 50%               3.431000
# 75%               4.199000
# max               4.512000

# %%
gasolinaEtanolSP.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512
