# %% [markdown]
# ## **Pandas Essencial**
# **Prof. Dr. Samuel Martins (@hisamuka @xavecoding)** <br/>
# xavecoding: https://youtube.com/c/xavecoding <br/>
#
# Neste tutorial, vamos aprender o essencial da biblioteca _Pandas_ para manipulação de dados.<br/><br/>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/"><img alt="Creative Commons License" style="border-width:0" src="https://i.creativecommons.org/l/by-nc-sa/4.0/88x31.png" /></a><br />This work is licensed under a <a rel="license" href="http://creativecommons.org/licenses/by-nc-sa/4.0/">Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International License</a>.

# %% [markdown]
# ### Pacotes usados neste Notebook

# %%
# pacotes usados neste notebook
import pandas as pd

# %% [markdown]
# <h1>Manipulação de Dados com Pandas</h1><hr/>

# %% [markdown]
# <h2>1. Manipulação Básica de Datasets</h2>
# <hr/>

# %% [markdown]
# **Dataset**: Gas Prices in Brazil: https://www.kaggle.com/matheusfreitag/gas-prices-in-brazil <br/>
#
# Este dataset contém os **registros dos preços médios semanais dos combustíveis do Brasil entre os anos de 2004 e 2019**. <br/>
# Cada *amostra (registro/linha)* consiste em um registro de preço aferido para um dado tipo de combustível em uma dada localidade do Brasil. <br/>
# Alguns dos principais *atributos* (colunas) do dataset são: 'ESTADO', 'PRODUTO', 'NÚMERO DE POSTOS PESQUISADOS', 'PREÇO MÉDIO REVENDA'.
#
#
# \* O arquivo disponibilizado no Kaggle está no formato *tsv*. Embora o _pandas_ consiga abrí-lo normalmente, convertemos tal arquivo para o formato *CSV*, que é um dos formatos mais utilizados, e mudamos seu separado para ';' apenas para mostrar algumas opções da função de carregamento.

# %% [markdown]
# ### 1.1. Importando o Dataset
# Para carregar um dataset no formato csv, basta utilizar a função `read_csv` do pandas. Por padrão, ela considera _','_ como separador.

# %%
data = pd.read_csv('Datasets/GasPricesinBrazil_2004-2019.csv') 
#importou um arquivo csv

# %%
data
# Out:
#        Unnamed: 0;DATA INICIAL;DATA FINAL;REGIÃO;ESTADO;PRODUTO;NÚMERO DE POSTOS PESQUISADOS;UNIDADE DE MEDIDA;PREÇO MÉDIO REVENDA;DESVIO PADRÃO REVENDA;PREÇO MÍNIMO REVENDA;PREÇO MÁXIMO REVENDA;MARGEM MÉDIA REVENDA;COEF DE VARIAÇÃO REVENDA;PREÇO MÉDIO DISTRIBUIÇÃO;DESVIO PADRÃO DISTRIBUIÇÃO;PREÇO MÍNIMO DISTRIBUIÇÃO;PREÇO MÁXIMO DISTRIBUIÇÃO;COEF DE VARIAÇÃO DISTRIBUIÇÃO;MÊS;ANO
# 0       0;2004-05-09;2004-05-15;CENTRO OESTE;DISTRITO ...
# 1       1;2004-05-09;2004-05-15;CENTRO OESTE;GOIAS;ETA...
# 2       2;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 3       3;2004-05-09;2004-05-15;CENTRO OESTE;MATO GROS...
# 4       4;2004-05-09;2004-05-15;NORDESTE;ALAGOAS;ETANO...
# ...                                                   ...
# 106818  106818;2019-06-23;2019-06-29;NORDESTE;RIO GRAN...
# 106819  106819;2019-06-23;2019-06-29;SUL;RIO GRANDE DO...
# 106820  106820;2019-06-23;2019-06-29;SUL;SANTA CATARIN...
# 106821  106821;2019-06-23;2019-06-29;SUDESTE;SAO PAULO...
# 106822  106822;2019-06-23;2019-06-29;NORDESTE;SERGIPE;...
#
# [106823 rows x 1 columns]

# %% [markdown]
# O dataset não foi carregado corretamente pois o separador utilizado seu arquivo CSV era ';' e não a ','. <br/>
# Vamos então carregá-lo corretamente:

# %%
data=pd.read_csv('Datasets/GasPricesinBrazil_2004-2019.csv', sep = ';') 
#Carregando o dataset corretamente --> separador ";"
# separador foi modificado com o comando sep=''

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# ### 1.2. Exibindo as primeiras linhas do Dataset
# A função `.head()` exibe as 5 primeiras linhas do dataset/tabela/Data Frame.

# %%
data.head() 
#Por padrão aparecerá as 5 primeiras LINHAS
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
data.head(3)
#mostrará as 3 primeiras LINHAS pois é o que foi pedido
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO            ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE  DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE             GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE       MATO GROSSO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
#
# [3 rows x 21 columns]

# %% [markdown]
# ### 1.3 Informações do Dataset e Elementos Chave

# %% [markdown]
# ### 1.3.1 Informações gerais sobre o Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  12  MARGEM MÉDIA REVENDA           106823 non-null  object
#  13  COEF DE VARIAÇÃO REVENDA       106823 non-null  float64
#  14  PREÇO MÉDIO DISTRIBUIÇÃO       106823 non-null  object
#  15  DESVIO PADRÃO DISTRIBUIÇÃO     106823 non-null  object
#  16  PREÇO MÍNIMO DISTRIBUIÇÃO      106823 non-null  object
#  17  PREÇO MÁXIMO DISTRIBUIÇÃO      106823 non-null  object
#  18  COEF DE VARIAÇÃO DISTRIBUIÇÃO  106823 non-null  object
#  19  MÊS                            106823 non-null  int64
#  20  ANO                            106823 non-null  int64
# dtypes: float64(5), int64(4), object(12)
# memory usage: 17.1+ MB

# %% [markdown]
# A primeira coluna da tabela, chamada _'Unnamed: 0'_, parece não significar nada. Na verdade, ela parece ser os **índices** da tabela, que foram salvos como uma _coluna_.<br/>
# Veremos jajá como **remover tal coluna**.
#
# Outro ponto é que, aparentemente, nenhum atributo/coluna possui valores nulos (_null_), uma vez que o número de registros do dataframe e os números de valores _non-null_ é de **106823**. <br/>
# Mas, veremos que não é bem assim para esse caso.

# %% [markdown]
# ### 1.3.2 Data Frame
# Todo dataset carregado (dados estruturados) é um `Data Frame`: 'Tabela' bi-dimensional, de tamanho mutável, com dados potencialmente heterogêneos. <br/>

# %%
type(data) 
#Verificação da var data que é um Dataframe
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Podemos acessar as **dimensões do Data Frame** (número de linhas x número de colunas) utilizando o atributo `.shape` do Data Frame.

# %%
data.shape
#Verificando a forma da var 
#A tupla a abaixo significa o (n° de linhas , n° de colunas )
# Out:
# (106823, 21)

# %%
print(f'O Dataframe possui {data.shape[0]} linhas e {data.shape[1]} colunas')
#Pode ser feito um print formatado com as informaçoẽs
# Out:
# O Dataframe possui 106823 linhas e 21 colunas

# %% [markdown]
# #### **Criando um DataFrame**
#
# Podemos criar um DataFrame a partir de um _dicionário_, onde cada **chave** possui uma **lista de elementos de igual tamanho**.<br/>
# As **chaves** representam as **colunas** e **cada um dos valores de sua lista** representa o **valor da linha** correspondente para aquela coluna.

# %%
personagens_df = pd.DataFrame({
    'nome':['Luke Skywalker', 'Yoda', 'Palpatine'],
    'idade':[16, 1000, 70],
    'peso': [70.5, 15.3, 60.0],
    'eh jedi': [True, True, False]   # o nome das colunas podem ter espaços
})

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.3     True
# 2       Palpatine     70  60.0    False

# %%
personagens_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nome     3 non-null      object
#  1   idade    3 non-null      int64
#  2   peso     3 non-null      float64
#  3   eh jedi  3 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(1)
# memory usage: 203.0+ bytes

# %% [markdown]
# #### **VEJA MAIS**
# Criando um Data Frame a partir de um dicionário: https://www.geeksforgeeks.org/how-to-create-dataframe-from-dictionary-in-python-pandas/

# %% [markdown]
# #### **Renomeando as colunas de um DataFrame**
# **===>** O atributo `DataFrame.columns` retorna uma ";lista" com os **nomes de todas as colunas** do data frame.

# %%
personagens_df.columns
# Out:
# Index(['nome', 'idade', 'peso', 'eh jedi'], dtype='object')

# %%
type(personagens_df.columns)
#As colunas são do tipo index
# Out:
# pandas.core.indexes.base.Index

# %%
list(personagens_df)
#O DataFrame pode ser convertido para uma lista
# Out:
# ['nome', 'idade', 'peso', 'eh jedi']

# %% [markdown]
# <br/>
#
# **===>** Para **renomear colunas** do data frame, utilize o método `DataFrame.rename`, que retorna uma _cópia_ do data frame com as as colunas renomeadas:

# %%
personagens_df
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.3     True
# 2       Palpatine     70  60.0    False

# %%
personagens_df_renomeado=personagens_df.rename(columns={
    'nome': 'aluno',
    'idade': 'Idade'
})
#Pode-se renomear as colunas nesta orem:
#'coluna': 'novo nome desejado'

# %%
personagens_df_renomeado
#O rename sempre retorna uma cópia do Dataframe original
# Out:
#             aluno  Idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.3     True
# 2       Palpatine     70  60.0    False

# %%
personagens_df
#df original
# Out:
#              nome  idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.3     True
# 2       Palpatine     70  60.0    False

# %% [markdown]
# Para renomear o _próprio_ data frame em questão, utilize o parâmetro `inplace=True`:

# %%
personagens_df_renomeado=personagens_df.rename(columns={
    'nome': 'aluno',
    'idade': 'Idade'
}, inplace=True) 
#Mudou os nomes das colunas do Dtaframe original

# %%
personagens_df
# Out:
#             aluno  Idade  peso  eh jedi
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.3     True
# 2       Palpatine     70  60.0    False

# %% [markdown]
# <br/>
#
# **===>** Uma outra forma de **renomear todas as colunas** de um data frame é passar uma _lista_ com os novos nomes das colunas para o atributo `DataFrame.columns`:

# %%
personagens_df.columns=('NOME','IDADE','PESO','EH_JEDI')

# %%
personagens_df
# Out:
#              NOME  IDADE  PESO  EH_JEDI
# 0  Luke Skywalker     16  70.5     True
# 1            Yoda   1000  15.3     True
# 2       Palpatine     70  60.0    False

# %% [markdown]
# ### 1.3.3 Series

# %% [markdown]
# Array uni-dimensional com os dados e rótulos de um eixo.

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
data['ESTADO']
#Selecionando uma coluna INTEIRA
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
#Selecionando uma coluna INTEIR
#Essa forma de acesso só funciona para colunas com nomes sem espaços, acentos, etc...
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
type(data['ESTADO'])
# Out:
# pandas.core.series.Series

# %%
data.iloc[1]
#Seleciondo linhas, neste caso a linha do índice 1
#Para seleção de uma linha é necessário o seu índice
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Name: 1, dtype: object

# %%
type(data.iloc[1])
# Out:
# pandas.core.series.Series

# %%
#Series --> uma lista de valores que geralmente representam 
# algun eixo em um Dataframe, seja uma coluna ou uma linha

# %% [markdown]
# #### **Criando uma Series**
#
# Podemos criar um DataFrame a partir de uma lista de elementos.

# %%
pd.Series([1.9, 6.0, 23.4])
# Out:
# 0     1.9
# 1     6.0
# 2    23.4
# dtype: float64

# %% [markdown]
# Podemos alterar o **nome dos índices** (veremos melhor jajá) e o **nome da Series** (o que ela representa):

# %%
pd.Series([1.9, 6.0, 23.4], index=['prova1','prova2','trabalho'], name='Notas do aluno')
#Modificando o nome dos índices, neste caso com valores textuais
#Pode-se dar um nome as suas Series com o comando name=
# Out:
# prova1       1.9
# prova2       6.0
# trabalho    23.4
# Name: Notas do aluno, dtype: float64

# %% [markdown]
# #### **VEJA MAIS**
# https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html

# %% [markdown]
# ### 1.3.4 Atribuindo Dados

# %% [markdown]
# #### 1.3.4.1 Atribuindo constantes

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
produto_view=data['PRODUTO']
produto_view 
#As series NÃO retorna uma CÓPIA mas retorna uma REFERÊNCIA da coluna
#Neste comando somente foi adicionado uma var para coluna (produto_view)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copia=data['PRODUTO'].copy()
produto_copia
#retorna uma cópia da coluna PRODUTOS
#Para criação de uma cópia de uma coluna usamos a função copy()
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copia_backup=data['PRODUTO'].copy()
produto_copia_backup
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO']='combustível' 
#Atribuiu o valor "combustível" para cada linha deste Dataframe na coluna PRODUTO

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#        PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  combustível                           127              R$/l
# 1  combustível                           387              R$/l
# 2  combustível                           192              R$/l
# 3  combustível                           162              R$/l
# 4  combustível                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# 1                1.162                  0.114  ...                 1.449
# 2                1.389                  0.097  ...                 1.760
# 3                1.262                  0.070  ...                 1.509
# 4                1.181                  0.078  ...                 1.400
#
#    MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                 0.463                    0.012                     0.825
# 1                 0.399                    0.098                     0.763
# 2                 0.419                    0.070                      0.97
# 3                 0.432                    0.055                      0.83
# 4                  0.24                    0.066                     0.941
#
#   DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                       0.11                    0.4201
# 1                      0.088                    0.5013
# 2                      0.095                    0.5614
# 3                      0.119                    0.5991
# 4                      0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
# [5 rows x 21 columns]

# %%
produto_view
#Como essa var foi aplicada para visualização, ela também foi modificada já que ela mostra os dados das lista original
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
produto_copia_backup
#NÃO foi modificado pois é uma cópia da coluna original ANTES de ser modificada
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# #### 1.3.4.2 Atribuindo listas ou series

# %%
num_linha, num_coluna=data.shape
num_linha, num_coluna
#n°linhas x n°colunas
# Out:
# (106823, 21)

# %%
novo_produto=[f'Produto {indice}'for indice in range(num_linha)]
len(novo_produto)
#Para cada linha da tabela
#tamanho da var novo_produto
# Out:
# 106823

# %%
data['PRODUTO']=novo_produto
#Adiciona os valores da var novo_produto na coluna PRODUTO do dataframe

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO         PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL       Produto 0                           127
# 1                     GOIAS       Produto 1                           387
# 2               MATO GROSSO       Produto 2                           192
# 3        MATO GROSSO DO SUL       Produto 3                           162
# 4                   ALAGOAS       Produto 4                           103
# ...                     ...             ...                           ...
# 106818  RIO GRANDE DO NORTE  Produto 106818                             7
# 106819    RIO GRANDE DO SUL  Produto 106819                            23
# 106820       SANTA CATARINA  Produto 106820                            24
# 106821            SAO PAULO  Produto 106821                            52
# 106822              SERGIPE  Produto 106822                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %%
produto_view
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO']=produto_copia_backup
#Voltando para ooriginais

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA COEF DE VARIAÇÃO REVENDA  \
# 0                      1.350                 0.463                    0.012
# 1                      1.449                 0.399                    0.098
# 2                      1.760                 0.419                    0.070
# 3                      1.509                 0.432                    0.055
# 4                      1.400                  0.24                    0.066
# ...                      ...                   ...                      ...
# 106818                 3.690                 0.818                    0.018
# 106819                 3.789                  0.95                    0.038
# 106820                 3.499                 0.914                    0.065
# 106821                 3.490                 0.646                    0.076
# 106822                 3.699                 1.179                    0.001
#
#         PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                       0.11
# 1                          0.763                      0.088
# 2                           0.97                      0.095
# 3                           0.83                      0.119
# 4                          0.941                      0.077
# ...                          ...                        ...
# 106818                     2.756                          0
# 106819                     2.451                      0.402
# 106820                     1.998                          0
# 106821                     2.374                      0.165
# 106822                     2.518                          0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                    0.9666
# 1                         0.5013                      1.05
# 2                         0.5614                     1.161
# 3                         0.5991                   1.22242
# 4                         0.7441                    1.0317
# ...                          ...                       ...
# 106818                     2.756                     2.756
# 106819                    1.9842                    2.8661
# 106820                    1.9981                    1.9981
# 106821                    2.0179                    2.5093
# 106822                    2.5175                    2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                              0.133   5  2004
# 1                              0.115   5  2004
# 2                              0.098   5  2004
# 3                              0.143   5  2004
# 4                              0.082   5  2004
# ...                              ...  ..   ...
# 106818                             0   6  2019
# 106819                         0.164   6  2019
# 106820                             0   6  2019
# 106821                          0.07   6  2019
# 106822                             0   6  2019
#
# [106823 rows x 21 columns]

# %% [markdown]
# #### 1.3.4.3 Criando novas colunas
# Para **criar uma nova coluna** em um data frame, basta atribuirmos uma _lista/Series de valores_ a uma **nova 'chave'** do data frame. <br/>
#
# **PS:** A _quantidade de valores_ da lista precisa ser **igual** ao _número de linhas/registros_ do data frame.

# %%
data['Coluna']='COLUNA_EXEMPLO'
#Criando uma coluna a partir de um valor constante
#todas as linhs teram o mesmo valor nesta coluna

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# 0                1.288                  0.016  ...                 0.463
# 1                1.162                  0.114  ...                 0.399
# 2                1.389                  0.097  ...                 0.419
# 3                1.262                  0.070  ...                 0.432
# 4                1.181                  0.078  ...                  0.24
#
#    COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                     0.012                    0.825
# 1                     0.098                    0.763
# 2                     0.070                     0.97
# 3                     0.055                     0.83
# 4                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#            Coluna
# 0  COLUNA_EXEMPLO
# 1  COLUNA_EXEMPLO
# 2  COLUNA_EXEMPLO
# 3  COLUNA_EXEMPLO
# 4  COLUNA_EXEMPLO
#
# [5 rows x 22 columns]

# %%
data['coluna a partir de lista']=range(data.shape[0])
#Crimos outra coluna onde atribuimos valor para cada uma das linhas 
#Passamos um intervalo para adicionar valores em todasa as linhas começando pelo 0

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                          0.012                     0.825
# 1                          0.098                     0.763
# 2                          0.070                      0.97
# 3                          0.055                      0.83
# 4                          0.066                     0.941
# ...                          ...                       ...
# 106818                     0.018                     2.756
# 106819                     0.038                     2.451
# 106820                     0.065                     1.998
# 106821                     0.076                     2.374
# 106822                     0.001                     2.518
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                            0.11                     0.4201
# 1                           0.088                     0.5013
# 2                           0.095                     0.5614
# 3                           0.119                     0.5991
# 4                           0.077                     0.7441
# ...                           ...                        ...
# 106818                          0                      2.756
# 106819                      0.402                     1.9842
# 106820                          0                     1.9981
# 106821                      0.165                     2.0179
# 106822                          0                     2.5175
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                         0.9666                         0.133   5  2004
# 1                           1.05                         0.115   5  2004
# 2                          1.161                         0.098   5  2004
# 3                        1.22242                         0.143   5  2004
# 4                         1.0317                         0.082   5  2004
# ...                          ...                           ...  ..   ...
# 106818                     2.756                             0   6  2019
# 106819                    2.8661                         0.164   6  2019
# 106820                    1.9981                             0   6  2019
# 106821                    2.5093                          0.07   6  2019
# 106822                    2.5175                             0   6  2019
#
#                 Coluna  coluna a partir de lista
# 0       COLUNA_EXEMPLO                         0
# 1       COLUNA_EXEMPLO                         1
# 2       COLUNA_EXEMPLO                         2
# 3       COLUNA_EXEMPLO                         3
# 4       COLUNA_EXEMPLO                         4
# ...                ...                       ...
# 106818  COLUNA_EXEMPLO                    106818
# 106819  COLUNA_EXEMPLO                    106819
# 106820  COLUNA_EXEMPLO                    106820
# 106821  COLUNA_EXEMPLO                    106821
# 106822  COLUNA_EXEMPLO                    106822
#
# [106823 rows x 23 columns]

# %%
data['não funciona']=[1, 2, 3]
#NÃO FUNCIONA, pois para atribuir elementos de uma lista em um dataframe é preciso que essa lista tenha o n° de elementos igual ao n° de linhas do dataframe
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 data['não funciona']=[1, 2, 3]
#       2 #NÃO FUNCIONA, pois para atribuir elementos de uma lista em um dataframe é preciso que essa lista tenha o n° de elementos igual ao n° de linhas do dataframe
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4311, in DataFrame.__setitem__(self, key, value)
#    4308     self._setitem_array([key], value)
#    4309 else:
#    4310     # set column
# -> 4311     self._set_item(key, value)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:4524, in DataFrame._set_item(self, key, value)
#    4514 def _set_item(self, key, value) -> None:
#    4515     """
#    4516     Add series to DataFrame in specified column.
#    4517
#    (...)
#    4522     ensure homogeneity.
#    4523     """
# -> 4524     value, refs = self._sanitize_column(value)
#    4526     if (
#    4527         key in self.columns
#    4528         and value.ndim == 1
#    4529         and not isinstance(value.dtype, ExtensionDtype)
#    4530     ):
#    4531         # broadcast across multiple columns if necessary
#    4532         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:5266, in DataFrame._sanitize_column(self, value)
#    5263     return _reindex_for_setitem(value, self.index)
#    5265 if is_list_like(value):
# -> 5266     com.require_length_match(value, self.index)
#    5267 arr = sanitize_array(value, self.index, copy=True, allow_2d=True)
#    5268 if (
#    5269     isinstance(value, Index)
#    5270     and value.dtype == "object"
#    (...)
#    5273     # TODO: Remove kludge in sanitize_array for string mode when enforcing
#    5274     # this deprecation
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/common.py:573, in require_length_match(data, index)
#     569 """
#     570 Check the length of data matches the length of the index.
#     571 """
#     572 if len(data) != len(index):
# --> 573     raise ValueError(
#     574         "Length of values "
#     575         f"({len(data)}) "
#     576         "does not match length of index "
#     577         f"({len(index)})"
#     578     )
#
# ValueError: Length of values (3) does not match length of index (106823)

# %% [markdown]
# <br/>
#
# Outro exemplo:

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO          Coluna  \
# 0                         0.133   5  2004  COLUNA_EXEMPLO
# 1                         0.115   5  2004  COLUNA_EXEMPLO
# 2                         0.098   5  2004  COLUNA_EXEMPLO
# 3                         0.143   5  2004  COLUNA_EXEMPLO
# 4                         0.082   5  2004  COLUNA_EXEMPLO
#
#    coluna a partir de lista
# 0                         0
# 1                         1
# 2                         2
# 3                         3
# 4                         4
#
# [5 rows x 23 columns]

# %%
data['PREÇO MÉDIO REVENDA (dólar)']=data['PREÇO MÉDIO REVENDA']*5.60
#Pode se criar uma coluna a partir de uma já existente
#Multiplicamos a coluna 'PREÇO MÉDIO REVENDA' pelo valor do dólar e adribuimos os resultados a uma nova coluna 'PREÇO MÉDIO REVENDA (dólar)'

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#            Coluna coluna a partir de lista  PREÇO MÉDIO REVENDA (dólar)
# 0  COLUNA_EXEMPLO                        0                       7.2128
# 1  COLUNA_EXEMPLO                        1                       6.5072
# 2  COLUNA_EXEMPLO                        2                       7.7784
# 3  COLUNA_EXEMPLO                        3                       7.0672
# 4  COLUNA_EXEMPLO                        4                       6.6136
#
# [5 rows x 24 columns]

# %% [markdown]
# **PS:** Obviamente, a lógica correta em converter o preço dos combustíveis em reais para dólares não é considerar uma taxa de câmbio fixa, uma vez que cada preço foi aferido em um momento diferente.

# %% [markdown]
# ### 1.3.4 Índices

# %% [markdown]
# Todo Data Frame possui **índices**, que não são considerado colunas da tabela. Tais índices são comumente **númericos**, de 0 a num_linhas-1, mas também podem ser **textuais (rótulos/labels)**.

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# 2               MATO GROSSO  ETANOL HIDRATADO                           192
# 3        MATO GROSSO DO SUL  ETANOL HIDRATADO                           162
# 4                   ALAGOAS  ETANOL HIDRATADO                           103
# ...                     ...               ...                           ...
# 106818  RIO GRANDE DO NORTE               GNV                             7
# 106819    RIO GRANDE DO SUL               GNV                            23
# 106820       SANTA CATARINA               GNV                            24
# 106821            SAO PAULO               GNV                            52
# 106822              SERGIPE               GNV                             4
#
#        UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   R$/l                1.288                  0.016  ...
# 1                   R$/l                1.162                  0.114  ...
# 2                   R$/l                1.389                  0.097  ...
# 3                   R$/l                1.262                  0.070  ...
# 4                   R$/l                1.181                  0.078  ...
# ...                  ...                  ...                    ...  ...
# 106818             R$/m3                3.574                  0.065  ...
# 106819             R$/m3                3.401                  0.129  ...
# 106820             R$/m3                2.912                  0.190  ...
# 106821             R$/m3                3.020                  0.229  ...
# 106822             R$/m3                3.697                  0.005  ...
#
#         PREÇO MÉDIO DISTRIBUIÇÃO  DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                          0.825                        0.11
# 1                          0.763                       0.088
# 2                           0.97                       0.095
# 3                           0.83                       0.119
# 4                          0.941                       0.077
# ...                          ...                         ...
# 106818                     2.756                           0
# 106819                     2.451                       0.402
# 106820                     1.998                           0
# 106821                     2.374                       0.165
# 106822                     2.518                           0
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO  PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                         0.4201                     0.9666
# 1                         0.5013                       1.05
# 2                         0.5614                      1.161
# 3                         0.5991                    1.22242
# 4                         0.7441                     1.0317
# ...                          ...                        ...
# 106818                     2.756                      2.756
# 106819                    1.9842                     2.8661
# 106820                    1.9981                     1.9981
# 106821                    2.0179                     2.5093
# 106822                    2.5175                     2.5175
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO          Coluna  \
# 0                              0.133   5  2004  COLUNA_EXEMPLO
# 1                              0.115   5  2004  COLUNA_EXEMPLO
# 2                              0.098   5  2004  COLUNA_EXEMPLO
# 3                              0.143   5  2004  COLUNA_EXEMPLO
# 4                              0.082   5  2004  COLUNA_EXEMPLO
# ...                              ...  ..   ...             ...
# 106818                             0   6  2019  COLUNA_EXEMPLO
# 106819                         0.164   6  2019  COLUNA_EXEMPLO
# 106820                             0   6  2019  COLUNA_EXEMPLO
# 106821                          0.07   6  2019  COLUNA_EXEMPLO
# 106822                             0   6  2019  COLUNA_EXEMPLO
#
#        coluna a partir de lista  PREÇO MÉDIO REVENDA (dólar)
# 0                             0                       7.2128
# 1                             1                       6.5072
# 2                             2                       7.7784
# 3                             3                       7.0672
# 4                             4                       6.6136
# ...                         ...                          ...
# 106818                   106818                      20.0144
# 106819                   106819                      19.0456
# 106820                   106820                      16.3072
# 106821                   106821                      16.9120
# 106822                   106822                      20.7032
#
# [106823 rows x 24 columns]

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# Use `list(data.index)` ou `data.index.to_list()` para converter um RangeIndex para uma python list.

# %% [markdown]
# #### **Exemplo de Data Frame com Índices Textuais (labels)**

# %%
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao.head()
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation4', 'Switch'], dtype='object')

# %% [markdown]
# ### 1.4 Selecionando uma ou mais observações (Indexação)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#            Coluna coluna a partir de lista  PREÇO MÉDIO REVENDA (dólar)
# 0  COLUNA_EXEMPLO                        0                       7.2128
# 1  COLUNA_EXEMPLO                        1                       6.5072
# 2  COLUNA_EXEMPLO                        2                       7.7784
# 3  COLUNA_EXEMPLO                        3                       7.0672
# 4  COLUNA_EXEMPLO                        4                       6.6136
#
# [5 rows x 24 columns]

# %% [markdown]
# #### **==>  Index-based selection (seleção baseada em Índices)**
# Mostrando linhas específicas de um DataFrame:
#
# `iloc`: seleciona elementos do Dataframe, baseado em seu **índice (número)** --> row-first, column-second

# %% [markdown]
# **Selecionando uma observação/linha:**

# %%
data.iloc[1]
#Seleciona a linha de indece 1 e mostra suas informações
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Coluna                             COLUNA_EXEMPLO
# coluna a partir de lista                        1
# PREÇO MÉDIO REVENDA (dólar)                6.5072
# Name: 1, dtype: object

# %% [markdown]
# **Selecionando múltiplas observações/linhas:**

# %%
data.iloc[:6]
#Seleciona as linhas de indece 0 até 5
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
# 5                1.383                  0.132  ...                     0.957
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
# 5                       0.128                    0.5686
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
# 5                       1.35                         0.134   5  2004
#
#            Coluna coluna a partir de lista  PREÇO MÉDIO REVENDA (dólar)
# 0  COLUNA_EXEMPLO                        0                       7.2128
# 1  COLUNA_EXEMPLO                        1                       6.5072
# 2  COLUNA_EXEMPLO                        2                       7.7784
# 3  COLUNA_EXEMPLO                        3                       7.0672
# 4  COLUNA_EXEMPLO                        4                       6.6136
# 5  COLUNA_EXEMPLO                        5                       7.7448
#
# [6 rows x 24 columns]

# %%
data.iloc[10:16]
#Seleciona as linhas de indece 10 até 15
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL    REGIÃO               ESTADO  \
# 10          10   2004-05-09  2004-05-15  NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15  NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15     NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15     NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15     NORTE             AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 10  ETANOL HIDRATADO                            89              R$/l
# 11  ETANOL HIDRATADO                           131              R$/l
# 12  ETANOL HIDRATADO                            57              R$/l
# 13  ETANOL HIDRATADO                            33              R$/l
# 14  ETANOL HIDRATADO                            15              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 10                1.573                  0.134  ...                     1.079
# 11                1.276                  0.116  ...                     0.944
# 12                1.301                  0.109  ...                      0.98
# 13                1.805                  0.134  ...                     1.116
# 14                1.785                  0.035  ...                     1.373
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 10                       0.078                    0.8857
# 11                       0.078                    0.7119
# 12                       0.052                    0.8267
# 13                       0.171                     0.767
# 14                       0.167                    0.8339
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 10                     1.2499                         0.072   5  2004
# 11                     1.1386                         0.083   5  2004
# 12                     1.1059                         0.053   5  2004
# 13                     1.2992                         0.153   5  2004
# 14                     1.4912                         0.122   5  2004
# 15                     1.2109                          0.06   5  2004
#
#             Coluna coluna a partir de lista  PREÇO MÉDIO REVENDA (dólar)
# 10  COLUNA_EXEMPLO                       10                       8.8088
# 11  COLUNA_EXEMPLO                       11                       7.1456
# 12  COLUNA_EXEMPLO                       12                       7.2856
# 13  COLUNA_EXEMPLO                       13                      10.1080
# 14  COLUNA_EXEMPLO                       14                       9.9960
# 15  COLUNA_EXEMPLO                       15                       8.8368
#
# [6 rows x 24 columns]

# %%
data.iloc[[1, 5, 10, 15]]
#Selecionando linhas com indices não continuos. Indices: 1, 5, 10, 15
#Colocamos uma lista com os indices das linhas que queremos selecinar dentro do comondo iloc
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1   ETANOL HIDRATADO                           387              R$/l
# 5   ETANOL HIDRATADO                           408              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 1                 1.162                  0.114  ...                     0.763
# 5                 1.383                  0.132  ...                     0.957
# 10                1.573                  0.134  ...                     1.079
# 15                1.578                  0.123  ...                     1.137
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 1                        0.088                    0.5013
# 5                        0.128                    0.5686
# 10                       0.078                    0.8857
# 15                       0.068                    0.9515
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 1                        1.05                         0.115   5  2004
# 5                        1.35                         0.134   5  2004
# 10                     1.2499                         0.072   5  2004
# 15                     1.2109                          0.06   5  2004
#
#             Coluna coluna a partir de lista  PREÇO MÉDIO REVENDA (dólar)
# 1   COLUNA_EXEMPLO                        1                       6.5072
# 5   COLUNA_EXEMPLO                        5                       7.7448
# 10  COLUNA_EXEMPLO                       10                       8.8088
# 15  COLUNA_EXEMPLO                       15                       8.8368
#
# [4 rows x 24 columns]

# %%
data.iloc[[5, 1, 15, 10]]
#Selecionando linhas de indices: 5, 1, 15, 10
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO    ESTADO  \
# 5            5   2004-05-09  2004-05-15      NORDESTE     BAHIA
# 1            1   2004-05-09  2004-05-15  CENTRO OESTE     GOIAS
# 15          15   2004-05-09  2004-05-15         NORTE  AMAZONAS
# 10          10   2004-05-09  2004-05-15      NORDESTE     PIAUI
#
#              PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5   ETANOL HIDRATADO                           408              R$/l
# 1   ETANOL HIDRATADO                           387              R$/l
# 15  ETANOL HIDRATADO                            53              R$/l
# 10  ETANOL HIDRATADO                            89              R$/l
#
#     PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 5                 1.383                  0.132  ...                     0.957
# 1                 1.162                  0.114  ...                     0.763
# 15                1.578                  0.123  ...                     1.137
# 10                1.573                  0.134  ...                     1.079
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 5                        0.128                    0.5686
# 1                        0.088                    0.5013
# 15                       0.068                    0.9515
# 10                       0.078                    0.8857
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 5                        1.35                         0.134   5  2004
# 1                        1.05                         0.115   5  2004
# 15                     1.2109                          0.06   5  2004
# 10                     1.2499                         0.072   5  2004
#
#             Coluna coluna a partir de lista  PREÇO MÉDIO REVENDA (dólar)
# 5   COLUNA_EXEMPLO                        5                       7.7448
# 1   COLUNA_EXEMPLO                        1                       6.5072
# 15  COLUNA_EXEMPLO                       15                       8.8368
# 10  COLUNA_EXEMPLO                       10                       8.8088
#
# [4 rows x 24 columns]

# %%
data.iloc[1, 4]
#Selecionando o VALOR da linha de incice 1, coluna 4
# Out:
# 'GOIAS'

# %%
# e assim por diante!

# %% [markdown]
# #### **==>  Label-based selection (seleção baseadas em Rótulos)**
#
# `loc`: seleciona elementos do Dataframe, baseado em seus **rótulos** --> row-first, column-second

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.iloc[0]
#Retorna a linha de ince 0 (implícito)
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao.iloc[0,1]
#Retorna a linha de ince 0 (implícito) e coluna de índece 1 (implícito) --> iloc
#Retorna o valor 131
# Out:
# np.int64(131)

# %%
pesquisa_de_satisfacao.loc['XboxOne']
#Retorna a linha cujo rótulo do índice é 'XboxOne'
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao.iloc['XboxOne']
#NÃO FUNCIONA, pois o comando iloc só funciona com números

# %%
pesquisa_de_satisfacao.loc[1]
#NÃO FUNCIONA, pois o comando loc só funciona com rótulos

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
#Retorna o VALOR da linha 'Playstation4', coluna 'ruim'
#Retorna o n° 2
# Out:
# np.int64(2)

# %%
pesquisa_de_satisfacao.loc[['XboxOne', 'Switch']]
#Retorna somente as linhas 'XboxOne'e 'Switch'
# Out:
#          bom  ruim  pessimo
# XboxOne   50   131       30
# Switch   100    30        1

# %%
pesquisa_de_satisfacao[['bom', 'pessimo']]
#Dessa forma você passa uma lista de colunas que queira retornar 
#Retorna todas as lihas e apenas as colunas 'bom' e 'pessimo'
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %%
pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]
#Usando o loc
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %% [markdown]
# ### OBSERVAÇÃO

# %% [markdown]
# ### *índices númericos*,por defaul, *possuem rótulos que correspondem aos seus valores*

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#            Coluna coluna a partir de lista  PREÇO MÉDIO REVENDA (dólar)
# 0  COLUNA_EXEMPLO                        0                       7.2128
# 1  COLUNA_EXEMPLO                        1                       6.5072
# 2  COLUNA_EXEMPLO                        2                       7.7784
# 3  COLUNA_EXEMPLO                        3                       7.0672
# 4  COLUNA_EXEMPLO                        4                       6.6136
#
# [5 rows x 24 columns]

# %%
data.iloc[1]
#Índice
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Coluna                             COLUNA_EXEMPLO
# coluna a partir de lista                        1
# PREÇO MÉDIO REVENDA (dólar)                6.5072
# Name: 1, dtype: object

# %%
data.loc[1]
#Rótulo
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ANO                                          2004
# Coluna                             COLUNA_EXEMPLO
# coluna a partir de lista                        1
# PREÇO MÉDIO REVENDA (dólar)                6.5072
# Name: 1, dtype: object

# %% [markdown]
# ### 1.5 Selecionando um ou mais atributos (colunas)

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#            Coluna coluna a partir de lista  PREÇO MÉDIO REVENDA (dólar)
# 0  COLUNA_EXEMPLO                        0                       7.2128
# 1  COLUNA_EXEMPLO                        1                       6.5072
# 2  COLUNA_EXEMPLO                        2                       7.7784
# 3  COLUNA_EXEMPLO                        3                       7.0672
# 4  COLUNA_EXEMPLO                        4                       6.6136
#
# [5 rows x 24 columns]

# %%
data['ESTADO']
#Retorna a coluna 'ESTADO' com seus valores
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.ESTADO
#Outra forma de retornar a coluna 'ESTADO'
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.loc[:,'ESTADO']
#Outra forma de retornar a coluna 'ESTADO'
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.DATA INICIAL
#NÃO FUNCIONA ! O comando dataframe.NOME_DA_COLUNA só funciona se o rótulo/nome da coluna NÃO tiver espaço

# %%
data['DATA INICIAL']
#Para selecionar colunas que tem espaço no rótulo/nome
# Out:
# 0         2004-05-09
# 1         2004-05-09
# 2         2004-05-09
# 3         2004-05-09
# 4         2004-05-09
#              ...
# 106818    2019-06-23
# 106819    2019-06-23
# 106820    2019-06-23
# 106821    2019-06-23
# 106822    2019-06-23
# Name: DATA INICIAL, Length: 106823, dtype: object

# %% [markdown]
# Como o rótulo da coluna 'DATA INICIAL' **possui espaço**, não é possível acessá-la como método: `data.DATA INICIAL`

# %%
data[['PRODUTO','ESTADO','REGIÃO']]
#Seleciona multiplas colunas
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %% [markdown]
# ### 1.6 Removendo um Atributo (Coluna) do Data Frame

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                1.288                  0.016  ...                     0.825
# 1                1.162                  0.114  ...                     0.763
# 2                1.389                  0.097  ...                      0.97
# 3                1.262                  0.070  ...                      0.83
# 4                1.181                  0.078  ...                     0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#    PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                     0.9666                         0.133   5  2004
# 1                       1.05                         0.115   5  2004
# 2                      1.161                         0.098   5  2004
# 3                    1.22242                         0.143   5  2004
# 4                     1.0317                         0.082   5  2004
#
#            Coluna coluna a partir de lista  PREÇO MÉDIO REVENDA (dólar)
# 0  COLUNA_EXEMPLO                        0                       7.2128
# 1  COLUNA_EXEMPLO                        1                       6.5072
# 2  COLUNA_EXEMPLO                        2                       7.7784
# 3  COLUNA_EXEMPLO                        3                       7.0672
# 4  COLUNA_EXEMPLO                        4                       6.6136
#
# [5 rows x 24 columns]

# %% [markdown]
# Como vimos anteriormente, o atributo 'Unnamed: 0' parece ser um **ruído** em nosso dataset. Desta maneira, vamos eliminá-lo,

# %%
del data['Unnamed: 0']

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# 1                1.162                  0.114                  0.89  ...
# 2                1.389                  0.097                  1.18  ...
# 3                1.262                  0.070                  1.09  ...
# 4                1.181                  0.078                  1.05  ...
#
#    COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                     0.012                    0.825
# 1                     0.098                    0.763
# 2                     0.070                     0.97
# 3                     0.055                     0.83
# 4                     0.066                    0.941
#
#    DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                        0.11                    0.4201
# 1                       0.088                    0.5013
# 2                       0.095                    0.5614
# 3                       0.119                    0.5991
# 4                       0.077                    0.7441
#
#   PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                    0.9666                         0.133   5  2004
# 1                      1.05                         0.115   5  2004
# 2                     1.161                         0.098   5  2004
# 3                   1.22242                         0.143   5  2004
# 4                    1.0317                         0.082   5  2004
#
#            Coluna  coluna a partir de lista
# 0  COLUNA_EXEMPLO                         0
# 1  COLUNA_EXEMPLO                         1
# 2  COLUNA_EXEMPLO                         2
# 3  COLUNA_EXEMPLO                         3
# 4  COLUNA_EXEMPLO                         4
#
# [5 rows x 22 columns]

# %% [markdown]
# <br/>
#
# Vamos remover as colunas criadas como exeplo nas aulas anteriores

# %%
del data['Coluna']
del data['coluna a partir de lista']
del data['PREÇO MÉDIO REVENDA (dólares)']

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %%
data.shape
# Out:
# (106823, 20)

# %% [markdown]
# ### 1.7 Salvando um Data Frame

# %% [markdown]
# Para salvarmos um Data Frame para um **arquivo CSV**, basta usarmos o método `.to_csv`. <br/>
# Por padrão, esse método **salva os índices da tabela como uma coluna no CSV**.<br/>
# Como no geral tais índices são números de 0 a n-1, não há necessidade para isso (veja que removemos anteriormente a coluna 'Unnamed: 0' que foi justamente esse caso).<br/>
# Desta forma, utilize o parâmetro: `index=False`.
#
# Por padrão, o método utilizará a ',' como separador das colunas. Caso queira alterá-lo, utilize o parâmetro `sep`.

# %%
data.to_csv('Datasets/GasPricesinBrazil_2004-2019 preprocessado.csv', index=False)

# %% [markdown]
# ### 1.8 Seleção Condicional: Filtrando amostras

# %% [markdown]
# Durante nossas análise exploratórias, frequentemente filtraremos nossas amostras, a partir de certas **condições**, para fins de análise mais específica. <br/>
# Existem algumas maneiras de fazermos tal filtragem. Antes disso, vamos carregar nosso dataset pré-processado que salvamos no item anterior.

# %%
data= pd.read_csv('Datasets/GasPricesinBrazil_2004-2019 preprocessado.csv', sep=';')

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO          Coluna  \
# 0                         0.133   5  2004  COLUNA_EXEMPLO
# 1                         0.115   5  2004  COLUNA_EXEMPLO
# 2                         0.098   5  2004  COLUNA_EXEMPLO
# 3                         0.143   5  2004  COLUNA_EXEMPLO
# 4                         0.082   5  2004  COLUNA_EXEMPLO
#
#    coluna a partir de lista
# 0                         0
# 1                         1
# 2                         2
# 3                         3
# 4                         4
#
# [5 rows x 23 columns]

# %%
data['ESTADO'].unique()
#Mostra todos os estados da coluna 'ESTADO' sem repetições
#unique()--> estrai todos valores de uma coluna sem repetições
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# #### **Selecionando apenas os preços dos Postos de São Paulo**

# %% [markdown]
# ##### **==> Alternativa 1: Seleção Condicional (Comparações diretas)**

# %% [markdown]
# O código abaixo retorna uma ***Series ('array') de booleans***, com o número de linhas (amostras) do Data Frame, que informa os registros de preços dos postos do _estado de São Paulo_ (True).

# %%
data['ESTADO']=='SAO PAULO'
#Localizando 'SAO PAULO' na coluna 'ESTADO', onde se na linha tiver 'SAO PAULO' é True
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
selecao=data['ESTADO']=='SAO PAULO'
#Salvando essa series de booleans em uma var

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
type(selecao)
# Out:
# pandas.core.series.Series

# %%
selecao.shape
#Na var 'selecao' só mostra as series/linhas. 
# Por isso, o comando shape só mostra o n° de linhas
# Out:
# (106823,)

# %%
data.shape
# Out:
# (106823, 23)

# %% [markdown]
# Para **filtrarmos** os registros de postos do estado de São Paulo:

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                      0.085                 0.590                 1.150
# 50                      0.083                 0.590                 1.150
# 77                      0.071                 0.620                 1.199
# 104                     0.075                 0.639                 1.359
# 131                     0.071                 0.669                 1.199
# ...                       ...                   ...                   ...
# 106724                  0.156                 3.099                 4.220
# 106751                  0.169                 3.199                 4.320
# 106778                  0.183                 3.769                 4.999
# 106805                  6.100                50.000                89.900
# 106821                  0.229                 2.699                 3.490
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                    0.198                     0.111
# 50                     0.19                     0.108
# 77                    0.209                     0.086
# 104                   0.216                     0.085
# 131                   0.205                     0.079
# ...                     ...                       ...
# 106724                0.401                     0.045
# 106751                0.451                     0.047
# 106778                0.429                     0.044
# 106805               17.679                     0.091
# 106821                0.646                     0.076
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.57                      0.056
# 50                        0.576                       0.05
# 77                        0.614                      0.063
# 104                       0.671                      0.075
# 131                       0.689                      0.072
# ...                         ...                        ...
# 106724                    3.047                      0.097
# 106751                    3.123                      0.111
# 106778                    3.713                      0.097
# 106805                   49.214                      5.071
# 106821                    2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                             0.098    5  2004
# 50                             0.087    5  2004
# 77                             0.103    5  2004
# 104                            0.112    5  2004
# 131                            0.104    6  2004
# ...                              ...  ...   ...
# 106724                         0.032    6  2019
# 106751                         0.036    6  2019
# 106778                         0.026    6  2019
# 106805                         0.103    6  2019
# 106821                          0.07    6  2019
#
# [4263 rows x 20 columns]

# %% [markdown]
# O resultado é um Data Frame com _apenas_ os registros desejados após a **filtragem**.<br/>
# Podemos ainda utilizar o método `loc` para o mesmo fim:

# %%
data.loc[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                      0.085                 0.590                 1.150
# 50                      0.083                 0.590                 1.150
# 77                      0.071                 0.620                 1.199
# 104                     0.075                 0.639                 1.359
# 131                     0.071                 0.669                 1.199
# ...                       ...                   ...                   ...
# 106724                  0.156                 3.099                 4.220
# 106751                  0.169                 3.199                 4.320
# 106778                  0.183                 3.769                 4.999
# 106805                  6.100                50.000                89.900
# 106821                  0.229                 2.699                 3.490
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                    0.198                     0.111
# 50                     0.19                     0.108
# 77                    0.209                     0.086
# 104                   0.216                     0.085
# 131                   0.205                     0.079
# ...                     ...                       ...
# 106724                0.401                     0.045
# 106751                0.451                     0.047
# 106778                0.429                     0.044
# 106805               17.679                     0.091
# 106821                0.646                     0.076
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.57                      0.056
# 50                        0.576                       0.05
# 77                        0.614                      0.063
# 104                       0.671                      0.075
# 131                       0.689                      0.072
# ...                         ...                        ...
# 106724                    3.047                      0.097
# 106751                    3.123                      0.111
# 106778                    3.713                      0.097
# 106805                   49.214                      5.071
# 106821                    2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                             0.098    5  2004
# 50                             0.087    5  2004
# 77                             0.103    5  2004
# 104                            0.112    5  2004
# 131                            0.104    6  2004
# ...                              ...  ...   ...
# 106724                         0.032    6  2019
# 106751                         0.036    6  2019
# 106778                         0.026    6  2019
# 106805                         0.103    6  2019
# 106821                          0.07    6  2019
#
# [4263 rows x 20 columns]

# %% [markdown]
# ##### **==> Alternativa 2: Utilizando o método `query`**

# %% [markdown]
# `query` filtra linhas de um DataFrame baseado em uma **query (pergunta)**.

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# 1                1.162                  0.114                  0.89
# 2                1.389                  0.097                  1.18
# 3                1.262                  0.070                  1.09
# 4                1.181                  0.078                  1.05
#
#    PREÇO MÁXIMO REVENDA MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 0                 1.350                0.463                     0.012
# 1                 1.449                0.399                     0.098
# 2                 1.760                0.419                     0.070
# 3                 1.509                0.432                     0.055
# 4                 1.400                 0.24                     0.066
#
#   PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                    0.825                       0.11
# 1                    0.763                      0.088
# 2                     0.97                      0.095
# 3                     0.83                      0.119
# 4                    0.941                      0.077
#
#   PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                    0.4201                    0.9666
# 1                    0.5013                      1.05
# 2                    0.5614                     1.161
# 3                    0.5991                   1.22242
# 4                    0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                         0.133    5  2004
# 1                         0.115    5  2004
# 2                         0.098    5  2004
# 3                         0.143    5  2004
# 4                         0.082    5  2004

# %%
data.query('ESTADO=="SAO PAULO"')
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                      0.085                 0.590                 1.150
# 50                      0.083                 0.590                 1.150
# 77                      0.071                 0.620                 1.199
# 104                     0.075                 0.639                 1.359
# 131                     0.071                 0.669                 1.199
# ...                       ...                   ...                   ...
# 106724                  0.156                 3.099                 4.220
# 106751                  0.169                 3.199                 4.320
# 106778                  0.183                 3.769                 4.999
# 106805                  6.100                50.000                89.900
# 106821                  0.229                 2.699                 3.490
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                    0.198                     0.111
# 50                     0.19                     0.108
# 77                    0.209                     0.086
# 104                   0.216                     0.085
# 131                   0.205                     0.079
# ...                     ...                       ...
# 106724                0.401                     0.045
# 106751                0.451                     0.047
# 106778                0.429                     0.044
# 106805               17.679                     0.091
# 106821                0.646                     0.076
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.57                      0.056
# 50                        0.576                       0.05
# 77                        0.614                      0.063
# 104                       0.671                      0.075
# 131                       0.689                      0.072
# ...                         ...                        ...
# 106724                    3.047                      0.097
# 106751                    3.123                      0.111
# 106778                    3.713                      0.097
# 106805                   49.214                      5.071
# 106821                    2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                             0.098    5  2004
# 50                             0.087    5  2004
# 77                             0.103    5  2004
# 104                            0.112    5  2004
# 131                            0.104    6  2004
# ...                              ...  ...   ...
# 106724                         0.032    6  2019
# 106751                         0.036    6  2019
# 106778                         0.026    6  2019
# 106805                         0.103    6  2019
# 106821                          0.07    6  2019
#
# [4263 rows x 20 columns]

# %% [markdown]
# <br/>
#
# Uma boa prática é **salvar o Data Frame filtrado em uma nova variável**. Isso simplifica a complexidade do código para futuras análiseS feita para os postos de São Paulo, neste caso.

# %%
postos_SP = data.query('ESTADO=="SAO PAULO"')

# %%
postos_SP
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                      0.085                 0.590                 1.150
# 50                      0.083                 0.590                 1.150
# 77                      0.071                 0.620                 1.199
# 104                     0.075                 0.639                 1.359
# 131                     0.071                 0.669                 1.199
# ...                       ...                   ...                   ...
# 106724                  0.156                 3.099                 4.220
# 106751                  0.169                 3.199                 4.320
# 106778                  0.183                 3.769                 4.999
# 106805                  6.100                50.000                89.900
# 106821                  0.229                 2.699                 3.490
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                    0.198                     0.111
# 50                     0.19                     0.108
# 77                    0.209                     0.086
# 104                   0.216                     0.085
# 131                   0.205                     0.079
# ...                     ...                       ...
# 106724                0.401                     0.045
# 106751                0.451                     0.047
# 106778                0.429                     0.044
# 106805               17.679                     0.091
# 106821                0.646                     0.076
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.57                      0.056
# 50                        0.576                       0.05
# 77                        0.614                      0.063
# 104                       0.671                      0.075
# 131                       0.689                      0.072
# ...                         ...                        ...
# 106724                    3.047                      0.097
# 106751                    3.123                      0.111
# 106778                    3.713                      0.097
# 106805                   49.214                      5.071
# 106821                    2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                             0.098    5  2004
# 50                             0.087    5  2004
# 77                             0.103    5  2004
# 104                            0.112    5  2004
# 131                            0.104    6  2004
# ...                              ...  ...   ...
# 106724                         0.032    6  2019
# 106751                         0.036    6  2019
# 106778                         0.026    6  2019
# 106805                         0.103    6  2019
# 106821                          0.07    6  2019
#
# [4263 rows x 20 columns]

# %%
postos_SP.shape
# Out:
# (4263, 20)

# %%
postos_SP.head()
# Out:
#     DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23    2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50    2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77    2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
#
#      NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                           4047              R$/l                0.768
# 50                           4066              R$/l                0.766
# 77                           4077              R$/l                0.823
# 104                          4073              R$/l                0.887
# 131                          4082              R$/l                0.894
#
#      DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                   0.085                 0.590                 1.150
# 50                   0.083                 0.590                 1.150
# 77                   0.071                 0.620                 1.199
# 104                  0.075                 0.639                 1.359
# 131                  0.071                 0.669                 1.199
#
#     MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 23                 0.198                     0.111                     0.57
# 50                  0.19                     0.108                    0.576
# 77                 0.209                     0.086                    0.614
# 104                0.216                     0.085                    0.671
# 131                0.205                     0.079                    0.689
#
#     DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 23                       0.056                    0.4271
# 50                        0.05                   0.43204
# 77                       0.063                   0.34951
# 104                      0.075                    0.3398
# 131                      0.072                   0.47797
#
#     PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                     1.4123                         0.098    5  2004
# 50                     0.9724                         0.087    5  2004
# 77                      1.412                         0.103    5  2004
# 104                    1.0669                         0.112    5  2004
# 131                    1.0669                         0.104    6  2004

# %% [markdown]
# <br/>
#
# ### RESETANDO OS ÍNDICES

# %% [markdown]
# Note que as linhas do dataframe a cima continua os mesmos da dataframe original.
# Em muita das vezes os índices originais são importantes.
# <br/>
#
# Mas se quiser resetar os índices do dataframe filtrado, fazendo os índices começarem de 0 à n°_de_linhas, use o comando .reset_index

# %%
postos_SP
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                      0.085                 0.590                 1.150
# 50                      0.083                 0.590                 1.150
# 77                      0.071                 0.620                 1.199
# 104                     0.075                 0.639                 1.359
# 131                     0.071                 0.669                 1.199
# ...                       ...                   ...                   ...
# 106724                  0.156                 3.099                 4.220
# 106751                  0.169                 3.199                 4.320
# 106778                  0.183                 3.769                 4.999
# 106805                  6.100                50.000                89.900
# 106821                  0.229                 2.699                 3.490
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                    0.198                     0.111
# 50                     0.19                     0.108
# 77                    0.209                     0.086
# 104                   0.216                     0.085
# 131                   0.205                     0.079
# ...                     ...                       ...
# 106724                0.401                     0.045
# 106751                0.451                     0.047
# 106778                0.429                     0.044
# 106805               17.679                     0.091
# 106821                0.646                     0.076
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.57                      0.056
# 50                        0.576                       0.05
# 77                        0.614                      0.063
# 104                       0.671                      0.075
# 131                       0.689                      0.072
# ...                         ...                        ...
# 106724                    3.047                      0.097
# 106751                    3.123                      0.111
# 106778                    3.713                      0.097
# 106805                   49.214                      5.071
# 106821                    2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                             0.098    5  2004
# 50                             0.087    5  2004
# 77                             0.103    5  2004
# 104                            0.112    5  2004
# 131                            0.104    6  2004
# ...                              ...  ...   ...
# 106724                         0.032    6  2019
# 106751                         0.036    6  2019
# 106778                         0.026    6  2019
# 106805                         0.103    6  2019
# 106821                          0.07    6  2019
#
# [4263 rows x 20 columns]

# %%
postos_SP.reset_index()
# Out:
#        index DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0         23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1         50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2         77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3        104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4        131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...      ...          ...         ...      ...        ...               ...
# 4258  106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259  106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260  106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261  106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262  106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  MARGEM MÉDIA REVENDA  \
# 0                     0.085  ...                 1.150                 0.198
# 1                     0.083  ...                 1.150                  0.19
# 2                     0.071  ...                 1.199                 0.209
# 3                     0.075  ...                 1.359                 0.216
# 4                     0.071  ...                 1.199                 0.205
# ...                     ...  ...                   ...                   ...
# 4258                  0.156  ...                 4.220                 0.401
# 4259                  0.169  ...                 4.320                 0.451
# 4260                  0.183  ...                 4.999                 0.429
# 4261                  6.100  ...                89.900                17.679
# 4262                  0.229  ...                 3.490                 0.646
#
#      COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                       0.111                      0.57
# 1                       0.108                     0.576
# 2                       0.086                     0.614
# 3                       0.085                     0.671
# 4                       0.079                     0.689
# ...                       ...                       ...
# 4258                    0.045                     3.047
# 4259                    0.047                     3.123
# 4260                    0.044                     3.713
# 4261                    0.091                    49.214
# 4262                    0.076                     2.374
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.056                    0.4271
# 1                          0.05                   0.43204
# 2                         0.063                   0.34951
# 3                         0.075                    0.3398
# 4                         0.072                   0.47797
# ...                         ...                       ...
# 4258                      0.097                    2.8599
# 4259                      0.111                     2.885
# 4260                      0.097                      3.52
# 4261                      5.071                     40.19
# 4262                      0.165                    2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO
# 0                       1.4123                         0.098   5  2004
# 1                       0.9724                         0.087   5  2004
# 2                        1.412                         0.103   5  2004
# 3                       1.0669                         0.112   5  2004
# 4                       1.0669                         0.104   6  2004
# ...                        ...                           ...  ..   ...
# 4258                    3.3481                         0.032   6  2019
# 4259                     3.491                         0.036   6  2019
# 4260                    4.0892                         0.026   6  2019
# 4261                        72                         0.103   6  2019
# 4262                    2.5093                          0.07   6  2019
#
# [4263 rows x 21 columns]

# %%
postos_SP.reset_index(drop=True)
#Se não for relevante a coluna 'index' criada automaticamente
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                     0.085                 0.590                 1.150
# 1                     0.083                 0.590                 1.150
# 2                     0.071                 0.620                 1.199
# 3                     0.075                 0.639                 1.359
# 4                     0.071                 0.669                 1.199
# ...                     ...                   ...                   ...
# 4258                  0.156                 3.099                 4.220
# 4259                  0.169                 3.199                 4.320
# 4260                  0.183                 3.769                 4.999
# 4261                  6.100                50.000                89.900
# 4262                  0.229                 2.699                 3.490
#
#      MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                   0.198                     0.111                     0.57
# 1                    0.19                     0.108                    0.576
# 2                   0.209                     0.086                    0.614
# 3                   0.216                     0.085                    0.671
# 4                   0.205                     0.079                    0.689
# ...                   ...                       ...                      ...
# 4258                0.401                     0.045                    3.047
# 4259                0.451                     0.047                    3.123
# 4260                0.429                     0.044                    3.713
# 4261               17.679                     0.091                   49.214
# 4262                0.646                     0.076                    2.374
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.056                    0.4271
# 1                          0.05                   0.43204
# 2                         0.063                   0.34951
# 3                         0.075                    0.3398
# 4                         0.072                   0.47797
# ...                         ...                       ...
# 4258                      0.097                    2.8599
# 4259                      0.111                     2.885
# 4260                      0.097                      3.52
# 4261                      5.071                     40.19
# 4262                      0.165                    2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                       1.4123                         0.098    5  2004
# 1                       0.9724                         0.087    5  2004
# 2                        1.412                         0.103    5  2004
# 3                       1.0669                         0.112    5  2004
# 4                       1.0669                         0.104    6  2004
# ...                        ...                           ...  ...   ...
# 4258                    3.3481                         0.032    6  2019
# 4259                     3.491                         0.036    6  2019
# 4260                    4.0892                         0.026    6  2019
# 4261                        72                         0.103    6  2019
# 4262                    2.5093                          0.07    6  2019
#
# [4263 rows x 20 columns]

# %%
postos_SP
#Ainda não foi alterado, para alterá-lo é preciso usar o  atributo inplace=True
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 23                              4047              R$/l                0.768
# 50                              4066              R$/l                0.766
# 77                              4077              R$/l                0.823
# 104                             4073              R$/l                0.887
# 131                             4082              R$/l                0.894
# ...                              ...               ...                  ...
# 106724                           863              R$/l                3.448
# 106751                          1277              R$/l                3.574
# 106778                          1644              R$/l                4.142
# 106805                          1017           R$/13Kg               66.893
# 106821                            52             R$/m3                3.020
#
#         DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 23                      0.085                 0.590                 1.150
# 50                      0.083                 0.590                 1.150
# 77                      0.071                 0.620                 1.199
# 104                     0.075                 0.639                 1.359
# 131                     0.071                 0.669                 1.199
# ...                       ...                   ...                   ...
# 106724                  0.156                 3.099                 4.220
# 106751                  0.169                 3.199                 4.320
# 106778                  0.183                 3.769                 4.999
# 106805                  6.100                50.000                89.900
# 106821                  0.229                 2.699                 3.490
#
#        MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA  \
# 23                    0.198                     0.111
# 50                     0.19                     0.108
# 77                    0.209                     0.086
# 104                   0.216                     0.085
# 131                   0.205                     0.079
# ...                     ...                       ...
# 106724                0.401                     0.045
# 106751                0.451                     0.047
# 106778                0.429                     0.044
# 106805               17.679                     0.091
# 106821                0.646                     0.076
#
#        PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 23                         0.57                      0.056
# 50                        0.576                       0.05
# 77                        0.614                      0.063
# 104                       0.671                      0.075
# 131                       0.689                      0.072
# ...                         ...                        ...
# 106724                    3.047                      0.097
# 106751                    3.123                      0.111
# 106778                    3.713                      0.097
# 106805                   49.214                      5.071
# 106821                    2.374                      0.165
#
#        PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 23                        0.4271                    1.4123
# 50                       0.43204                    0.9724
# 77                       0.34951                     1.412
# 104                       0.3398                    1.0669
# 131                      0.47797                    1.0669
# ...                          ...                       ...
# 106724                    2.8599                    3.3481
# 106751                     2.885                     3.491
# 106778                      3.52                    4.0892
# 106805                     40.19                        72
# 106821                    2.0179                    2.5093
#
#        COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 23                             0.098    5  2004
# 50                             0.087    5  2004
# 77                             0.103    5  2004
# 104                            0.112    5  2004
# 131                            0.104    6  2004
# ...                              ...  ...   ...
# 106724                         0.032    6  2019
# 106751                         0.036    6  2019
# 106778                         0.026    6  2019
# 106805                         0.103    6  2019
# 106821                          0.07    6  2019
#
# [4263 rows x 20 columns]

# %%
postos_SP.reset_index(drop=True, inplace=True)

# %%
postos_SP
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# 1                             4066              R$/l                0.766
# 2                             4077              R$/l                0.823
# 3                             4073              R$/l                0.887
# 4                             4082              R$/l                0.894
# ...                            ...               ...                  ...
# 4258                           863              R$/l                3.448
# 4259                          1277              R$/l                3.574
# 4260                          1644              R$/l                4.142
# 4261                          1017           R$/13Kg               66.893
# 4262                            52             R$/m3                3.020
#
#       DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# 0                     0.085                 0.590                 1.150
# 1                     0.083                 0.590                 1.150
# 2                     0.071                 0.620                 1.199
# 3                     0.075                 0.639                 1.359
# 4                     0.071                 0.669                 1.199
# ...                     ...                   ...                   ...
# 4258                  0.156                 3.099                 4.220
# 4259                  0.169                 3.199                 4.320
# 4260                  0.183                 3.769                 4.999
# 4261                  6.100                50.000                89.900
# 4262                  0.229                 2.699                 3.490
#
#      MARGEM MÉDIA REVENDA  COEF DE VARIAÇÃO REVENDA PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                   0.198                     0.111                     0.57
# 1                    0.19                     0.108                    0.576
# 2                   0.209                     0.086                    0.614
# 3                   0.216                     0.085                    0.671
# 4                   0.205                     0.079                    0.689
# ...                   ...                       ...                      ...
# 4258                0.401                     0.045                    3.047
# 4259                0.451                     0.047                    3.123
# 4260                0.429                     0.044                    3.713
# 4261               17.679                     0.091                   49.214
# 4262                0.646                     0.076                    2.374
#
#      DESVIO PADRÃO DISTRIBUIÇÃO PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.056                    0.4271
# 1                          0.05                   0.43204
# 2                         0.063                   0.34951
# 3                         0.075                    0.3398
# 4                         0.072                   0.47797
# ...                         ...                       ...
# 4258                      0.097                    2.8599
# 4259                      0.111                     2.885
# 4260                      0.097                      3.52
# 4261                      5.071                     40.19
# 4262                      0.165                    2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO  MÊS   ANO
# 0                       1.4123                         0.098    5  2004
# 1                       0.9724                         0.087    5  2004
# 2                        1.412                         0.103    5  2004
# 3                       1.0669                         0.112    5  2004
# 4                       1.0669                         0.104    6  2004
# ...                        ...                           ...  ...   ...
# 4258                    3.3481                         0.032    6  2019
# 4259                     3.491                         0.036    6  2019
# 4260                    4.0892                         0.026    6  2019
# 4261                        72                         0.103    6  2019
# 4262                    2.5093                          0.07    6  2019
#
# [4263 rows x 20 columns]

# %% [markdown]
# ### Alternativa 2 (comum)

# %%
postos_SP = data.query('ESTADO=="SAO PAULO"').reset_index(drop=True)

# %%
postos_SP  ##HELP##
# Out:
#       Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 0             23   2004-05-09  2004-05-15  SUDESTE  SAO PAULO
# 1             50   2004-05-16  2004-05-22  SUDESTE  SAO PAULO
# 2             77   2004-05-23  2004-05-29  SUDESTE  SAO PAULO
# 3            104   2004-05-30  2004-06-05  SUDESTE  SAO PAULO
# 4            131   2004-06-06  2004-06-12  SUDESTE  SAO PAULO
# ...          ...          ...         ...      ...        ...
# 4258      106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4259      106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4260      106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4261      106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
# 4262      106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0     ETANOL HIDRATADO                          4047              R$/l
# 1     ETANOL HIDRATADO                          4066              R$/l
# 2     ETANOL HIDRATADO                          4077              R$/l
# 3     ETANOL HIDRATADO                          4073              R$/l
# 4     ETANOL HIDRATADO                          4082              R$/l
# ...                ...                           ...               ...
# 4258       ÓLEO DIESEL                           863              R$/l
# 4259   ÓLEO DIESEL S10                          1277              R$/l
# 4260    GASOLINA COMUM                          1644              R$/l
# 4261               GLP                          1017           R$/13Kg
# 4262               GNV                            52             R$/m3
#
#       PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 0                   0.768                  0.085  ...
# 1                   0.766                  0.083  ...
# 2                   0.823                  0.071  ...
# 3                   0.887                  0.075  ...
# 4                   0.894                  0.071  ...
# ...                   ...                    ...  ...
# 4258                3.448                  0.156  ...
# 4259                3.574                  0.169  ...
# 4260                4.142                  0.183  ...
# 4261               66.893                  6.100  ...
# 4262                3.020                  0.229  ...
#
#       COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 0                        0.111                      0.57
# 1                        0.108                     0.576
# 2                        0.086                     0.614
# 3                        0.085                     0.671
# 4                        0.079                     0.689
# ...                        ...                       ...
# 4258                     0.045                     3.047
# 4259                     0.047                     3.123
# 4260                     0.044                     3.713
# 4261                     0.091                    49.214
# 4262                     0.076                     2.374
#
#      DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 0                         0.056                     0.4271
# 1                          0.05                    0.43204
# 2                         0.063                    0.34951
# 3                         0.075                     0.3398
# 4                         0.072                    0.47797
# ...                         ...                        ...
# 4258                      0.097                     2.8599
# 4259                      0.111                      2.885
# 4260                      0.097                       3.52
# 4261                      5.071                      40.19
# 4262                      0.165                     2.0179
#
#      PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 0                       1.4123                         0.098   5  2004
# 1                       0.9724                         0.087   5  2004
# 2                        1.412                         0.103   5  2004
# 3                       1.0669                         0.112   5  2004
# 4                       1.0669                         0.104   6  2004
# ...                        ...                           ...  ..   ...
# 4258                    3.3481                         0.032   6  2019
# 4259                     3.491                         0.036   6  2019
# 4260                    4.0892                         0.026   6  2019
# 4261                        72                         0.103   6  2019
# 4262                    2.5093                          0.07   6  2019
#
#               Coluna  coluna a partir de lista
# 0     COLUNA_EXEMPLO                        23
# 1     COLUNA_EXEMPLO                        50
# 2     COLUNA_EXEMPLO                        77
# 3     COLUNA_EXEMPLO                       104
# 4     COLUNA_EXEMPLO                       131
# ...              ...                       ...
# 4258  COLUNA_EXEMPLO                    106724
# 4259  COLUNA_EXEMPLO                    106751
# 4260  COLUNA_EXEMPLO                    106778
# 4261  COLUNA_EXEMPLO                    106805
# 4262  COLUNA_EXEMPLO                    106821
#
# [4263 rows x 23 columns]

# %% [markdown]
# #### **Selecionando registros de postos do Rio de Janeiro com Preços acima de 2 reais**

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO          Coluna  \
# 0                         0.133   5  2004  COLUNA_EXEMPLO
# 1                         0.115   5  2004  COLUNA_EXEMPLO
# 2                         0.098   5  2004  COLUNA_EXEMPLO
# 3                         0.143   5  2004  COLUNA_EXEMPLO
# 4                         0.082   5  2004  COLUNA_EXEMPLO
#
#    coluna a partir de lista
# 0                         0
# 1                         1
# 2                         2
# 3                         3
# 4                         4
#
# [5 rows x 23 columns]

# %%
data['ESTADO']=='RIO DE JANEIRO'
#Registros do dataframe onde 'ESTADO' são iguais a RIO DE JANEIRO
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
data['PREÇO MÉDIO REVENDA']>=2.0
#Reqgistros do dataframe onde 'PREÇO MÉDIO DE REVENDA' é maior igual a 2.0
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818     True
# 106819     True
# 106820     True
# 106821     True
# 106822     True
# Name: PREÇO MÉDIO REVENDA, Length: 106823, dtype: bool

# %%
selecao=(data['ESTADO']=='RIO DE JANEIRO') & (data['PREÇO MÉDIO REVENDA']>=2.0)
#Mostra somente os Valores onde 'ESTADO' é Rio de Janeiro e 'PREÇO MÉDIO REVENDA' é >= 2.0

# %%
selecao
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %% [markdown]
# Note que o resultado da seleção continua sendo uma _Series de booleans_ com o _mesmo número de linhas/amostras do DataFrame_, de modo que cada linha possuirá um valor booleano indicando se o posto é do Rio de Janeiro e o preço aferido do combustível é maior que 2 reais (True) ou não.
#
# O símbolo **&** significa **AND** na comparação. Essa nomenclatura do python/pandas é diferente das nomenclaturas tradicionais (&&). <br/>
# Similarmente:
# - **|** representa o **OR** (não é ||)
# - **~** representa o **NOT** (não é !)

# %%
data[selecao]
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 2501          2501   2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO
# 2528          2528   2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO
# 2555          2555   2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO
# 2582          2582   2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO
# 2609          2609   2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 106718      106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106745      106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106772      106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106799      106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106817      106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 2501    ETANOL HIDRATADO                           881              R$/l
# 2528    ETANOL HIDRATADO                           889              R$/l
# 2555    ETANOL HIDRATADO                           902              R$/l
# 2582    ETANOL HIDRATADO                           898              R$/l
# 2609    ETANOL HIDRATADO                           890              R$/l
# ...                  ...                           ...               ...
# 106718       ÓLEO DIESEL                           212              R$/l
# 106745   ÓLEO DIESEL S10                           335              R$/l
# 106772    GASOLINA COMUM                           422              R$/l
# 106799               GLP                           221           R$/13Kg
# 106817               GNV                           124             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 2501                  2.028                  0.148  ...
# 2528                  2.125                  0.149  ...
# 2555                  2.163                  0.138  ...
# 2582                  2.166                  0.146  ...
# 2609                  2.172                  0.143  ...
# ...                     ...                    ...  ...
# 106718                3.569                  0.166  ...
# 106745                3.697                  0.187  ...
# 106772                4.928                  0.165  ...
# 106799               65.010                  5.812  ...
# 106817                3.111                  0.260  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 2501                       0.073                     1.806
# 2528                       0.070                     1.839
# 2555                       0.064                     1.895
# 2582                       0.067                     1.935
# 2609                       0.066                     1.963
# ...                          ...                       ...
# 106718                     0.047                     3.102
# 106745                     0.051                     3.197
# 106772                     0.033                      4.39
# 106799                     0.089                    47.535
# 106817                     0.084                     2.404
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 2501                         0.11                       1.31
# 2528                        0.117                      1.438
# 2555                        0.134                       1.43
# 2582                         0.14                      1.438
# 2609                        0.133                      1.438
# ...                           ...                        ...
# 106718                      0.119                      2.886
# 106745                      0.127                     2.9772
# 106772                      0.097                        4.2
# 106799                      3.934                         39
# 106817                      0.174                      2.126
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 2501                      2.1358                         0.061   2  2006
# 2528                      2.2801                         0.064   3  2006
# 2555                      2.3454                         0.071   3  2006
# 2582                      2.2925                         0.072   3  2006
# 2609                      2.2513                         0.068   3  2006
# ...                          ...                           ...  ..   ...
# 106718                    3.5162                         0.038   6  2019
# 106745                    3.5388                          0.04   6  2019
# 106772                     4.618                         0.022   6  2019
# 106799                      58.2                         0.083   6  2019
# 106817                    2.7909                         0.072   6  2019
#
#                 Coluna  coluna a partir de lista
# 2501    COLUNA_EXEMPLO                      2501
# 2528    COLUNA_EXEMPLO                      2528
# 2555    COLUNA_EXEMPLO                      2555
# 2582    COLUNA_EXEMPLO                      2582
# 2609    COLUNA_EXEMPLO                      2609
# ...                ...                       ...
# 106718  COLUNA_EXEMPLO                    106718
# 106745  COLUNA_EXEMPLO                    106745
# 106772  COLUNA_EXEMPLO                    106772
# 106799  COLUNA_EXEMPLO                    106799
# 106817  COLUNA_EXEMPLO                    106817
#
# [3061 rows x 23 columns]

# %% [markdown]
# Alternativamente, poderíamos usar o método `query` para fazermos tal seleção. Porém, isso não é possível especificamente para esse caso, pois o rótulo da coluna 'PREÇO MÉDIO REVENDA' possui caracteres inválidos para o método (cedilha, acentos)

# %%
# Não funciona
# data.query('ESTADO=="RIO DE JANEIRO" and PREÇO MÉDIO REVENDA > 2')

# %%
data.query('ESTADO=="RIO DE JANEIRO" or ESTADO=="SAO PAULO"')
#Se resgistro na coluna 'ESTADO' for RIO DE JANEIRO ou SAO PAULO retorna os valores
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 22              22   2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO
# 23              23   2004-05-09  2004-05-15  SUDESTE       SAO PAULO
# 49              49   2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO
# 50              50   2004-05-16  2004-05-22  SUDESTE       SAO PAULO
# 76              76   2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 106778      106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
# 106799      106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106805      106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
# 106817      106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106821      106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 22      ETANOL HIDRATADO                           952              R$/l
# 23      ETANOL HIDRATADO                          4047              R$/l
# 49      ETANOL HIDRATADO                           948              R$/l
# 50      ETANOL HIDRATADO                          4066              R$/l
# 76      ETANOL HIDRATADO                           973              R$/l
# ...                  ...                           ...               ...
# 106778    GASOLINA COMUM                          1644              R$/l
# 106799               GLP                           221           R$/13Kg
# 106805               GLP                          1017           R$/13Kg
# 106817               GNV                           124             R$/m3
# 106821               GNV                            52             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 22                    1.098                  0.154  ...
# 23                    0.768                  0.085  ...
# 49                    1.092                  0.157  ...
# 50                    0.766                  0.083  ...
# 76                    1.103                  0.140  ...
# ...                     ...                    ...  ...
# 106778                4.142                  0.183  ...
# 106799               65.010                  5.812  ...
# 106805               66.893                  6.100  ...
# 106817                3.111                  0.260  ...
# 106821                3.020                  0.229  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 22                         0.140                     0.786
# 23                         0.111                      0.57
# 49                         0.144                     0.808
# 50                         0.108                     0.576
# 76                         0.127                     0.822
# ...                          ...                       ...
# 106778                     0.044                     3.713
# 106799                     0.089                    47.535
# 106805                     0.091                    49.214
# 106817                     0.084                     2.404
# 106821                     0.076                     2.374
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 22                          0.173                      0.326
# 23                          0.056                     0.4271
# 49                          0.175                     0.3257
# 50                           0.05                    0.43204
# 76                          0.166                    0.38909
# ...                           ...                        ...
# 106778                      0.097                       3.52
# 106799                      3.934                         39
# 106805                      5.071                      40.19
# 106817                      0.174                      2.126
# 106821                      0.165                     2.0179
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 22                         1.263                          0.22   5  2004
# 23                        1.4123                         0.098   5  2004
# 49                        1.2921                         0.217   5  2004
# 50                        0.9724                         0.087   5  2004
# 76                        1.1859                         0.202   5  2004
# ...                          ...                           ...  ..   ...
# 106778                    4.0892                         0.026   6  2019
# 106799                      58.2                         0.083   6  2019
# 106805                        72                         0.103   6  2019
# 106817                    2.7909                         0.072   6  2019
# 106821                    2.5093                          0.07   6  2019
#
#                 Coluna  coluna a partir de lista
# 22      COLUNA_EXEMPLO                        22
# 23      COLUNA_EXEMPLO                        23
# 49      COLUNA_EXEMPLO                        49
# 50      COLUNA_EXEMPLO                        50
# 76      COLUNA_EXEMPLO                        76
# ...                ...                       ...
# 106778  COLUNA_EXEMPLO                    106778
# 106799  COLUNA_EXEMPLO                    106799
# 106805  COLUNA_EXEMPLO                    106805
# 106817  COLUNA_EXEMPLO                    106817
# 106821  COLUNA_EXEMPLO                    106821
#
# [8526 rows x 23 columns]

# %% [markdown]
# **Aprofundando mais ainda**
#
# A primeira comparação `(data['ESTADO'] == 'RIO DE JANEIRO')` checa, linha a linha (amostra a amostra) do DataFrame, quais são aquelas cujo o estado é RIO DE JANEIRO. Nenhuma averiguação de preços é feita nesse momento. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# A segunda comparação `(data['PREÇO MÉDIO REVENDA'] > 2)` checa, linha a linha (amostra a amostra) do DataFrame, quais são os registro cujo preço do combustível é maior que 2 reais. Note que essa comparação checará os postos de **TODOS os estados**. Como resultado, temos uma Series de booleans que responde **apenas** a essa "pergunta" feita.
#
# Por fim, as duas "perguntas" são unidas pelo AND (&) que retorna a "pergunta completa" que fizemos.

# %% [markdown]
# Alguns podem argumentar que tal abordagem é **ineficiente**, uma vez que, para cada condição ("pergunta"), estamos varrendo todas as linhas do DataFrame. <br/>
# O Pandas _tenta otimizar_ isso ao máximo por de trás dos panos. Mas, de fato, de tivermos um dataset **muito grande** (centenas de milhares de linhas), tal abordagem se tornará _lenta_.

# %% [markdown]
# Assim, poderíamos fazer filtragem com múltiplos condicionais em partes:

# %%
selecao_1=data['ESTADO']=='RIO DE JANEIRO'
postos_RJ=data[selecao_1]
postos_RJ
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 22              22   2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO
# 49              49   2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO
# 76              76   2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO
# 103            103   2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO
# 130            130   2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 106718      106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106745      106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106772      106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106799      106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106817      106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 22      ETANOL HIDRATADO                           952              R$/l
# 49      ETANOL HIDRATADO                           948              R$/l
# 76      ETANOL HIDRATADO                           973              R$/l
# 103     ETANOL HIDRATADO                           955              R$/l
# 130     ETANOL HIDRATADO                           966              R$/l
# ...                  ...                           ...               ...
# 106718       ÓLEO DIESEL                           212              R$/l
# 106745   ÓLEO DIESEL S10                           335              R$/l
# 106772    GASOLINA COMUM                           422              R$/l
# 106799               GLP                           221           R$/13Kg
# 106817               GNV                           124             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 22                    1.098                  0.154  ...
# 49                    1.092                  0.157  ...
# 76                    1.103                  0.140  ...
# 103                   1.149                  0.156  ...
# 130                   1.165                  0.154  ...
# ...                     ...                    ...  ...
# 106718                3.569                  0.166  ...
# 106745                3.697                  0.187  ...
# 106772                4.928                  0.165  ...
# 106799               65.010                  5.812  ...
# 106817                3.111                  0.260  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 22                         0.140                     0.786
# 49                         0.144                     0.808
# 76                         0.127                     0.822
# 103                        0.136                     0.849
# 130                        0.132                     0.911
# ...                          ...                       ...
# 106718                     0.047                     3.102
# 106745                     0.051                     3.197
# 106772                     0.033                      4.39
# 106799                     0.089                    47.535
# 106817                     0.084                     2.404
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 22                          0.173                      0.326
# 49                          0.175                     0.3257
# 76                          0.166                    0.38909
# 103                         0.188                     0.3453
# 130                         0.198                        0.4
# ...                           ...                        ...
# 106718                      0.119                      2.886
# 106745                      0.127                     2.9772
# 106772                      0.097                        4.2
# 106799                      3.934                         39
# 106817                      0.174                      2.126
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 22                         1.263                          0.22   5  2004
# 49                        1.2921                         0.217   5  2004
# 76                        1.1859                         0.202   5  2004
# 103                       1.3667                         0.221   5  2004
# 130                       1.3667                         0.217   6  2004
# ...                          ...                           ...  ..   ...
# 106718                    3.5162                         0.038   6  2019
# 106745                    3.5388                          0.04   6  2019
# 106772                     4.618                         0.022   6  2019
# 106799                      58.2                         0.083   6  2019
# 106817                    2.7909                         0.072   6  2019
#
#                 Coluna  coluna a partir de lista
# 22      COLUNA_EXEMPLO                        22
# 49      COLUNA_EXEMPLO                        49
# 76      COLUNA_EXEMPLO                        76
# 103     COLUNA_EXEMPLO                       103
# 130     COLUNA_EXEMPLO                       130
# ...                ...                       ...
# 106718  COLUNA_EXEMPLO                    106718
# 106745  COLUNA_EXEMPLO                    106745
# 106772  COLUNA_EXEMPLO                    106772
# 106799  COLUNA_EXEMPLO                    106799
# 106817  COLUNA_EXEMPLO                    106817
#
# [4263 rows x 23 columns]

# %%
selecao_2=postos_RJ['PREÇO MÉDIO REVENDA']>2.0
selecao_2
# Out:
# 22        False
# 49        False
# 76        False
# 103       False
# 130       False
#           ...
# 106718     True
# 106745     True
# 106772     True
# 106799     True
# 106817     True
# Name: PREÇO MÉDIO REVENDA, Length: 4263, dtype: bool

# %%
postosRJ_preco_Medio=postos_RJ[selecao_2]

# %%
postosRJ_preco_Medio
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 2501          2501   2006-02-26  2006-03-04  SUDESTE  RIO DE JANEIRO
# 2528          2528   2006-03-05  2006-03-11  SUDESTE  RIO DE JANEIRO
# 2555          2555   2006-03-12  2006-03-18  SUDESTE  RIO DE JANEIRO
# 2582          2582   2006-03-19  2006-03-25  SUDESTE  RIO DE JANEIRO
# 2609          2609   2006-03-26  2006-04-01  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 106718      106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106745      106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106772      106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106799      106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106817      106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 2501    ETANOL HIDRATADO                           881              R$/l
# 2528    ETANOL HIDRATADO                           889              R$/l
# 2555    ETANOL HIDRATADO                           902              R$/l
# 2582    ETANOL HIDRATADO                           898              R$/l
# 2609    ETANOL HIDRATADO                           890              R$/l
# ...                  ...                           ...               ...
# 106718       ÓLEO DIESEL                           212              R$/l
# 106745   ÓLEO DIESEL S10                           335              R$/l
# 106772    GASOLINA COMUM                           422              R$/l
# 106799               GLP                           221           R$/13Kg
# 106817               GNV                           124             R$/m3
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 2501                  2.028                  0.148  ...
# 2528                  2.125                  0.149  ...
# 2555                  2.163                  0.138  ...
# 2582                  2.166                  0.146  ...
# 2609                  2.172                  0.143  ...
# ...                     ...                    ...  ...
# 106718                3.569                  0.166  ...
# 106745                3.697                  0.187  ...
# 106772                4.928                  0.165  ...
# 106799               65.010                  5.812  ...
# 106817                3.111                  0.260  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 2501                       0.073                     1.806
# 2528                       0.070                     1.839
# 2555                       0.064                     1.895
# 2582                       0.067                     1.935
# 2609                       0.066                     1.963
# ...                          ...                       ...
# 106718                     0.047                     3.102
# 106745                     0.051                     3.197
# 106772                     0.033                      4.39
# 106799                     0.089                    47.535
# 106817                     0.084                     2.404
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 2501                         0.11                       1.31
# 2528                        0.117                      1.438
# 2555                        0.134                       1.43
# 2582                         0.14                      1.438
# 2609                        0.133                      1.438
# ...                           ...                        ...
# 106718                      0.119                      2.886
# 106745                      0.127                     2.9772
# 106772                      0.097                        4.2
# 106799                      3.934                         39
# 106817                      0.174                      2.126
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 2501                      2.1358                         0.061   2  2006
# 2528                      2.2801                         0.064   3  2006
# 2555                      2.3454                         0.071   3  2006
# 2582                      2.2925                         0.072   3  2006
# 2609                      2.2513                         0.068   3  2006
# ...                          ...                           ...  ..   ...
# 106718                    3.5162                         0.038   6  2019
# 106745                    3.5388                          0.04   6  2019
# 106772                     4.618                         0.022   6  2019
# 106799                      58.2                         0.083   6  2019
# 106817                    2.7909                         0.072   6  2019
#
#                 Coluna  coluna a partir de lista
# 2501    COLUNA_EXEMPLO                      2501
# 2528    COLUNA_EXEMPLO                      2528
# 2555    COLUNA_EXEMPLO                      2555
# 2582    COLUNA_EXEMPLO                      2582
# 2609    COLUNA_EXEMPLO                      2609
# ...                ...                       ...
# 106718  COLUNA_EXEMPLO                    106718
# 106745  COLUNA_EXEMPLO                    106745
# 106772  COLUNA_EXEMPLO                    106772
# 106799  COLUNA_EXEMPLO                    106799
# 106817  COLUNA_EXEMPLO                    106817
#
# [3054 rows x 23 columns]

# %% [markdown]
# #### **Selecionando registros de postos de São Paulo ou do Rio de Janeiro com Gasolina Comum acima de 2 reais**

# %% [markdown]
# Podemos fazer a solução do "jeito mais lento", percorrendo o DataFrame inteiro _múltiplas vezes_:

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 0                1.288                  0.016  ...                     0.012
# 1                1.162                  0.114  ...                     0.098
# 2                1.389                  0.097  ...                     0.070
# 3                1.262                  0.070  ...                     0.055
# 4                1.181                  0.078  ...                     0.066
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 0                     0.825                       0.11
# 1                     0.763                      0.088
# 2                      0.97                      0.095
# 3                      0.83                      0.119
# 4                     0.941                      0.077
#
#    PREÇO MÍNIMO DISTRIBUIÇÃO PREÇO MÁXIMO DISTRIBUIÇÃO  \
# 0                     0.4201                    0.9666
# 1                     0.5013                      1.05
# 2                     0.5614                     1.161
# 3                     0.5991                   1.22242
# 4                     0.7441                    1.0317
#
#   COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO          Coluna  \
# 0                         0.133   5  2004  COLUNA_EXEMPLO
# 1                         0.115   5  2004  COLUNA_EXEMPLO
# 2                         0.098   5  2004  COLUNA_EXEMPLO
# 3                         0.143   5  2004  COLUNA_EXEMPLO
# 4                         0.082   5  2004  COLUNA_EXEMPLO
#
#    coluna a partir de lista
# 0                         0
# 1                         1
# 2                         2
# 3                         3
# 4                         4
#
# [5 rows x 23 columns]

# %%
selecao1=(data['ESTADO']=='SAO PAULO') | (data['ESTADO']=='RIO DE JANEIRO')
#faz a busca na coluna 'ESTADO' procurando 'SAO PAULO' e 'RIO DE JANEIRO'

selecao2=data['PRODUTO']=='GASOLINA COMUM'

selecao3=data['PREÇO MÉDIO REVENDA']>2

selecao_final=selecao1 & selecao2 & selecao3

# %%
selecao_final
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821    False
# 106822    False
# Length: 106823, dtype: bool

# %%
data[selecao_final]
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO          ESTADO  \
# 12086        12086   2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO
# 12113        12113   2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO
# 12140        12140   2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO
# 12167        12167   2004-05-30  2004-06-05  SUDESTE  RIO DE JANEIRO
# 12194        12194   2004-06-06  2004-06-12  SUDESTE  RIO DE JANEIRO
# ...            ...          ...         ...      ...             ...
# 106479      106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO
# 106623      106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO
# 106629      106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO
# 106772      106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO
# 106778      106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO
#
#                PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 12086   GASOLINA COMUM                          1071              R$/l
# 12113   GASOLINA COMUM                          1055              R$/l
# 12140   GASOLINA COMUM                          1091              R$/l
# 12167   GASOLINA COMUM                          1055              R$/l
# 12194   GASOLINA COMUM                          1091              R$/l
# ...                ...                           ...               ...
# 106479  GASOLINA COMUM                          1643              R$/l
# 106623  GASOLINA COMUM                           418              R$/l
# 106629  GASOLINA COMUM                          1635              R$/l
# 106772  GASOLINA COMUM                           422              R$/l
# 106778  GASOLINA COMUM                          1644              R$/l
#
#         PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  \
# 12086                 2.045                  0.109  ...
# 12113                 2.040                  0.113  ...
# 12140                 2.042                  0.108  ...
# 12167                 2.053                  0.111  ...
# 12194                 2.063                  0.107  ...
# ...                     ...                    ...  ...
# 106479                4.210                  0.177  ...
# 106623                4.927                  0.160  ...
# 106629                4.168                  0.177  ...
# 106772                4.928                  0.165  ...
# 106778                4.142                  0.183  ...
#
#         COEF DE VARIAÇÃO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO  \
# 12086                      0.053                     1.791
# 12113                      0.055                     1.788
# 12140                      0.053                      1.79
# 12167                      0.054                     1.802
# 12194                      0.052                     1.816
# ...                          ...                       ...
# 106479                     0.042                     3.785
# 106623                     0.032                     4.383
# 106629                     0.042                     3.725
# 106772                     0.033                      4.39
# 106778                     0.044                     3.713
#
#        DESVIO PADRÃO DISTRIBUIÇÃO  PREÇO MÍNIMO DISTRIBUIÇÃO  \
# 12086                       0.047                     1.6363
# 12113                       0.049                     1.5943
# 12140                       0.046                    1.63596
# 12167                       0.055                       1.64
# 12194                       0.054                       1.64
# ...                           ...                        ...
# 106479                      0.096                       3.52
# 106623                        0.1                     4.1972
# 106629                      0.096                      3.502
# 106772                      0.097                        4.2
# 106778                      0.097                       3.52
#
#        PREÇO MÁXIMO DISTRIBUIÇÃO COEF DE VARIAÇÃO DISTRIBUIÇÃO MÊS   ANO  \
# 12086                     1.9594                         0.026   5  2004
# 12113                    1.99651                         0.027   5  2004
# 12140                     2.2137                         0.026   5  2004
# 12167                    2.21425                         0.031   5  2004
# 12194                    2.32425                          0.03   6  2004
# ...                          ...                           ...  ..   ...
# 106479                    4.1007                         0.025   6  2019
# 106623                    4.6239                         0.023   6  2019
# 106629                    4.0892                         0.026   6  2019
# 106772                     4.618                         0.022   6  2019
# 106778                    4.0892                         0.026   6  2019
#
#                 Coluna  coluna a partir de lista
# 12086   COLUNA_EXEMPLO                     12086
# 12113   COLUNA_EXEMPLO                     12113
# 12140   COLUNA_EXEMPLO                     12140
# 12167   COLUNA_EXEMPLO                     12167
# 12194   COLUNA_EXEMPLO                     12194
# ...                ...                       ...
# 106479  COLUNA_EXEMPLO                    106479
# 106623  COLUNA_EXEMPLO                    106623
# 106629  COLUNA_EXEMPLO                    106629
# 106772  COLUNA_EXEMPLO                    106772
# 106778  COLUNA_EXEMPLO                    106778
#
# [1564 rows x 23 columns]

# %% [markdown]
# <br/>
#
# Alternativamente:

# %% [markdown]
# #### **Selecionando registros dos anos de 2008, 2010 e 2012**

# %% [markdown]
# **ALTERNATIVA 1**

# %% [markdown]
# **ALTERNATIVA 2**

# %% [markdown]
# ### **Iterando com DataFrames**

# %% [markdown]
# #### For-each `DataFrame.iterrows()` (LENTO ==> apenas indicado para iterar pequenos conjunto de dados)

# %% [markdown]
# <h2>2. Preparação dos dados</h2>
# <hr/>

# %% [markdown]
# ### 2.1 Removendo amostras com valores vazios (null / nan) no dataset

# %% [markdown]
# De um total de 106823 observações, **não há valores null** / nan para nenhum atributo. Mas, veremos que não é bem assim neste caso específico.<br/><br/>

# %% [markdown]
# ### 2.2 Conversão de tipos de atributos

# %% [markdown]
# O pandas automaticamente reconhece os tipos de dados de cada coluna. <br/>
# Porém, existem alguns atributos que estão com seus tipos errados: P. ex., "PREÇO MÉDIO DISTRIBUIÇÃO" deveria ser ```float64``` e não ```object```.<br/>
# Nestes casos, muito provavelmente algumas amostras têm um string ao invés de um número para tais atributos. <br/>
#
# Os atributos *"DATA INICIAL"* e *"DATA FINAL"* deveriam ser do tipo `datetime`.
#
# Em outros casos, alguns **atributos categóricos** são ```objects```, mas poderiam ter o tipo ```category```, que é um tipo especial do pandas. <br/>
# Este tipo é necessário para se utilizar algumas funções específicas do pandas. <br/>
# **Não** converteremos para este tipo por ora.

# %% [markdown]
# #### **Datas**
# Como os atributos de data do datset já estão em um formato de data aceitável (YYYY-MM-DD), não precisamos forçar nenhuma conversão nesse sentido.

# %% [markdown]
# #### **Dados Numéricos**

# %% [markdown]
# <br/>
#
# Note que temos vários valores ***null*** agora **após a *conversão de tipos***. Vamos checá-los com mais cuidado nos dados originais e preprocessados.

# %% [markdown]
# ### 2.3 Limpeza de dados

# %% [markdown]
# Várias amostras possuem a _string '-'_ em algumas colunas ao invés de um número de fato. Ou seja, não há aferições destes atributos para estas amostras. <br/>
#
# <br/>
#
# Poderíamos **preencher os valores NaN com um valor padrão**. Para isso, basta usar o método `.fillna`.

# %% [markdown]
# <br/>
#
# Por mais que a função `fillna` seja interessante e útil em muitos casos, no problema em questão estamos interessados em analisar precisamente, p. ex., o **'PREÇO MÉDIO DISTRIBUIÇÃO'**.<br/>
# A fim de não termos valores _sintéticos_ gerados pelo `fillna`, que possam atrapalhar nossa análise, iremos **remover (drop) todas as amostras que possuem qualquer valor NaN** para quaisquer atributos/colunas. <br/>
#
# Para isso, basta utilizarmos o método `dropna`.

# %% [markdown]
# Nosso data frame agora, após essa _limpeza_, ficou mais enxuto, contentdo 103392 registros frente aos 106823 registros originais. <br/>
#
# Essas são apenas algumas das possíveis _técnicas de limpeza de dados_. Outras estratégias, p. ex., **confiam na detecção de outliers**, que não veremos neste curso.

# %% [markdown]
# #### **Salvando o Dataset Preprocessado**

# %% [markdown]
# <h2>3. Estatísticas Descritivas</h2>
# <hr/>

# %% [markdown]
# O Pandas fornecem algumas funções/métodos ue computam certas estatísticas descritivas.

# %% [markdown]
# `describe`: exibe várias **estatísticas descritivas** para os _atributos_ de um dataframe ou para uma _Series_.

# %% [markdown]
# <br/>
#
# Como o resultado do `describe` de um _dataframe_ é outro _dataframe_, podemos filtrar apenas algumas colunas.

# %% [markdown]
# **Acessando apenas algumas estatísticas**

# %% [markdown]
# <br/>
#
# `mean`, `std`, `min`, etc: cada uma das estatísticas do `describe` podem ser computadas individualmente:

# %% [markdown]
# #### Qual é o menor preço mínimo de revenda?

# %% [markdown]
# #### Qual é a média e desvio padrão dos preços mínimos de revenda?

# %% [markdown]
# #### Quais são os estados considerados?

# %% [markdown]
# #### Quantos registros (aferições) cada estado possui?

# %% [markdown]
# `.value_counts()`:  Conta a frequência dos valores de uma dada variável (de preferência, _categórica_).

# %% [markdown]
# <h2>4. Executando funções para cada item de um DataFrame ou Series</h2>
# <hr/>

# %% [markdown]
# Uma alternativa ao `for-loop` que vimos anteriormente e que é _lento_, é usarmos _funções próprias do pandas_ que **aplicam/mapeiam uma dada função a todos os elementos de um DataFrame ou Series**, retornando novos elementos "transformados".

# %% [markdown]
# <img src='./imagens/apply_map_applymap.png' width=300/>
#
#
# Fonte: https://towardsdatascience.com/introduction-to-pandas-apply-applymap-and-map-5d3e044e93ff

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df

# %% [markdown]
# `apply()`: usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %% [markdown]
# <img src='./imagens/pandas_axis.jpg' width=500/>
#
# Fonte: https://www.allthesnippets.com/browse/pandas/df_axis.html

# %% [markdown]
# <img src='./imagens/apply_axis_1.png' width=250/>

# %% [markdown]
# <img src='./imagens/apply_axis_0.png' width=250/>

# %% [markdown]
# ##### Usando `lambda` functions

# %% [markdown]
# <img src='./imagens/apply_axis_1_mean.png' width=350/>

# %% [markdown]
# <br/>
#
# `applymap()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de um DataFrame.

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df

# %% [markdown]
# <br/>
#
# `map()`: usado para aplicar uma função para **cada elemento** (_element-wise_) de uma _Series_.

# %% [markdown]
# <h2>5. Agrupamento</h2>
# <hr/>

# %% [markdown]
# `groupby`: Usado para criar **grupo de elementos** (e.x., baseado nos valores de um atributo). <br/>
# **Funções** podem então ser aplicadas para os _elementos de cada grupo_, de modo que os **resultados de cada grupo são combinados**.

# %% [markdown]
# <br/>
#
# Também podemos ter agrupamentos por mais de um atributo.

# %% [markdown]
# <br/>
#
# `.agg`: **agrega (roda)** uma série de funções para os elementos de um dataframe ou de grupos de um dataframe.

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [np.nan, np.nan, np.nan]],
                  columns=['A', 'B', 'C'])
df

# %% [markdown]
# <h2>6. Ordenação</h2>
# <hr/>

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas

# %% [markdown]
# `.sort_values()`: ordena valores ao longo de um eixo.

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em **ordem crescente (ascendente)**. Podemos alterar isso pelo argumento `ascending`.

# %% [markdown]
# <br/>
#
# Podemos ordenar a partir de **mais de uma coluna**:

# %% [markdown]
# Ordena os registros, primeiramente, pela coluna 'nota_final' em **ordem descrente**. <br/>
# Então, reordena os registros _"empatados"_, ou seja, com a **mesma nota final**, em _ordem alfabética_ (ordem crescente).

# %% [markdown]
# <br/>
#
# Note que o dataframe original **não foi alterado** após a ordenação.

# %% [markdown]
# Para alterá-lo, use o argumento `inplace=True`:

# %% [markdown]
# <h2>7. Exercícios</h2>
# <hr/>

# %% [markdown]
# Vamos aplicar os conceitos que vimos em alguns exercícios. <br/>
# Para isso, utilizaremos o dataset de _preços de combustíveis no Brasil_.
#
# Como há apenas medições de janeiro a junho para o ano de 2019, resolvemos **remover os dados** deste ano da análise.

# %% [markdown]
# Note que temos um novo dataframe com 99739 linhas, mas com índices fora desse intervalo. <br/>
# Acontece que os registros mantiveram seus índices originais após a query. <br/>
#
# Para resetar os índices de _0 a num_linhas-1_, basta usarmos o método `.reset_index()`.

# %% [markdown]
# Os índices agora foram **resetados**. Porém, os índices antigos se transformaram em _uma nova coluna_ chamada 'index'. <br/>
# Para removê-la durante o _reset_, basta passarmos o argumento `drop=True`.

# %% [markdown]
# ### 7.1 Qual a proporção de postos pesquisados para cada combustível em cada região

# %% [markdown]
# ### 7.2 Como os preços da Gasolina Comum em São Paulo variaram em 2018?

# %% [markdown]
# #### **Estatísticas Descritivas**

# %% [markdown]
# ### 7.3 Como os preços da Gasolina Comum e do Etanol em São Paulo variaram em 2018?

# %% [markdown]
# <h2>8. Assuntos para continuar os estudos</h2>
# <hr/>
#
# - join
# - concat
# - plot
# - data cleaning
