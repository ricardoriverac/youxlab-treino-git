# %%
import pandas as pd
livros = pd.read_csv (r'/home/youx/youxlab-treino-git/youxlab-treino-git/dados/extra/livros.csv', sep=',')
estoque = pd.read_csv (r'/home/youx/youxlab-treino-git/youxlab-treino-git/dados/extra/livros.csv', sep=',')
livros
# Out:
#             Nome do Livro                      Autor                Editora  \
# 0     Cem Anos de Solidão     Gabriel García Márquez                 Record
# 1            Dom Casmurro           Machado de Assis                  Ática
# 2  A Revolução dos Bichos              George Orwell   Companhia das Letras
# 3             Metamorfose                Franz Kafka              Principis
# 4   A morte de Ivan Ilich               Liev Tolstói              Principis
# 5      O pequeno principe   Antonie de Saint-Exupéry             HarperKids
#
#    Data de Lançamento           ISBN
# 0          1967-05-30  9788535914849
# 1          1899-01-01  9788508108512
# 2          1945-08-17  9788535914840
# 3          2019-11-27    85943118782
# 4          2023-06-20     655552894X
# 5          2023-08-15     6584956247

# %%
estoque
# Out:
#             Nome do Livro                      Autor                Editora  \
# 0     Cem Anos de Solidão     Gabriel García Márquez                 Record
# 1            Dom Casmurro           Machado de Assis                  Ática
# 2  A Revolução dos Bichos              George Orwell   Companhia das Letras
# 3             Metamorfose                Franz Kafka              Principis
# 4   A morte de Ivan Ilich               Liev Tolstói              Principis
# 5      O pequeno principe   Antonie de Saint-Exupéry             HarperKids
#
#    Data de Lançamento           ISBN
# 0          1967-05-30  9788535914849
# 1          1899-01-01  9788508108512
# 2          1945-08-17  9788535914840
# 3          2019-11-27    85943118782
# 4          2023-06-20     655552894X
# 5          2023-08-15     6584956247

# %%
estoque['ISBN'] = estoque['ISBN'].astype(str)
livros['ISBN'] = livros['ISBN'].astype(str)

merge = pd.merge(estoque, livros, on='ISBN')
merge.head(5)
# Out:
#           Nome do Livro_x                  Autor_x              Editora_x  \
# 0     Cem Anos de Solidão   Gabriel García Márquez                 Record
# 1            Dom Casmurro         Machado de Assis                  Ática
# 2  A Revolução dos Bichos            George Orwell   Companhia das Letras
# 3             Metamorfose              Franz Kafka              Principis
# 4   A morte de Ivan Ilich             Liev Tolstói              Principis
#
#    Data de Lançamento_x           ISBN         Nome do Livro_y  \
# 0            1967-05-30  9788535914849     Cem Anos de Solidão
# 1            1899-01-01  9788508108512            Dom Casmurro
# 2            1945-08-17  9788535914840  A Revolução dos Bichos
# 3            2019-11-27    85943118782             Metamorfose
# 4            2023-06-20     655552894X   A morte de Ivan Ilich
#
#                    Autor_y              Editora_y  Data de Lançamento_y
# ...

# %%
estoque.to_csv('relatorio_estoque.csv', index=False)
