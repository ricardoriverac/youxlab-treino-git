# %% [markdown]
# # Importando pandas

# %%
import pandas as pd

# %%
#carregando data sets corretamente usando o separado usando ";"
data = pd.read_csv('/home/youx/workspace-git/youxlab-treino-git/curso_dados/data.sets/ipynb.xave/GasPricesinBrazil_2004-2019.csv', sep=';') 
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
# carregando a data sets com apenas 7 linhas 
data.head(7)
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
# 6           6   2004-05-09  2004-05-15      NORDESTE               CEARA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   Unnamed: 0                     106823 non-null  int64
#  1   DATA INICIAL                   106823 non-null  object
#  2   DATA FINAL                     106823 non-null  object
#  3   REGIÃO                         106823 non-null  object
#  4   ESTADO                         106823 non-null  object
#  5   PRODUTO                        106823 non-null  object
#  6   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  7   UNIDADE DE MEDIDA              106823 non-null  object
#  8   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  9   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  10  PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  11  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %% [markdown]
# # Data Frame

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# <p>Podemos acessar as dimensões para o dataFrame</p>

# %%
data.shape
# Out:
# (106823, 21)

# %%
print(f'O dataFrame possui {data.shape[0]} linhas/observações e {data.shape[1]} colunas/atributos')
# Out:
# O dataFrame possui 106823 linhas/observações e 21 colunas/atributos

# %% [markdown]
# ### Criando um dataFrame

# %%
# index , nomedojog , nome , ano de lancamento
# 0          Zelda  Link     1998
# 1          God    Kratos   2003
# 2          Mario  Luigi    1999
jogos_df = pd.DataFrame({
    'nomedojog' : ['Zelda ocarina of time','god of war','Mario Bros'],
    'nomedopers' : ['Link' , 'Kratos' , 'Luigi'],
    'Anolançado' : [1998, 2003, 1999],
    'eh_bom' : [True,True,False]
})

# %%
jogos_df
# Out:
#                nomedojog nomedopers  Anolançado  eh_bom
# 0  Zelda ocarina of time       Link        1998    True
# 1             god of war     Kratos        2003    True
# 2             Mario Bros      Luigi        1999   False

# %%
jogos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   nomedojog   3 non-null      object
#  1   nomedopers  3 non-null      object
#  2   Anolançado  3 non-null      int64
#  3   eh_bom      3 non-null      bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 203.0+ bytes

# %% [markdown]
# <h3>Renomeando os data frames</h3>

# %%
jogos_df.columns
# Out:
# Index(['nomedojog', 'nomedopers', 'Anolançado', 'eh_bom'], dtype='object')

# %% [markdown]
# <p>Original</p>

# %%
jogos_df
# Out:
#                nomedojog nomedopers  Anolançado  eh_bom
# 0  Zelda ocarina of time       Link        1998    True
# 1             god of war     Kratos        2003    True
# 2             Mario Bros      Luigi        1999   False

# %% [markdown]
# <p>Renomeando com a cópia do original</p>

# %%
jogos_df_renomados = jogos_df.rename(columns={
    'nomedojog' : 'Jogo',
    'nomedopers': 'Personagem',
    'Anolançado' : 'Lançamento',
    'eh_bom' : 'Bom' 
})

# %%
jogos_df_renomados
# Out:
#                     Jogo Personagem  Lançamento    Bom
# 0  Zelda ocarina of time       Link        1998   True
# 1             god of war     Kratos        2003   True
# 2             Mario Bros      Luigi        1999  False

# %% [markdown]
# <p>Alterando o original</p>

# %%
jogos_df.rename(columns={
    'nomedojog' : 'Jogo',
    'nomedopers': 'Personagem',
    'Anolançado' : 'Lançamento',
    'eh_bom' : 'Bom'
    },
    # para alterar o dataframe original use o paramêtro "inplace=True"
    inplace=True)

# %%
jogos_df
# Out:
#                     Jogo Personagem  Lançamento    Bom
# 0  Zelda ocarina of time       Link        1998   True
# 1             god of war     Kratos        2003   True
# 2             Mario Bros      Luigi        1999  False

# %% [markdown]
# <p>Renomeando com listas</p>

# %%
jogos_df.columns
# Out:
# Index(['Jogo', 'Personagem', 'Lançamento', 'Bom'], dtype='object')

# %%
jogos_df.columns = ['JOGOS' , 'PERSONAGEM' , 'LANÇAMENTO','BOM']

# %%
jogos_df
# Out:
#                    JOGOS PERSONAGEM  LANÇAMENTO    BOM
# 0  Zelda ocarina of time       Link        1998   True
# 1             god of war     Kratos        2003   True
# 2             Mario Bros      Luigi        1999  False

# %% [markdown]
# <h1>Series</h1>

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
type(data["ESTADO"])
# Out:
# pandas.core.series.Series

# %%
# Só e possivel fazer desse tipo se não conter caracteres inválidas como _ , . etc
type(data.ESTADO)
# Out:
# pandas.core.series.Series

# %%
# pode pegar um atribuito pela indexação dele como o exemplo abaixo 
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %% [markdown]
# <p>Criando series</p>

# %%
pd.Series([5.5 , 6.3 , 2.3])
# Out:
# 0    5.5
# 1    6.3
# 2    2.3
# dtype: float64

# %% [markdown]
# <p>Renomeando as series pelo indices</p>

# %%
pd.Series([5.5 , 6.3 , 9.3] , index=['Prova 1' , 'Prova 2' , 'Projeto'] , name='Notas do Júlio')
# Out:
# Prova 1    5.5
# Prova 2    6.3
# Projeto    9.3
# Name: Notas do Júlio, dtype: float64

# %% [markdown]
# <h1>Atribuindo dados</h1>

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
# faça uma copia

# %%
data_copy_bkp = data['PRODUTO'].copy()

# %%
data_copy_bkp
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
# atribuindo em listas ou series no caso
nrows , ncolum = data.shape
nrows , ncolum
# Out:
# (106823, 21)

# %%
novos_produtos = [f'Produtos {i}' for i in range(nrows)]
novos_produtos
# Out:
# ['Produtos 0',
#  'Produtos 1',
#  'Produtos 2',
#  'Produtos 3',
#  'Produtos 4',
#  'Produtos 5',
#  'Produtos 6',
#  'Produtos 7',
#  'Produtos 8',
#  'Produtos 9',
#  'Produtos 10',
#  'Produtos 11',
#  'Produtos 12',
#  'Produtos 13',
#  'Produtos 14',
#  'Produtos 15',
#  'Produtos 16',
#  'Produtos 17',
#  'Produtos 18',
#  'Produtos 19',
#  'Produtos 20',
#  'Produtos 21',
#  'Produtos 22',
#  'Produtos 23',
#  'Produtos 24',
#  'Produtos 25',
#  'Produtos 26',
#  'Produtos 27',
#  'Produtos 28',
#  'Produtos 29',
#  'Produtos 30',
#  'Produtos 31',
#  'Produtos 32',
#  'Produtos 33',
#  'Produtos 34',
#  'Produtos 35',
#  'Produtos 36',
#  'Produtos 37',
#  'Produtos 38',
#  'Produtos 39',
#  'Produtos 40',
#  'Produtos 41',
#  'Produtos 42',
#  'Produtos 43',
#  'Produtos 44',
#  'Produtos 45',
#  'Produtos 46',
#  'Produtos 47',
#  'Produtos 48',
#  'Produtos 49',
#  'Produtos 50',
#  'Produtos 51',
#  'Produtos 52',
#  'Produtos 53',
#  'Produtos 54',
#  'Produtos 55',
# ...

# %%
data['PRODUTO'] = novos_produtos
data.PRODUTO
# Out:
# 0              Produtos 0
# 1              Produtos 1
# 2              Produtos 2
# 3              Produtos 3
# 4              Produtos 4
#                ...
# 106818    Produtos 106818
# 106819    Produtos 106819
# 106820    Produtos 106820
# 106821    Produtos 106821
# 106822    Produtos 106822
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#       PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Produtos 0                           127              R$/l
# 1  Produtos 1                           387              R$/l
# 2  Produtos 2                           192              R$/l
# 3  Produtos 3                           162              R$/l
# 4  Produtos 4                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# ...

# %%
print(data['PRODUTO'])
print('\n')
print(data_copy_bkp)
# Out:
# 0              Produtos 0
# 1              Produtos 1
# 2              Produtos 2
# 3              Produtos 3
# 4              Produtos 4
#                ...
# 106818    Produtos 106818
# 106819    Produtos 106819
# 106820    Produtos 106820
# 106821    Produtos 106821
# 106822    Produtos 106822
# Name: PRODUTO, Length: 106823, dtype: object
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %% [markdown]
# <p>Voltando para oque era antes de manipular</p>

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#       PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  Produtos 0                           127              R$/l
# 1  Produtos 1                           387              R$/l
# 2  Produtos 2                           192              R$/l
# 3  Produtos 3                           162              R$/l
# 4  Produtos 4                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 0                1.288                  0.016  ...                 1.350
# ...

# %%
data['PRODUTO'] = data_copy_bkp
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %% [markdown]
# <h1 style="color: purple">Criando novas colunas</h1>

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
data['nota sem noção'] = 'DEFAULT'
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  MARGEM MÉDIA REVENDA  \
# ...

# %%
data['PREÇO MÉDIO REVENDA (doláres)'] = data['PREÇO MÉDIO REVENDA'] * 6.0
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# ...

# %% [markdown]
# <h1>Indices</h1>

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.index
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %% [markdown]
# <p>Criando indices</p>

# %%
pesquisa_de_consoles = pd.DataFrame(
    {
    'bom' : [3.1 , 2.1 , 5.1],
    'medio' : [5.1 , 4.1 , 9.1],
    'pessimo' : [3.1 , 5.1 , 7.1]
    }, index=['Switch' , 'Xbox' , 'Playstion'])

# %%
pesquisa_de_consoles
# Out:
#            bom  medio  pessimo
# Switch     3.1    5.1      3.1
# Xbox       2.1    4.1      5.1
# Playstion  5.1    9.1      7.1

# %%
pesquisa_de_consoles.index
# Out:
# Index(['Switch', 'Xbox', 'Playstion'], dtype='object')

# %% [markdown]
# <h1>Seleçao de indices</h1>

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data.iloc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %%
data.iloc[:6]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5           5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# ...

# %%
data.iloc[[1,8,9]]
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO      ESTADO  \
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE       GOIAS
# 8           8   2004-05-09  2004-05-15      NORDESTE     PARAIBA
# 9           9   2004-05-09  2004-05-15      NORDESTE  PERNAMBUCO
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 1  ETANOL HIDRATADO                           387              R$/l
# 8  ETANOL HIDRATADO                           125              R$/l
# 9  ETANOL HIDRATADO                           423              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# 1                1.162                  0.114  ...                     0.098
# 8                1.284                  0.130  ...                     0.101
# 9                1.224                  0.141  ...                     0.115
#
#    PREÇO MÉDIO DISTRIBUIÇÃO DESVIO PADRÃO DISTRIBUIÇÃO  \
# 1                     0.763                      0.088
# ...

# %% [markdown]
# <p>Filtrando os estados do nortes usando o iloc</p>

# %%
localizar_estados_nortes = data.iloc[9:101]

# %%
localizar_estados_nortes.head(50)
# Out:
#     Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 9            9   2004-05-09  2004-05-15      NORDESTE           PERNAMBUCO
# 10          10   2004-05-09  2004-05-15      NORDESTE                PIAUI
# 11          11   2004-05-09  2004-05-15      NORDESTE  RIO GRANDE DO NORTE
# 12          12   2004-05-09  2004-05-15      NORDESTE              SERGIPE
# 13          13   2004-05-09  2004-05-15         NORTE                 ACRE
# 14          14   2004-05-09  2004-05-15         NORTE                AMAPA
# 15          15   2004-05-09  2004-05-15         NORTE             AMAZONAS
# 16          16   2004-05-09  2004-05-15         NORTE                 PARA
# 17          17   2004-05-09  2004-05-15         NORTE             RONDONIA
# 18          18   2004-05-09  2004-05-15         NORTE              RORAIMA
# 19          19   2004-05-09  2004-05-15         NORTE            TOCANTINS
# ...

# %%
localizar_estados_nortes.iloc[9]
# Out:
# Unnamed: 0                                     18
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                                      NORTE
# ESTADO                                    RORAIMA
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                   14
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                           1.3
# DESVIO PADRÃO REVENDA                         0.0
# PREÇO MÍNIMO REVENDA                          1.3
# PREÇO MÁXIMO REVENDA                          1.3
# MARGEM MÉDIA REVENDA                        0.202
# COEF DE VARIAÇÃO REVENDA                      0.0
# PREÇO MÉDIO DISTRIBUIÇÃO                    1.098
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.096
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.9798
# PREÇO MÁXIMO DISTRIBUIÇÃO                  1.3577
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.087
# ...

# %%
estado_roraima = localizar_estados_nortes.iloc[9,4]
valor_medio_revenda = localizar_estados_nortes.iloc[9,8]

# %%
estado = pd.Series(estado_roraima, name='ESTADO')
valor = pd.Series(valor_medio_revenda, name='REVENDA')
valor
teste = pd.concat([estado, valor], axis=1)
teste
# Out:
#     ESTADO  REVENDA
# 0  RORAIMA      1.3

# %% [markdown]
# <h1>Seleção de rótulos<h1>

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# ...

# %%
pesquisa_de_consoles
# Out:
#            bom  medio  pessimo
# Switch     3.1    5.1      3.1
# Xbox       2.1    4.1      5.1
# Playstion  5.1    9.1      7.1

# %%
pesquisa_de_consoles.loc[: ,['bom' , 'pessimo']]
# Out:
#            bom  pessimo
# Switch     3.1      3.1
# Xbox       2.1      5.1
# Playstion  5.1      7.1

# %%
pesquisa_de_consoles.loc['Switch' , ['bom' , 'pessimo']]
# Out:
# bom        3.1
# pessimo    3.1
# Name: Switch, dtype: float64

# %%
data.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  COEF DE VARIAÇÃO REVENDA  \
# ...

# %% [markdown]
# <p>rótulos também aceitam indices númericos

# %%
data.loc[1]
# Out:
# Unnamed: 0                                      1
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# ...

# %% [markdown]
# ## Seleção de colunas/atribuito

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data[['PRODUTO' , 'REGIÃO' , 'ESTADO']]
# Out:
#                  PRODUTO        REGIÃO               ESTADO
# 0       ETANOL HIDRATADO  CENTRO OESTE     DISTRITO FEDERAL
# 1       ETANOL HIDRATADO  CENTRO OESTE                GOIAS
# 2       ETANOL HIDRATADO  CENTRO OESTE          MATO GROSSO
# 3       ETANOL HIDRATADO  CENTRO OESTE   MATO GROSSO DO SUL
# 4       ETANOL HIDRATADO      NORDESTE              ALAGOAS
# ...                  ...           ...                  ...
# 106818               GNV      NORDESTE  RIO GRANDE DO NORTE
# 106819               GNV           SUL    RIO GRANDE DO SUL
# 106820               GNV           SUL       SANTA CATARINA
# 106821               GNV       SUDESTE            SAO PAULO
# 106822               GNV      NORDESTE              SERGIPE
#
# [106823 rows x 3 columns]

# %%
data[data['ESTADO'] == 'RORAIMA']["PRODUTO"].unique()
# data.query('ESTADO == "RORAIMA"')
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'ÓLEO DIESEL',
#        'ÓLEO DIESEL S10'], dtype=object)

# %%
data
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 106818      106818   2019-06-23  2019-06-29      NORDESTE
# 106819      106819   2019-06-23  2019-06-29           SUL
# 106820      106820   2019-06-23  2019-06-29           SUL
# 106821      106821   2019-06-23  2019-06-29       SUDESTE
# 106822      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %% [markdown]
# ### Removendo colunas/atribuitos

# %%
del data['Unnamed: 0']
del data['nota sem noção']

# %%
del data['PREÇO MÉDIO REVENDA (doláres)']

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data.to_csv('/home/youx/workspace-git/youxlab-treino-git/curso_dados/data.sets/ipynb.xave/preprecoderevenda.csv', index=False)

# %% [markdown]
# ## Seleção condicional

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data.shape
# Out:
# (106823, 20)

# %%
data['ESTADO'] == 'SAO PAULO'
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 106818    False
# 106819    False
# 106820    False
# 106821     True
# 106822    False
# Name: ESTADO, Length: 106823, dtype: bool

# %%
# cria um valor boleano para todos os estados de são paulo 
selecao = data['ESTADO'] == 'SAO PAULO'

# %%
data[selecao]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 23       2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 77       2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 104      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 131      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...             ...         ...      ...        ...               ...
# 106724   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 106751   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 106778   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 106805   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 106821   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# #### Criando uma array a partir de um metôdo com valores selecionados de um atribuito/colunas

# %%
# cria uma array unica para mostrar todos os estados de data 
pd.unique(data["ESTADO"])
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %% [markdown]
# ## Filtragem parte 2

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
pd.unique(data['ESTADO'])
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
# uso mais comuns ultimante
postos_sp = data.query('ESTADO == "SAO PAULO"').reset_index(drop=True)

# %%
postos_sp
# Out:
#      DATA INICIAL  DATA FINAL   REGIÃO     ESTADO           PRODUTO  \
# 0      2004-05-09  2004-05-15  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 1      2004-05-16  2004-05-22  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 2      2004-05-23  2004-05-29  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 3      2004-05-30  2004-06-05  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# 4      2004-06-06  2004-06-12  SUDESTE  SAO PAULO  ETANOL HIDRATADO
# ...           ...         ...      ...        ...               ...
# 4258   2019-06-23  2019-06-29  SUDESTE  SAO PAULO       ÓLEO DIESEL
# 4259   2019-06-23  2019-06-29  SUDESTE  SAO PAULO   ÓLEO DIESEL S10
# 4260   2019-06-23  2019-06-29  SUDESTE  SAO PAULO    GASOLINA COMUM
# 4261   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GLP
# 4262   2019-06-23  2019-06-29  SUDESTE  SAO PAULO               GNV
#
#       NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 0                             4047              R$/l                0.768
# ...

# %%
produtos = postos_sp.query('PRODUTO == "GASOLINA COMUM"').reset_index(drop=True)
pd.unique(produtos['REGIÃO'])
# Out:
# array(['SUDESTE'], dtype=object)

# %% [markdown]
# ### Filtragem parte 3

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
estados_rj = data['ESTADO'] == 'RIO DE JANEIRO'

# %%
preco_minimo_revenda = data['PREÇO MÍNIMO REVENDA'] > 2

# %%
selecao_rj = preco_minimo_revenda & estados_rj

# %%
preco_revenda_do_rj = selecao_rj

# %%
data[preco_revenda_do_rj]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 9629     2011-04-03  2011-04-09  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 9710     2011-04-24  2011-04-30  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 9737     2011-05-01  2011-05-07  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 12842    2004-11-21  2004-11-27  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 12869    2004-11-28  2004-12-04  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# ...             ...         ...      ...             ...               ...
# 106718   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO       ÓLEO DIESEL
# 106745   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO   ÓLEO DIESEL S10
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
#
# ...

# %% [markdown]
# ### Filtragem parte 4

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
selecao_1 = (data['ESTADO'] == 'SAO PAULO') | (data['ESTADO'] == 'RIO DE JANEIRO')
postos_rj_sp = data[selecao_1]
postos_rj_sp
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 22       2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 23       2004-05-09  2004-05-15  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 49       2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# 50       2004-05-16  2004-05-22  SUDESTE       SAO PAULO  ETANOL HIDRATADO
# 76       2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO    GASOLINA COMUM
# 106799   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GLP
# 106805   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GLP
# 106817   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO               GNV
# 106821   2019-06-23  2019-06-29  SUDESTE       SAO PAULO               GNV
#
# ...

# %%
selecao_2 = postos_rj_sp['PRODUTO'] ==  'GASOLINA COMUM'
produto_gasolina_sp_rj = postos_rj_sp[selecao_2]
produto_gasolina_sp_rj
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12086    2004-05-09  2004-05-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12087    2004-05-09  2004-05-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12113    2004-05-16  2004-05-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12114    2004-05-16  2004-05-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 12140    2004-05-23  2004-05-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
selecao_3  = produto_gasolina_sp_rj['PREÇO MÍNIMO REVENDA'] > 2
produto_gasolina_sp_rj_maior_revenda = produto_gasolina_sp_rj[selecao_3]
produto_gasolina_sp_rj_maior_revenda
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO         PRODUTO  \
# 12842    2004-11-21  2004-11-27  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12869    2004-11-28  2004-12-04  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12923    2004-12-12  2004-12-18  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 12977    2004-12-26  2005-01-01  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 13031    2005-01-09  2005-01-15  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# ...             ...         ...      ...             ...             ...
# 106479   2019-06-09  2019-06-15  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106623   2019-06-16  2019-06-22  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106629   2019-06-16  2019-06-22  SUDESTE       SAO PAULO  GASOLINA COMUM
# 106772   2019-06-23  2019-06-29  SUDESTE  RIO DE JANEIRO  GASOLINA COMUM
# 106778   2019-06-23  2019-06-29  SUDESTE       SAO PAULO  GASOLINA COMUM
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %% [markdown]
# ### Filtragem parte 5

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %%
# Jeito mais pratico que achei de filtrar usando listas
listas_de_anos = [2008,2010,2013]
data.query('ANO in @listas_de_anos')
# Out:
#       DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 5098    2008-01-06  2008-01-12  CENTRO OESTE     DISTRITO FEDERAL
# 5099    2008-01-06  2008-01-12  CENTRO OESTE                GOIAS
# 5100    2008-01-06  2008-01-12  CENTRO OESTE          MATO GROSSO
# 5101    2008-01-06  2008-01-12  CENTRO OESTE   MATO GROSSO DO SUL
# 5102    2008-01-06  2008-01-12      NORDESTE              ALAGOAS
# ...            ...         ...           ...                  ...
# 63675   2013-12-29  2014-01-04      NORDESTE  RIO GRANDE DO NORTE
# 63676   2013-12-29  2014-01-04           SUL    RIO GRANDE DO SUL
# 63677   2013-12-29  2014-01-04           SUL       SANTA CATARINA
# 63678   2013-12-29  2014-01-04       SUDESTE            SAO PAULO
# 63679   2013-12-29  2014-01-04      NORDESTE              SERGIPE
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 5098   ETANOL HIDRATADO                            80              R$/l
# ...

# %% [markdown]
# #### interando com DataFrame

# %%
for index , rows in data.head(5).iterrows():
    print(f'indices {index} ==> {rows["ESTADO"]}')
# OBS: isso e bem importante para vai mexer com banco de dados
# Out:
# indices 0 ==> DISTRITO FEDERAL
# indices 1 ==> GOIAS
# indices 2 ==> MATO GROSSO
# indices 3 ==> MATO GROSSO DO SUL
# indices 4 ==> ALAGOAS

# %% [markdown]
# # 2 preparação de dados

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
# ...

# %%
data_pre = data.copy()
data_pre
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data_pre['DATA INICIAL'] = pd.to_datetime(data_pre['DATA INICIAL'])
data_pre['DATA FINAL'] = pd.to_datetime(data_pre['DATA FINAL'])
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
for atribuito in ['MARGEM MÉDIA REVENDA' , 'PREÇO MÉDIO DISTRIBUIÇÃO' , 'DESVIO PADRÃO DISTRIBUIÇÃO' , 'PREÇO MÍNIMO DISTRIBUIÇÃO' , 'PREÇO MÁXIMO DISTRIBUIÇÃO' , 'COEF DE VARIAÇÃO DISTRIBUIÇÃO']:
    data_pre[atribuito] = pd.to_numeric(data_pre[atribuito] , errors='coerce')

# %%
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  datetime64[ns]
#  1   DATA FINAL                     106823 non-null  datetime64[ns]
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
# ...

# %%
mask = data_pre['PREÇO MÉDIO DISTRIBUIÇÃO'].isnull()
data_pre[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data[mask]
# Out:
#        DATA INICIAL  DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25  2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09  2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23  2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26  2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27  2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...         ...      ...             ...               ...
# 106664   2019-06-16  2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16  2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23  2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23  2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23  2019-06-29      SUL          PARANA               GNV
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106823 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   106823 non-null  object
#  1   DATA FINAL                     106823 non-null  object
#  2   REGIÃO                         106823 non-null  object
#  3   ESTADO                         106823 non-null  object
#  4   PRODUTO                        106823 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   106823 non-null  int64
#  6   UNIDADE DE MEDIDA              106823 non-null  object
#  7   PREÇO MÉDIO REVENDA            106823 non-null  float64
#  8   DESVIO PADRÃO REVENDA          106823 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           106823 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           106823 non-null  float64
#  11  MARGEM MÉDIA REVENDA           106823 non-null  object
# ...

# %%
data_pre_fill = data_pre.fillna(0)
data_pre_fill
# Out:
#        DATA INICIAL DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09 2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09 2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09 2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09 2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09 2004-05-15      NORDESTE              ALAGOAS
# ...             ...        ...           ...                  ...
# 106818   2019-06-23 2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23 2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23 2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23 2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23 2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data_pre_fill = data_pre.fillna(value={
    'PREÇO MÉDIO DISTRIBUIÇÃO' : 20,
    'DESVIO PADRÃO DISTRIBUIÇÃO' : 30,
    'PREÇO MÍNIMO DISTRIBUIÇÃO' : 40,
    'PREÇO MÁXIMO DISTRIBUIÇÃO' : 'vazio'
})

# %%
data_pre_fill[mask]
# Out:
#        DATA INICIAL DATA FINAL   REGIÃO          ESTADO           PRODUTO  \
# 1903     2005-09-25 2005-10-01    NORTE            PARA  ETANOL HIDRATADO
# 1958     2005-10-09 2005-10-15    NORTE         RORAIMA  ETANOL HIDRATADO
# 2012     2005-10-23 2005-10-29    NORTE         RORAIMA  ETANOL HIDRATADO
# 2497     2006-02-26 2006-03-04    NORTE         RORAIMA  ETANOL HIDRATADO
# 3199     2006-08-27 2006-09-02    NORTE         RORAIMA  ETANOL HIDRATADO
# ...             ...        ...      ...             ...               ...
# 106664   2019-06-16 2019-06-22  SUDESTE    MINAS GERAIS               GNV
# 106666   2019-06-16 2019-06-22      SUL          PARANA               GNV
# 106811   2019-06-23 2019-06-29  SUDESTE  ESPIRITO SANTO               GNV
# 106813   2019-06-23 2019-06-29  SUDESTE    MINAS GERAIS               GNV
# 106815   2019-06-23 2019-06-29      SUL          PARANA               GNV
#
#         NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# ...

# %%
data_pre.dropna(inplace=True)
data_pre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103392 entries, 0 to 106822
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   DATA INICIAL                   103392 non-null  datetime64[ns]
#  1   DATA FINAL                     103392 non-null  datetime64[ns]
#  2   REGIÃO                         103392 non-null  object
#  3   ESTADO                         103392 non-null  object
#  4   PRODUTO                        103392 non-null  object
#  5   NÚMERO DE POSTOS PESQUISADOS   103392 non-null  int64
#  6   UNIDADE DE MEDIDA              103392 non-null  object
#  7   PREÇO MÉDIO REVENDA            103392 non-null  float64
#  8   DESVIO PADRÃO REVENDA          103392 non-null  float64
#  9   PREÇO MÍNIMO REVENDA           103392 non-null  float64
#  10  PREÇO MÁXIMO REVENDA           103392 non-null  float64
#  11  MARGEM MÉDIA REVENDA           103392 non-null  float64
# ...

# %%
data_pre.to_csv('/home/youx/workspace-git/youxlab-treino-git/curso_dados/data.sets/ipynb.xave/xavecodingfinal.csv')

# %% [markdown]
# # 3 Estatísticas Descritivas

# %%
data_final = pd.read_csv('/home/youx/workspace-git/youxlab-treino-git/curso_dados/data.sets/ipynb.xave/xavecodingfinal.csv')
data_final
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      106818   2019-06-23  2019-06-29      NORDESTE
# 103388      106819   2019-06-23  2019-06-29           SUL
# 103389      106820   2019-06-23  2019-06-29           SUL
# 103390      106821   2019-06-23  2019-06-29       SUDESTE
# 103391      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data_final.describe()
# Out:
#           Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count  103392.000000                 103392.000000        103392.000000
# mean    52973.958682                    240.511935            10.784472
# std     30968.261500                    408.039174            17.685852
# min         0.000000                      1.000000             0.766000
# 25%     25964.750000                     47.000000             2.073000
# 50%     52661.500000                    108.000000             2.723000
# 75%     79918.250000                    251.000000             3.745000
# max    106822.000000                   4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# ...

# %%
data_final['PREÇO MÉDIO REVENDA'].describe()
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %% [markdown]
# <p>tem outro jeito de fazer</p>

# %%
data_final.describe()['PREÇO MÉDIO REVENDA']
# Out:
# count    103392.000000
# mean         10.784472
# std          17.685852
# min           0.766000
# 25%           2.073000
# 50%           2.723000
# 75%           3.745000
# max          99.357000
# Name: PREÇO MÉDIO REVENDA, dtype: float64

# %%
stats = data_final.describe()

# %%
stats[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %%
data_final[['PREÇO MÉDIO REVENDA', 'PREÇO MÁXIMO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']].describe()
# Out:
#        PREÇO MÉDIO REVENDA  PREÇO MÁXIMO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# count        103392.000000         103392.000000             103392.000000
# mean             10.784472             12.458686                  8.559322
# std              17.685852             20.801190                 13.603686
# min               0.766000              0.999000                  0.506000
# 25%               2.073000              2.330000                  1.795000
# 50%               2.723000              3.000000                  2.335000
# 75%               3.745000              4.150000                  3.307000
# max              99.357000            120.000000                 83.137000

# %%
stats
# Out:
#           Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count  103392.000000                 103392.000000        103392.000000
# mean    52973.958682                    240.511935            10.784472
# std     30968.261500                    408.039174            17.685852
# min         0.000000                      1.000000             0.766000
# 25%     25964.750000                     47.000000             2.073000
# 50%     52661.500000                    108.000000             2.723000
# 75%     79918.250000                    251.000000             3.745000
# max    106822.000000                   4167.000000            99.357000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count          103392.000000         103392.000000         103392.000000
# mean                0.652589              9.334931             12.458686
# std                 1.346422             15.024383             20.801190
# ...

# %%
stats.loc[['min', 'max', 'mean'], ['PREÇO MÉDIO REVENDA', 'PREÇO MÉDIO DISTRIBUIÇÃO']]
# Out:
#       PREÇO MÉDIO REVENDA  PREÇO MÉDIO DISTRIBUIÇÃO
# min              0.766000                  0.506000
# max             99.357000                 83.137000
# mean            10.784472                  8.559322

# %%
data_final.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
data_final['PREÇO MÍNIMO REVENDA'].min()
# Out:
# np.float64(0.59)

# %%
mean = data_final['PREÇO MÍNIMO REVENDA'].mean()
std = data_final['PREÇO MÍNIMO REVENDA'].std()

print(f'A média dos preços mínimos de revenda é {mean:.2f} +- {std:.2f}')
# Out:
# A média dos preços mínimos de revenda é 9.33 +- 15.02

# %%
data_final['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 103387    RIO GRANDE DO NORTE
# 103388      RIO GRANDE DO SUL
# 103389         SANTA CATARINA
# 103390              SAO PAULO
# 103391                SERGIPE
# Name: ESTADO, Length: 103392, dtype: object

# %%
data_final['ESTADO'].unique()
# Out:
# array(['DISTRITO FEDERAL', 'GOIAS', 'MATO GROSSO', 'MATO GROSSO DO SUL',
#        'ALAGOAS', 'BAHIA', 'CEARA', 'MARANHAO', 'PARAIBA', 'PERNAMBUCO',
#        'PIAUI', 'RIO GRANDE DO NORTE', 'SERGIPE', 'ACRE', 'AMAPA',
#        'AMAZONAS', 'PARA', 'RONDONIA', 'RORAIMA', 'TOCANTINS',
#        'ESPIRITO SANTO', 'MINAS GERAIS', 'RIO DE JANEIRO', 'SAO PAULO',
#        'PARANA', 'RIO GRANDE DO SUL', 'SANTA CATARINA'], dtype=object)

# %%
sorted(data_final['ESTADO'].unique())
# Out:
# ['ACRE',
#  'ALAGOAS',
#  'AMAPA',
#  'AMAZONAS',
#  'BAHIA',
#  'CEARA',
#  'DISTRITO FEDERAL',
#  'ESPIRITO SANTO',
#  'GOIAS',
#  'MARANHAO',
#  'MATO GROSSO',
#  'MATO GROSSO DO SUL',
#  'MINAS GERAIS',
#  'PARA',
#  'PARAIBA',
#  'PARANA',
#  'PERNAMBUCO',
#  'PIAUI',
#  'RIO DE JANEIRO',
#  'RIO GRANDE DO NORTE',
#  'RIO GRANDE DO SUL',
#  'RONDONIA',
#  'RORAIMA',
#  'SANTA CATARINA',
#  'SAO PAULO',
#  'SERGIPE',
#  'TOCANTINS']

# %%
data_final['ESTADO'].value_counts()
# Out:
# ESTADO
# BAHIA                  4263
# RIO DE JANEIRO         4262
# SAO PAULO              4261
# RIO GRANDE DO SUL      4249
# PARAIBA                4240
# PERNAMBUCO             4236
# SERGIPE                4202
# SANTA CATARINA         4164
# MINAS GERAIS           4142
# ESPIRITO SANTO         4079
# MATO GROSSO DO SUL     4076
# ALAGOAS                4020
# RIO GRANDE DO NORTE    3999
# CEARA                  3964
# PARANA                 3902
# AMAZONAS               3713
# MATO GROSSO            3703
# PARA                   3477
# MARANHAO               3470
# ACRE                   3463
# RORAIMA                3457
# TOCANTINS              3453
# GOIAS                  3449
# RONDONIA               3441
# PIAUI                  3394
# DISTRITO FEDERAL       3317
# AMAPA                  2996
# Name: count, dtype: int64

# %%
data_final['ESTADO'].value_counts().to_frame()
# Out:
#                      count
# ESTADO
# BAHIA                 4263
# RIO DE JANEIRO        4262
# SAO PAULO             4261
# RIO GRANDE DO SUL     4249
# PARAIBA               4240
# PERNAMBUCO            4236
# SERGIPE               4202
# SANTA CATARINA        4164
# MINAS GERAIS          4142
# ESPIRITO SANTO        4079
# MATO GROSSO DO SUL    4076
# ALAGOAS               4020
# RIO GRANDE DO NORTE   3999
# CEARA                 3964
# PARANA                3902
# AMAZONAS              3713
# MATO GROSSO           3703
# PARA                  3477
# MARANHAO              3470
# ACRE                  3463
# RORAIMA               3457
# TOCANTINS             3453
# GOIAS                 3449
# RONDONIA              3441
# PIAUI                 3394
# DISTRITO FEDERAL      3317
# AMAPA                 2996

# %% [markdown]
# # 4 Executando funções

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]},
                    index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
def nossa_soma(series):
    return series.sum()

# %%
df['SOMA(A, B, C)'] = df.apply(nossa_soma, axis=1)
df
# Out:
#          A   B    C  SOMA(A, B, C)
# Linha 1  1  10  100            111
# Linha 2  2  20  200            222
# Linha 3  3  30  300            333
# Linha 4  4  40  400            444

# %%
df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)
df
# Out:
#           A    B     C  SOMA(A, B, C)
# Linha 1   1   10   100            111
# Linha 2   2   20   200            222
# Linha 3   3   30   300            333
# Linha 4   4   40   400            444
# Linha 5  10  100  1000           1110

# %%
df['MEDIA(A, B, C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)
# Linha 1   1   10   100            111            37.0
# Linha 2   2   20   200            222            74.0
# Linha 3   3   30   300            333           111.0
# Linha 4   4   40   400            444           148.0
# Linha 5  10  100  1000           1110           370.0

# %%
df['C * 2'] = df['C'].apply(lambda x: x * 2)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)  C * 2
# Linha 1   1   10   100            111            37.0    200
# Linha 2   2   20   200            222            74.0    400
# Linha 3   3   30   300            333           111.0    600
# Linha 4   4   40   400            444           148.0    800
# Linha 5  10  100  1000           1110           370.0   2000

# %%
df['A * 2'] = df['A'] * 2
df
# Out:
#           A    B     C  SOMA(A, B, C)  MEDIA(A, B, C)  C * 2  A * 2
# Linha 1   1   10   100            111            37.0    200      2
# Linha 2   2   20   200            222            74.0    400      4
# Linha 3   3   30   300            333           111.0    600      6
# Linha 4   4   40   400            444           148.0    800      8
# Linha 5  10  100  1000           1110           370.0   2000     20

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
df.applymap(lambda x: x ** 2)
# Out:
# /tmp/ipykernel_9521/547004281.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x ** 2)
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
nomes = pd.Series(['João', 'Maria', 'Alice', 'Pedro'])
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %%
nomes.map(lambda x: x.upper())
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object

# %% [markdown]
# # 5 Agrupamento

# %%
data_final.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
grupos.groups
# Out:
# {'CENTRO OESTE': [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], 'NORDESTE': [4, 5, 6, 7, 8, 9, 10, 11, 12, 31, 32, 33, 34, 35, 36, 37, 38, 39, 58, 59, 60, 61, 62, 63, 64, 65, 66, 85, 86, 87, 88, 89, 90, 91, 92, 93, 112, 113, 114, 115, 116, 117, 118, 119, 120, 139, 140, 141, 142, 143, 144, 145, 146, 147, 166, 167, 168, 169, 170, 171, 172, 173, 174, 193, 194, 195, 196, 197, 198, 199, 200, 201, 220, 221, 222, 223, 224, 225, 226, 227, 228, 247, 248, 249, 250, 251, 252, 253, 254, 255, 274, 275, 276, 277, 278, 279, 280, 281, 282, 301, ...], 'NORTE': [13, 14,
# ...

# %%
grupos.indices
# Out:
# {'CENTRO OESTE': array([     0,      1,      2, ..., 103363, 103364, 103383],
#        shape=(14545,)),
#  'NORDESTE': array([     4,      5,      6, ..., 103385, 103387, 103391],
#        shape=(35788,)),
#  'NORTE': array([    13,     14,     15, ..., 103374, 103375, 103379],
#        shape=(24000,)),
#  'SUDESTE': array([    20,     21,     22, ..., 103377, 103386, 103390],
#        shape=(16744,)),
#  'SUL': array([    24,     25,     26, ..., 103376, 103388, 103389],
#        shape=(12315,))}

# %%
grupos.get_group('CENTRO OESTE')
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 27              27   2004-05-16  2004-05-22  CENTRO OESTE    DISTRITO FEDERAL
# ...            ...          ...         ...           ...                 ...
# 103359      106787   2019-06-23  2019-06-29  CENTRO OESTE    DISTRITO FEDERAL
# 103361      106789   2019-06-23  2019-06-29  CENTRO OESTE               GOIAS
# 103363      106791   2019-06-23  2019-06-29  CENTRO OESTE         MATO GROSSO
# 103364      106792   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
# 103383      106812   2019-06-23  2019-06-29  CENTRO OESTE  MATO GROSSO DO SUL
#
# ...

# %%
grupos.describe()
# Out:
#              Unnamed: 0                                                       \
#                   count          mean           std   min       25%      50%
# REGIÃO
# CENTRO OESTE    14545.0  52794.848127  31380.202472   0.0  24647.00  53023.0
# NORDESTE        35788.0  53022.749022  30768.203891   4.0  26854.25  51922.5
# NORTE           24000.0  52735.865958  31714.571691  13.0  23526.75  54011.5
# SUDESTE         16744.0  53281.350334  30332.349374  20.0  28253.75  52127.5
# SUL             12315.0  53089.777913  30437.425938  24.0  27716.50  51968.0
#
#                                 NÚMERO DE POSTOS PESQUISADOS              ...  \
#                   75%       max                        count        mean  ...
# REGIÃO                                                                    ...
# CENTRO OESTE  80299.0  106812.0                      14545.0  144.898453  ...
# NORDESTE      79910.5  106822.0                      35788.0  124.721834  ...
# ...

# %%
grupos.min()
# Out:
#               Unnamed: 0 DATA INICIAL  DATA FINAL            ESTADO  \
# REGIÃO
# CENTRO OESTE           0   2004-05-09  2004-05-15  DISTRITO FEDERAL
# NORDESTE               4   2004-05-09  2004-05-15           ALAGOAS
# NORTE                 13   2004-05-09  2004-05-15              ACRE
# SUDESTE               20   2004-05-09  2004-05-15    ESPIRITO SANTO
# SUL                   24   2004-05-09  2004-05-15            PARANA
#
#                        PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO
# CENTRO OESTE  ETANOL HIDRATADO                             1
# NORDESTE      ETANOL HIDRATADO                             1
# NORTE         ETANOL HIDRATADO                             1
# SUDESTE       ETANOL HIDRATADO                             1
# SUL           ETANOL HIDRATADO                             1
#
#              UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE           R$/13Kg                1.097                    0.0
# ...

# %%
data_final.groupby('REGIÃO').min()
# Out:
#               Unnamed: 0 DATA INICIAL  DATA FINAL            ESTADO  \
# REGIÃO
# CENTRO OESTE           0   2004-05-09  2004-05-15  DISTRITO FEDERAL
# NORDESTE               4   2004-05-09  2004-05-15           ALAGOAS
# NORTE                 13   2004-05-09  2004-05-15              ACRE
# SUDESTE               20   2004-05-09  2004-05-15    ESPIRITO SANTO
# SUL                   24   2004-05-09  2004-05-15            PARANA
#
#                        PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# REGIÃO
# CENTRO OESTE  ETANOL HIDRATADO                             1
# NORDESTE      ETANOL HIDRATADO                             1
# NORTE         ETANOL HIDRATADO                             1
# SUDESTE       ETANOL HIDRATADO                             1
# SUL           ETANOL HIDRATADO                             1
#
#              UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  \
# REGIÃO
# CENTRO OESTE           R$/13Kg                1.097                    0.0
# ...

# %%
data_final.head()
# Out:
#    Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0           0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1           1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2           2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3           3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4           4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# ...

# %%
grupos = data_final.groupby(['REGIÃO', 'PRODUTO'])
grupos

# %%
grupos.groups
# Out:
# {('CENTRO OESTE', 'ETANOL HIDRATADO'): [0, 1, 2, 3, 27, 28, 29, 30, 54, 55, 56, 57, 81, 82, 83, 84, 108, 109, 110, 111, 135, 136, 137, 138, 162, 163, 164, 165, 189, 190, 191, 192, 216, 217, 218, 219, 243, 244, 245, 246, 270, 271, 272, 273, 297, 298, 299, 300, 324, 325, 326, 327, 351, 352, 353, 354, 378, 379, 380, 381, 405, 406, 407, 408, 432, 433, 434, 435, 459, 460, 461, 462, 486, 487, 488, 489, 513, 514, 515, 516, 540, 541, 542, 543, 567, 568, 569, 570, 594, 595, 596, 597, 621, 622, 623, 624, 648, 649, 650, 651, ...], ('CENTRO OESTE', 'GASOLINA COMUM'): [11980, 11981, 11982, 11983, 12007, 12008, 12009, 12010, 12034, 12035, 12036, 12037, 12061, 12062, 12063, 12064, 12088, 12089, 12090, 12091, 12115, 12116, 12117, 12118, 12142, 12143, 12144, 12145, 12169, 12170, 12171, 12172, 12196, 12197, 12198, 12199, 12223, 12224, 12225, 12226, 12250, 12251, 12252, 12253, 12277, 12278, 12279, 12280, 12304, 12305, 12306, 12307, 12331, 12332, 12333, 12334, 12358, 12359, 12360, 12361, 12385, 12386, 1
# ...

# %%
grupos['PREÇO MÉDIO REVENDA'].mean()
# Out:
# REGIÃO        PRODUTO
# CENTRO OESTE  ETANOL HIDRATADO     2.135670
#               GASOLINA COMUM       3.077476
#               GLP                 48.176747
#               GNV                  1.856312
#               ÓLEO DIESEL          2.481286
#               ÓLEO DIESEL S10      3.294752
# NORDESTE      ETANOL HIDRATADO     2.320266
#               GASOLINA COMUM       3.001887
#               GLP                 41.966090
#               GNV                  1.881722
#               ÓLEO DIESEL          2.346950
#               ÓLEO DIESEL S10      3.041966
# NORTE         ETANOL HIDRATADO     2.511624
#               GASOLINA COMUM       3.149501
#               GLP                 47.065572
#               GNV                  2.084399
#               ÓLEO DIESEL          2.571048
#               ÓLEO DIESEL S10      3.316231
# SUDESTE       ETANOL HIDRATADO     2.163621
#               GASOLINA COMUM       3.000565
#               GLP                 42.081544
# ...

# %%
grupos['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                                 count       mean        std     min       25%  \
# REGIÃO       PRODUTO
# CENTRO OESTE ETANOL HIDRATADO  3122.0   2.135670   0.561465   1.162   1.71400
#              GASOLINA COMUM    3134.0   3.077476   0.615290   1.936   2.66725
#              GLP               3098.0  48.176747  15.204045  28.791  37.33300
#              GNV                847.0   1.856312   0.423861   1.097   1.56900
#              ÓLEO DIESEL       3134.0   2.481286   0.626930   1.435   2.03300
#              ÓLEO DIESEL S10   1210.0   3.294752   0.421234   2.305   2.92425
# NORDESTE     ETANOL HIDRATADO  7046.0   2.320266   0.604374   1.181   1.82500
#              GASOLINA COMUM    7063.0   3.001887   0.640696   1.949   2.58400
#              GLP               6410.0  41.966090  12.063743  28.367  33.22875
#              GNV               5176.0   1.881722   0.522996   0.975   1.59600
#              ÓLEO DIESEL       7061.0   2.346950   0.605705   1.313   1.90000
# ...

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [None, None, None]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum, min])
# Out:
# /tmp/ipykernel_9521/1226331895.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.agg([sum, min])
# /tmp/ipykernel_9521/1226331895.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.agg([sum, min])
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupos = data_final.groupby('REGIÃO')
grupos

# %%
grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# Out:
# /tmp/ipykernel_9521/3977787304.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
# /tmp/ipykernel_9521/3977787304.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grupos['PREÇO MÉDIO REVENDA'].agg([min, max])
#                 min     max
# REGIÃO
# CENTRO OESTE  1.097  99.357
# NORDESTE      0.975  79.630
# NORTE         1.226  87.270
# SUDESTE       0.766  79.192
# SUL           0.922  72.088

# %% [markdown]
# # 6 Ordenação

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %%
notas.sort_values(by='nota_final', ascending=False)
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 3  Alice     20        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True])
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %%
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True], inplace=True)
notas
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# # 7 Exercícios

# %%
data_final
# Out:
#         Unnamed: 0 DATA INICIAL  DATA FINAL        REGIÃO  \
# 0                0   2004-05-09  2004-05-15  CENTRO OESTE
# 1                1   2004-05-09  2004-05-15  CENTRO OESTE
# 2                2   2004-05-09  2004-05-15  CENTRO OESTE
# 3                3   2004-05-09  2004-05-15  CENTRO OESTE
# 4                4   2004-05-09  2004-05-15      NORDESTE
# ...            ...          ...         ...           ...
# 103387      106818   2019-06-23  2019-06-29      NORDESTE
# 103388      106819   2019-06-23  2019-06-29           SUL
# 103389      106820   2019-06-23  2019-06-29           SUL
# 103390      106821   2019-06-23  2019-06-29       SUDESTE
# 103391      106822   2019-06-23  2019-06-29      NORDESTE
#
#                      ESTADO           PRODUTO  NÚMERO DE POSTOS PESQUISADOS  \
# 0          DISTRITO FEDERAL  ETANOL HIDRATADO                           127
# 1                     GOIAS  ETANOL HIDRATADO                           387
# ...

# %%
data_final_2019 = data_final.query('ANO != 2019')

# %%
data_index = data_final_2019.reset_index(drop=True)

# %% [markdown]
# ## 7.1

# %%
data_produto = data_index.groupby('PRODUTO')
data_produto

# %%
data_produto['REGIÃO'].value_counts().to_frame()
# Out:
#                                count
# PRODUTO          REGIÃO
# ETANOL HIDRATADO NORDESTE       6821
#                  NORTE          5021
#                  SUDESTE        3039
#                  CENTRO OESTE   3022
#                  SUL            2278
# GASOLINA COMUM   NORDESTE       6838
#                  NORTE          5289
#                  SUDESTE        3040
#                  CENTRO OESTE   3034
#                  SUL            2279
# GLP              NORDESTE       6185
#                  NORTE          5152
#                  SUDESTE        3037
#                  CENTRO OESTE   2998
#                  SUL            2268
# GNV              NORDESTE       5030
#                  SUDESTE        2772
#                  SUL            1847
#                  CENTRO OESTE    825
#                  NORTE           233
# ÓLEO DIESEL      NORDESTE       6836
#                  NORTE          5290
#                  SUDESTE        3040
# ...

# %% [markdown]
# ## 7.2

# %%
gasolina_de_sp_2018 = data_index.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_de_sp_2018.head()
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 92319       95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92465       95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92610       95654   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# 92755       95806   2018-01-28  2018-02-03  SUDESTE  SAO PAULO
# 92901       95958   2018-02-04  2018-02-10  SUDESTE  SAO PAULO
#
#               PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 92319  GASOLINA COMUM                          1641              R$/l
# 92465  GASOLINA COMUM                          1648              R$/l
# 92610  GASOLINA COMUM                          1648              R$/l
# 92755  GASOLINA COMUM                          1644              R$/l
# 92901  GASOLINA COMUM                          1646              R$/l
#
#        PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  ...  PREÇO MÁXIMO REVENDA  \
# 92319                3.988                  0.156  ...                 4.599
# ...

# %%
gasolina_de_sp_2018.shape
# Out:
# (52, 21)

# %%
gasolina_de_sp_2018.describe()
# Out:
#           Unnamed: 0  NÚMERO DE POSTOS PESQUISADOS  PREÇO MÉDIO REVENDA  \
# count      52.000000                     52.000000            52.000000
# mean    99196.096154                   1610.211538             4.202769
# std      2279.595314                    213.627432             0.180672
# min     95351.000000                    102.000000             3.970000
# 25%     97281.250000                   1639.000000             4.008000
# 50%     99196.500000                   1642.000000             4.202000
# 75%    101116.250000                   1644.000000             4.336250
# max    103025.000000                   1649.000000             4.512000
#
#        DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  PREÇO MÁXIMO REVENDA  \
# count              52.000000             52.000000             52.000000
# mean                0.175500              3.671500              4.975750
# std                 0.017955              0.163808              0.211198
# ...

# %%
gasolina_de_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %% [markdown]
# ## 7.3

# %%
data_index.query('(PRODUTO == "GASOLINA COMUM" or PRODUTO == "ETANOL HIDRATADO") and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 92238       95270   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92319       95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92384       95421   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92465       95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92529       95573   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# ...           ...          ...         ...      ...        ...
# 99410      102724   2018-12-16  2018-12-22  SUDESTE  SAO PAULO
# 99472      102793   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99553      102874   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99617      102944   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
# 99698      103025   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 92238  ETANOL HIDRATADO                          1664              R$/l
# ...

# %%
lista_de_estados = ["GASOLINA COMUM", "ETANOL HIDRATADO"]
data_index.query('PRODUTO in @lista_de_estados and ESTADO == "SAO PAULO" and ANO == 2018')
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 92238       95270   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92319       95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92384       95421   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92465       95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92529       95573   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# ...           ...          ...         ...      ...        ...
# 99410      102724   2018-12-16  2018-12-22  SUDESTE  SAO PAULO
# 99472      102793   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99553      102874   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99617      102944   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
# 99698      103025   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 92238  ETANOL HIDRATADO                          1664              R$/l
# ...

# %%
gasolina_etanol_sp_2018 = data_index.query('PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"] and ESTADO == "SAO PAULO" and ANO == 2018')
gasolina_etanol_sp_2018
# Out:
#        Unnamed: 0 DATA INICIAL  DATA FINAL   REGIÃO     ESTADO  \
# 92238       95270   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92319       95351   2018-01-07  2018-01-13  SUDESTE  SAO PAULO
# 92384       95421   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92465       95502   2018-01-14  2018-01-20  SUDESTE  SAO PAULO
# 92529       95573   2018-01-21  2018-01-27  SUDESTE  SAO PAULO
# ...           ...          ...         ...      ...        ...
# 99410      102724   2018-12-16  2018-12-22  SUDESTE  SAO PAULO
# 99472      102793   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99553      102874   2018-12-23  2018-12-29  SUDESTE  SAO PAULO
# 99617      102944   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
# 99698      103025   2018-12-30  2019-01-05  SUDESTE  SAO PAULO
#
#                 PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 92238  ETANOL HIDRATADO                          1664              R$/l
# ...

# %%
gasolina_etanol_sp_2018['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count           104.000000
# mean              3.457337
# std               0.766239
# min               2.393000
# 25%               2.726000
# 50%               3.431000
# 75%               4.199000
# max               4.512000

# %%
gasolina_etanol_sp_2018.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512
