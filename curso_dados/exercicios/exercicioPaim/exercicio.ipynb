# %%
import pandas as pd

# %%
dados = pd.DataFrame({
    'Nome do Livro':['Caraval', 'Imperfeitos', 'Uma dama fora dos padroẽs'], 
    'Autora': ['Stephanie Garber', 'Christina Lauren', 'Julia Quinn'],
    'Editora': ['Novo Conceito', 'Faro Editorial', 'Arqueiros'],
    'Data de lançamento': ['29/09/2016', '10/03/2022', '29/03/2016'],
})
dados
# Out:
#                Nome do Livro            Autora         Editora  \
# 0                    Caraval  Stephanie Garber   Novo Conceito
# 1                Imperfeitos  Christina Lauren  Faro Editorial
# 2  Uma dama fora dos padroẽs       Julia Quinn       Arqueiros
#
#   Data de lançamento           ISBN  Quantidade
# 0         29/09/2016  9781250095268          14
# 1         10/03/2022  9786559571284           3
# 2         29/03/2016  9788580418750          21

# %%
estoque = pd.DataFrame({
    'ISBN': ['9781250095268','9786559571284', '9788580418750'],
    'Quantidade': [14, 3, 21],
    'Data de Chegada': ['14/05/2024', '23/06/2024', '01/07/2024'],
    'Nome do Comprador': ['Biblioteca Central', 'Secretaria de Cultura', 'Biblioteca Central'] })
estoque
# Out:
#             ISBN  Quantidade Data de Chegada      Nome do Comprador
# 0  9781250095268          14      14/05/2024     Biblioteca Central
# 1  9786559571284           3      23/06/2024  Secretaria de Cultura
# 2  9788580418750          21      01/07/2024     Biblioteca Central

# %%
tudo = pd.merge(dados, estoque)
tudo
# Out:
#                Nome do Livro            Autora         Editora  \
# 0                    Caraval  Stephanie Garber   Novo Conceito
# 1                Imperfeitos  Christina Lauren  Faro Editorial
# 2  Uma dama fora dos padroẽs       Julia Quinn       Arqueiros
#
#   Data de lançamento           ISBN  Quantidade Data de Chegada  \
# 0         29/09/2016  9781250095268          14      14/05/2024
# 1         10/03/2022  9786559571284           3      23/06/2024
# 2         29/03/2016  9788580418750          21      01/07/2024
#
#        Nome do Comprador
# 0     Biblioteca Central
# 1  Secretaria de Cultura
# 2     Biblioteca Central

# %%
tudo.to_csv('relatorio_estoque.csv', index=False)
