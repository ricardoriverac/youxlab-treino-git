# %% [markdown]
# ## FAZENDO A DATA

# %%
import pandas as pd
data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019.csv', sep=",")
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# ## ATRIBUINDO DADOS

# %%
# atribuindo constantes
# retorna uma referência/view da coluna produto 
produto_view = data['PRODUTO']

# %%
produto_copy = data['PRODUTO'].copy() # retorna uma cópia da coluna 'PRODUTO'
produto_copy
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
data['PRODUTO'] = 'Combustível' # atribuindo o valor 'Combustível' para linha do dataframe na coluna 'PRODUTO'

# %%
nrows, ncols = data.shape

# %%
# atribuindo listas ou series

novos_produtos = [f'Produto {i}' for i in range(nrows)]
len(novos_produtos)
# Out:
# 106823

# %%
# a quantidade de elementos da lista 'novos_produtos' é igual ao número de linhas do dataframe
data['PRODUTO'] = novos_produtos

# %%
print(produto_view)
print('\n')
print(produto_copy)
# Out:
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object
#
#
# 0         ETANOL HIDRATADO
# 1         ETANOL HIDRATADO
# 2         ETANOL HIDRATADO
# 3         ETANOL HIDRATADO
# 4         ETANOL HIDRATADO
#                 ...
# 106818                 GNV
# 106819                 GNV
# 106820                 GNV
# 106821                 GNV
# 106822                 GNV
# Name: PRODUTO, Length: 106823, dtype: object

# %%
# voltando para os produtos originais
data['PRODUTO'] = produto_copy
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ## CRIANDO NOVAS COLUNAS

# %%
# criando uma coluna a partir de um valor constatnte/default
# todas as linhas terão o mesmo valor 'DEFAULT'
data['coluna sem nocao'] = 'DEFAULT'
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
data['coluna a partir de lista'] = range(data.shape[0])
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
# nao funciona pois a quantidade de elementos da lista (a serem atribuídos a nova coluna) é diferente da qtd de linhas do dataframe
# data['nao funciona'] =  [1,2,3]

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
data['PREÇO MÉDIO REVENDA (dólares)'] = data['PREÇO MÉDIO REVENDA'] * 6.0
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# ## ÍNDICES

# %%
data.index

# Use list(data.index) ou data.index.to_list() para converter um RangeIndex para uma python list.
# Out:
# RangeIndex(start=0, stop=106823, step=1)

# %%
# Exemplo DataFrame com índices textuais:
pesquisa_de_satisfacao = pd.DataFrame({
    'bom': [50, 21, 100],
    'ruim': [131, 2, 30],
    'pessimo': [30, 20, 1]
}, index=['XboxOne', 'Playstation4', 'Switch'])

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
pesquisa_de_satisfacao.index
# Out:
# Index(['XboxOne', 'Playstation4', 'Switch'], dtype='object')

# %% [markdown]
# ## INDEXAÇÃO

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
# Selecionando uma linha
# selecionadno a linha 1, observação do índice[1] do data frame
data.iloc[1]
# Out:
# DATA INICIAL                           2004-05-09
# DATA FINAL                             2004-05-15
# REGIÃO                               CENTRO OESTE
# ESTADO                                      GOIAS
# PRODUTO                          ETANOL HIDRATADO
# NÚMERO DE POSTOS PESQUISADOS                  387
# UNIDADE DE MEDIDA                            R$/l
# PREÇO MÉDIO REVENDA                         1.162
# DESVIO PADRÃO REVENDA                       0.114
# PREÇO MÍNIMO REVENDA                         0.89
# PREÇO MÁXIMO REVENDA                        1.449
# MARGEM MÉDIA REVENDA                        0.399
# COEF DE VARIAÇÃO REVENDA                    0.098
# PREÇO MÉDIO DISTRIBUIÇÃO                    0.763
# DESVIO PADRÃO DISTRIBUIÇÃO                  0.088
# PREÇO MÍNIMO DISTRIBUIÇÃO                  0.5013
# PREÇO MÁXIMO DISTRIBUIÇÃO                    1.05
# COEF DE VARIAÇÃO DISTRIBUIÇÃO               0.115
# MÊS                                             5
# ...

# %%
# Selecionando múltiplas linhas
# selecionando as linhas de índice de 0 a 5 (incluso)
data.iloc[:6]
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# 5   2004-05-09  2004-05-15      NORDESTE               BAHIA
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
# 5  ETANOL HIDRATADO                           408              R$/l
#
# ...

# %%
# Selecionando as linhas de índice de 10 a 15 (incluso)
data.iloc[10:16]
# Out:
#    DATA INICIAL  DATA FINAL    REGIÃO               ESTADO           PRODUTO  \
# 10   2004-05-09  2004-05-15  NORDESTE                PIAUI  ETANOL HIDRATADO
# 11   2004-05-09  2004-05-15  NORDESTE  RIO GRANDE DO NORTE  ETANOL HIDRATADO
# 12   2004-05-09  2004-05-15  NORDESTE              SERGIPE  ETANOL HIDRATADO
# 13   2004-05-09  2004-05-15     NORTE                 ACRE  ETANOL HIDRATADO
# 14   2004-05-09  2004-05-15     NORTE                AMAPA  ETANOL HIDRATADO
# 15   2004-05-09  2004-05-15     NORTE             AMAZONAS  ETANOL HIDRATADO
#
#     NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 10                            89              R$/l                1.573
# 11                           131              R$/l                1.276
# 12                            57              R$/l                1.301
# 13                            33              R$/l                1.805
# ...

# %%
# Selecionando as linhas de índice 1, 5, 10, 15
data.iloc[[1, 5, 10, 15]] # ou data.iloc[:16:5]
# Out:
#    DATA INICIAL  DATA FINAL        REGIÃO    ESTADO           PRODUTO  \
# 1    2004-05-09  2004-05-15  CENTRO OESTE     GOIAS  ETANOL HIDRATADO
# 5    2004-05-09  2004-05-15      NORDESTE     BAHIA  ETANOL HIDRATADO
# 10   2004-05-09  2004-05-15      NORDESTE     PIAUI  ETANOL HIDRATADO
# 15   2004-05-09  2004-05-15         NORTE  AMAZONAS  ETANOL HIDRATADO
#
#     NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 1                            387              R$/l                1.162
# 5                            408              R$/l                1.383
# 10                            89              R$/l                1.573
# 15                            53              R$/l                1.578
#
#     DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 1                   0.114                 0.890  ...
# 5                   0.132                 0.999  ...
# 10                  0.134                 1.400  ...
# ...

# %%
# Selecionando as linhas de índices 5, 1, 15, 10
data.iloc[[5, 1, 15, 10]]
# Out:
#    DATA INICIAL  DATA FINAL        REGIÃO    ESTADO           PRODUTO  \
# 5    2004-05-09  2004-05-15      NORDESTE     BAHIA  ETANOL HIDRATADO
# 1    2004-05-09  2004-05-15  CENTRO OESTE     GOIAS  ETANOL HIDRATADO
# 15   2004-05-09  2004-05-15         NORTE  AMAZONAS  ETANOL HIDRATADO
# 10   2004-05-09  2004-05-15      NORDESTE     PIAUI  ETANOL HIDRATADO
#
#     NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  PREÇO MÉDIO REVENDA  \
# 5                            408              R$/l                1.383
# 1                            387              R$/l                1.162
# 15                            53              R$/l                1.578
# 10                            89              R$/l                1.573
#
#     DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 5                   0.132                 0.999  ...
# 1                   0.114                 0.890  ...
# 15                  0.123                 1.280  ...
# ...

# %%
# Retornar o valor da linha de índice 1, coluna 4 ('ESTADO')
data.iloc[1, 4]
# Out:
# 'ETANOL HIDRATADO'

# %% [markdown]
# ## SELEÇÃO BASEADAS EM RÓTULOS

# %%
# retorna a linha de índice 0 (implícito) ==> usando o iloc
pesquisa_de_satisfacao.iloc[0]
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
# retorna o valor da linha de índice (implicito) e coluna de índice 1 (implicito) ==> usando o iloc
pesquisa_de_satisfacao.iloc[0,1]
# Out:
# np.int64(131)

# %%
# retorna a linha cuja o rótulo do índice é 'XboxOne'
pesquisa_de_satisfacao.loc['XboxOne']
# Out:
# bom         50
# ruim       131
# pessimo     30
# Name: XboxOne, dtype: int64

# %%
pesquisa_de_satisfacao
# Out:
#               bom  ruim  pessimo
# XboxOne        50   131       30
# Playstation4   21     2       20
# Switch        100    30        1

# %%
# retorna o valor da linha 'Playstation4', coluna 'ruim'
pesquisa_de_satisfacao.loc['Playstation4', 'ruim']
# Out:
# np.int64(2)

# %%
# selecionando as linhas de indices rotulados 'XboxOne', 'Switch'
pesquisa_de_satisfacao.loc[['XboxOne', 'Switch']]
# Out:
#          bom  ruim  pessimo
# XboxOne   50   131       30
# Switch   100    30        1

# %%
pesquisa_de_satisfacao.loc[:, ['bom', 'pessimo']]
# Out:
#               bom  pessimo
# XboxOne        50       30
# Playstation4   21       20
# Switch        100        1

# %% [markdown]
# ### SELECIONANDO UMA OU MAIS COLUNAS

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  ...  \
# 0                1.288                  0.016                  1.19  ...
# ...

# %%
data['ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
data.loc[:, 'ESTADO']
# Out:
# 0            DISTRITO FEDERAL
# 1                       GOIAS
# 2                 MATO GROSSO
# 3          MATO GROSSO DO SUL
# 4                     ALAGOAS
#                  ...
# 106818    RIO GRANDE DO NORTE
# 106819      RIO GRANDE DO SUL
# 106820         SANTA CATARINA
# 106821              SAO PAULO
# 106822                SERGIPE
# Name: ESTADO, Length: 106823, dtype: object

# %%
# selecionando múltiplas colunas
data[['PRODUTO', 'ESTADO', 'REGIÃO']]
# Out:
#                  PRODUTO               ESTADO        REGIÃO
# 0       ETANOL HIDRATADO     DISTRITO FEDERAL  CENTRO OESTE
# 1       ETANOL HIDRATADO                GOIAS  CENTRO OESTE
# 2       ETANOL HIDRATADO          MATO GROSSO  CENTRO OESTE
# 3       ETANOL HIDRATADO   MATO GROSSO DO SUL  CENTRO OESTE
# 4       ETANOL HIDRATADO              ALAGOAS      NORDESTE
# ...                  ...                  ...           ...
# 106818               GNV  RIO GRANDE DO NORTE      NORDESTE
# 106819               GNV    RIO GRANDE DO SUL           SUL
# 106820               GNV       SANTA CATARINA           SUL
# 106821               GNV            SAO PAULO       SUDESTE
# 106822               GNV              SERGIPE      NORDESTE
#
# [106823 rows x 3 columns]

# %% [markdown]
# ### REMOVENDO UMA COLUNA

# %%
# deleta/remove in-place (no proprio dataframe) a coluna de rótulo 'Unnamed: 0'

# del data['Unnamed: 0']
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %% [markdown]
# Vamos remover agora as colunas fictícias que foram criadas durante as aulas

# %%
del data['coluna sem nocao']
del data['coluna a partir de lista']
del data['PREÇO MÉDIO REVENDA (dólares)']

# %%
data.head()
# Out:
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2   2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3   2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4   2004-05-09  2004-05-15      NORDESTE             ALAGOAS
#
#             PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0  ETANOL HIDRATADO                           127              R$/l
# 1  ETANOL HIDRATADO                           387              R$/l
# 2  ETANOL HIDRATADO                           192              R$/l
# 3  ETANOL HIDRATADO                           162              R$/l
# 4  ETANOL HIDRATADO                           103              R$/l
#
#    PREÇO MÉDIO REVENDA  DESVIO PADRÃO REVENDA  PREÇO MÍNIMO REVENDA  \
# 0                1.288                  0.016                  1.19
# ...

# %% [markdown]
# Salvando um Data frame para arquivo CSV

# %%
data.to_csv('./datasets/GasPricesinBrazil_2004-2019.csv', index=False)

# %%
# data = pd.read_csv('./datasets/GasPricesinBrazil_2004-2019.csv')

# %% [markdown]
# # A PARTIR DE AGORA USAREI UM OUTRO BANCO DE DADOS

# %%
carros = pd.read_csv('./datasets/venda-de-carros.csv')

# %% [markdown]
# FILTRAGEM

# %%
# unique() retorna os dados únicos de uma coluna:
carros['Fabricante'].unique()
# Out:
# array(['Toyota', 'Honda', 'BMW', 'Nissan'], dtype=object)

# %%
# Para filtrar por condições, utilizamos .query() e no final do filtro usamos .reset_index() para os dados filtrados voltarem o index começando do 0.
dados_filtrados = carros.query('Fabricante == "Honda"').reset_index()
dados_filtrados
# Out:
#    index Fabricante       Cor  Quilometragem  Portas         Preco
# 0      1      Honda  Vermelho          87899       4  R$ 25,000.00
# 1      6      Honda      Azul          45698       4  R$ 17,500.00
# 2      7      Honda      Azul          54738       4  R$ 27,000.00

# %%
dados_filtrados2 = carros.query('Fabricante == "Honda" and Cor == "Azul"').reset_index()
dados_filtrados2
# Out:
#    index Fabricante   Cor  Quilometragem  Portas         Preco
# 0      6      Honda  Azul          45698       4  R$ 17,500.00
# 1      7      Honda  Azul          54738       4  R$ 27,000.00

# %%
# Outra forma de filtrar
dados_filtrados3 = carros[carros['Fabricante'] == 'Honda']
dados_filtrados3
# Out:
#   Fabricante       Cor  Quilometragem  Portas         Preco
# 1      Honda  Vermelho          87899       4  R$ 25,000.00
# 6      Honda      Azul          45698       4  R$ 17,500.00
# 7      Honda      Azul          54738       4  R$ 27,000.00

# %%
dados_filtrados4 = carros[(carros['Fabricante'] == 'Honda') & (carros['Cor'] == 'Azul')]
dados_filtrados4
# Out:
#   Fabricante   Cor  Quilometragem  Portas         Preco
# 6      Honda  Azul          45698       4  R$ 17,500.00
# 7      Honda  Azul          54738       4  R$ 27,000.00

# %% [markdown]
# Filtragem a partir de lista

# %%
lista_cores = ['Azul', 'Vermelho']
dados_filtrados5 = carros.query('Cor in @lista_cores')
dados_filtrados5
# Out:
#   Fabricante       Cor  Quilometragem  Portas         Preco
# 1      Honda  Vermelho          87899       4  R$ 25,000.00
# 2     Toyota      Azul          32549       3  R$ 27,000.00
# 6      Honda      Azul          45698       4  R$ 17,500.00
# 7      Honda      Azul          54738       4  R$ 27,000.00

# %% [markdown]
# O .dropna() remove todas as linhas do DataFrame que são vazias.
#
# O .fillna() preenche todos valores vazios de um DataFrame com 0

# %%
# O describle() retorna estatísticas descritiva como contagem, média, etc.
carros['Quilometragem'].describe()
# Out:
# count        10.000000
# mean      78601.400000
# std       61983.471735
# min       11179.000000
# 25%       35836.250000
# 50%       57369.000000
# 75%       96384.500000
# max      213095.000000
# Name: Quilometragem, dtype: float64

# %% [markdown]
# Para calcular a média, soma, desvio padrão, min, max:

# %%
print(carros['Quilometragem'].mean())
print(carros['Quilometragem'].sum())
print(carros['Quilometragem'].std())
print(carros['Quilometragem'].min())
print(carros['Quilometragem'].max())
# Out:
# 78601.4
# 786014
# 61983.47173454119
# 11179
# 213095

# %% [markdown]
# Para contagem usamos o value_counts():

# %%
carros['Fabricante'].value_counts()
# Out:
# Fabricante
# Toyota    4
# Honda     3
# Nissan    2
# BMW       1
# Name: count, dtype: int64

# %% [markdown]
# Podemos criar um novo DataFrame usando o .to_frame():

# %%
dados_fabricante = carros['Fabricante'].value_counts().to_frame().reset_index()
dados_fabricante
# Out:
#   Fabricante  count
# 0     Toyota      4
# 1      Honda      3
# 2     Nissan      2
# 3        BMW      1

# %% [markdown]
# APPLY E MAP

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# apply(): usado para aplicar uma função ao longo de um eixo de um DataFrame ou em valores de uma Series.

# %%
def nossa_soma(series):
    return series.sum()

df['SOMA(A, B, C)'] = df.apply(nossa_soma, axis=1)
df
# Out:
#          A   B    C  SOMA(A, B, C)
# Linha 1  1  10  100            111
# Linha 2  2  20  200            222
# Linha 3  3  30  300            333
# Linha 4  4  40  400            444

# %%
# aplica a função soma para cada coluna do dataframe
df.loc['Linha 5'] = df.apply(nossa_soma, axis=0)
df
# Out:
#           A    B     C  SOMA(A, B, C)
# Linha 1   1   10   100            111
# Linha 2   2   20   200            222
# Linha 3   3   30   300            333
# Linha 4   4   40   400            444
# Linha 5  10  100  1000           1110

# %% [markdown]
# Usando lambda functions (*nao sei usar*)

# %%
df['MÉDIA(A, B , C)'] = df[['A', 'B', 'C']].apply(lambda series: series.mean(), axis=1)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MÉDIA(A, B , C)
# Linha 1   1   10   100            111             37.0
# Linha 2   2   20   200            222             74.0
# Linha 3   3   30   300            333            111.0
# Linha 4   4   40   400            444            148.0
# Linha 5  10  100  1000           1110            370.0

# %%
# aplica a lambda function abaixo para cada elemento da coluna
df['C * 2'] = df['C'].apply(lambda x: x * 2)
df
# Out:
#           A    B     C  SOMA(A, B, C)  MÉDIA(A, B , C)  C * 2
# Linha 1   1   10   100            111             37.0    200
# Linha 2   2   20   200            222             74.0    400
# Linha 3   3   30   300            333            111.0    600
# Linha 4   4   40   400            444            148.0    800
# Linha 5  10  100  1000           1110            370.0   2000

# %%
df['A * 2'] = df['A'] * 2
df
# Out:
#           A    B     C  SOMA(A, B, C)  MÉDIA(A, B , C)  C * 2  A * 2
# Linha 1   1   10   100            111             37.0    200      2
# Linha 2   2   20   200            222             74.0    400      4
# Linha 3   3   30   300            333            111.0    600      6
# Linha 4   4   40   400            444            148.0    800      8
# Linha 5  10  100  1000           1110            370.0   2000     20

# %%
df = pd.DataFrame({ 'A': [1, 2, 3, 4], 
                    'B': [10, 20, 30, 40],
                    'C': [100, 200, 300, 400]}, 
                     index=['Linha 1', 'Linha 2', 'Linha 3', 'Linha 4'])
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %%
# retorna um novo dataframe com todos os elementos ao quadrado.
# poderíamos usar uma função ao invés de uma lambda function
 
df.applymap(lambda x: x ** 2)
# Out:
# /tmp/ipykernel_32902/1799327147.py:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x: x ** 2)
#           A     B       C
# Linha 1   1   100   10000
# Linha 2   4   400   40000
# Linha 3   9   900   90000
# Linha 4  16  1600  160000

# %%
df
# Out:
#          A   B    C
# Linha 1  1  10  100
# Linha 2  2  20  200
# Linha 3  3  30  300
# Linha 4  4  40  400

# %% [markdown]
# map(): usado para aplicar uma função para cada elemento (element-wise) de uma Series.

# %%
nomes = pd.Series(['João', 'Maria', 'Alice', 'Pedro'])
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %%
# retorna uma nova Series com todos os nomes com letras maiuscúlas.
# poderíamos usar uma função ao invés de uma lambda function
nomes.map(lambda x: x.upper())
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object

# %%
nomes
# Out:
# 0     João
# 1    Maria
# 2    Alice
# 3    Pedro
# dtype: object

# %%
# O Pandas já fornece uma série de métodos para manipulação de strings.
# Assim, poderíamos usar o código abaixo para obter o mesmo resultado.
nomes.str.upper()
# Out:
# 0     JOÃO
# 1    MARIA
# 2    ALICE
# 3    PEDRO
# dtype: object

# %% [markdown]
# #### AGRUPAMENTO

# %%
carros.head()
# Out:
#   Fabricante       Cor  Quilometragem  Portas          Preco
# 0     Toyota    Branco         150043       4   R$ 24,000.00
# 1      Honda  Vermelho          87899       4   R$ 25,000.00
# 2     Toyota      Azul          32549       3   R$ 27,000.00
# 3        BMW     Preto          11179       5  R$ 122,000.00
# 4     Nissan    Branco         213095       4   R$ 13,500.00

# %% [markdown]
# groupby: Usado para criar grupos de elementos (e.x., baseado nos valores de um atributo (categórico)).
# Funções podem então ser aplicadas para os elementos de cada grupo, de modo que os resultados de cada grupo são combinados.

# %%
grupos = carros.groupby('Cor')
grupos

# %%
# retorna os grupos obtidos pelo groupby
grupos.groups
# Out:
# {'Azul': [2, 6, 7], 'Branco': [0, 4, 8, 9], 'Preto': [3], 'Verde': [5], 'Vermelho': [1]}

# %%
# retorna os índices das linhas/observações de cada grupo
grupos.indices
# Out:
# {'Azul': array([2, 6, 7]),
#  'Branco': array([0, 4, 8, 9]),
#  'Preto': array([3]),
#  'Verde': array([5]),
#  'Vermelho': array([1])}

# %%
# retorna um dataframe apenas com as observações do grupo 'Azul'
grupos.get_group('Azul')
# Out:
#   Fabricante   Cor  Quilometragem  Portas         Preco
# 2     Toyota  Azul          32549       3  R$ 27,000.00
# 6      Honda  Azul          45698       4  R$ 17,500.00
# 7      Honda  Azul          54738       4  R$ 27,000.00

# %%
# descreva para nós algumas estatística descritivas para as observações de cada grupo
grupos.describe()
# Out:
#          Quilometragem                                                 \
#                  count           mean           std      min      25%
# Cor
# Azul               3.0   44328.333333  11157.729175  32549.0  39123.5
# Branco             4.0  113684.500000  83315.222125  31600.0  52900.0
# Preto              1.0   11179.000000           NaN  11179.0  11179.0
# Verde              1.0   99213.000000           NaN  99213.0  99213.0
# Vermelho           1.0   87899.000000           NaN  87899.0  87899.0
#
#                                        Portas                               \
#                50%       75%       max  count      mean      std  min  25%
# Cor
# Azul       45698.0   50218.0   54738.0    3.0  3.666667  0.57735  3.0  3.5
# Branco    105021.5  165806.0  213095.0    4.0  4.000000  0.00000  4.0  4.0
# Preto      11179.0   11179.0   11179.0    1.0  5.000000      NaN  5.0  5.0
# Verde      99213.0   99213.0   99213.0    1.0  4.000000      NaN  4.0  4.0
# ...

# %%
# grupos.mean()
# media

# %%
grupos.min()  # com letras, vira ordem alfabética
# Out:
#          Fabricante  Quilometragem  Portas          Preco
# Cor
# Azul          Honda          32549       3   R$ 17,500.00
# Branco       Nissan          31600       4   R$ 13,500.00
# Preto           BMW          11179       5  R$ 122,000.00
# Verde        Toyota          99213       4   R$ 14,500.00
# Vermelho      Honda          87899       4   R$ 25,000.00

# %%
carros.groupby('Fabricante').min()
# Out:
#                Cor  Quilometragem  Portas          Preco
# Fabricante
# BMW          Preto          11179       5  R$ 122,000.00
# Honda         Azul          45698       4   R$ 17,500.00
# Nissan      Branco          31600       4   R$ 13,500.00
# Toyota        Azul          32549       3   R$ 14,500.00

# %%
carros.head()
# Out:
#   Fabricante       Cor  Quilometragem  Portas          Preco
# 0     Toyota    Branco         150043       4   R$ 24,000.00
# 1      Honda  Vermelho          87899       4   R$ 25,000.00
# 2     Toyota      Azul          32549       3   R$ 27,000.00
# 3        BMW     Preto          11179       5  R$ 122,000.00
# 4     Nissan    Branco         213095       4   R$ 13,500.00

# %%
grupos = carros.groupby(['Fabricante', 'Quilometragem'])
grupos

# %%
grupos.groups
# Out:
# {('BMW', 11179): [3], ('Honda', 45698): [6], ('Honda', 54738): [7], ('Honda', 87899): [1], ('Nissan', 31600): [9], ('Nissan', 213095): [4], ('Toyota', 32549): [2], ('Toyota', 60000): [8], ('Toyota', 99213): [5], ('Toyota', 150043): [0]}

# %%
grupos.mean(numeric_only=True).reset_index()
# Out:
#   Fabricante  Quilometragem  Portas
# 0        BMW          11179     5.0
# 1      Honda          45698     4.0
# 2      Honda          54738     4.0
# 3      Honda          87899     4.0
# 4     Nissan          31600     4.0
# 5     Nissan         213095     4.0
# 6     Toyota          32549     3.0
# 7     Toyota          60000     4.0
# 8     Toyota          99213     4.0
# 9     Toyota         150043     4.0

# %%
grupos['Quilometragem'].mean(numeric_only=True)
# Out:
# Fabricante  Quilometragem
# BMW         11179             11179.0
# Honda       45698             45698.0
#             54738             54738.0
#             87899             87899.0
# Nissan      31600             31600.0
#             213095           213095.0
# Toyota      32549             32549.0
#             60000             60000.0
#             99213             99213.0
#             150043           150043.0
# Name: Quilometragem, dtype: float64

# %%
grupos['Quilometragem'].describe()
# Out:
#                           count      mean  std       min       25%       50%  \
# Fabricante Quilometragem
# BMW        11179            1.0   11179.0  NaN   11179.0   11179.0   11179.0
# Honda      45698            1.0   45698.0  NaN   45698.0   45698.0   45698.0
#            54738            1.0   54738.0  NaN   54738.0   54738.0   54738.0
#            87899            1.0   87899.0  NaN   87899.0   87899.0   87899.0
# Nissan     31600            1.0   31600.0  NaN   31600.0   31600.0   31600.0
#            213095           1.0  213095.0  NaN  213095.0  213095.0  213095.0
# Toyota     32549            1.0   32549.0  NaN   32549.0   32549.0   32549.0
#            60000            1.0   60000.0  NaN   60000.0   60000.0   60000.0
#            99213            1.0   99213.0  NaN   99213.0   99213.0   99213.0
#            150043           1.0  150043.0  NaN  150043.0  150043.0  150043.0
#
#                                75%       max
# Fabricante Quilometragem
# ...

# %%
carros.head()
# Out:
#   Fabricante       Cor  Quilometragem  Portas          Preco
# 0     Toyota    Branco         150043       4   R$ 24,000.00
# 1      Honda  Vermelho          87899       4   R$ 25,000.00
# 2     Toyota      Azul          32549       3   R$ 27,000.00
# 3        BMW     Preto          11179       5  R$ 122,000.00
# 4     Nissan    Branco         213095       4   R$ 13,500.00

# %% [markdown]
# .agg: agrega (roda) uma série de funções para os elementos de um dataframe ou de grupos de um dataframe

# %%
df = pd.DataFrame([[1, 2, 3],
                   [4, 5, 6],
                   [7, 8, 9],
                   [None, None, None]],
                  columns=['A', 'B', 'C'])
df
# Out:
#      A    B    C
# 0  1.0  2.0  3.0
# 1  4.0  5.0  6.0
# 2  7.0  8.0  9.0
# 3  NaN  NaN  NaN

# %%
df.agg([sum,min])
# Out:
# /tmp/ipykernel_32902/1413054331.py:1: FutureWarning: The provided callable <built-in function sum> is currently using Series.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.agg([sum,min])
# /tmp/ipykernel_32902/1413054331.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.agg([sum,min])
#         A     B     C
# sum  12.0  15.0  18.0
# min   1.0   2.0   3.0

# %%
grupos = carros.groupby('Fabricante')
grupos

# %%
# Computa o menor e maior valor do 'Quilometragem' para cada Fabricante (grupo)
grupos['Quilometragem'].agg([min, max])
# Out:
# /tmp/ipykernel_32902/3748208663.py:2: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   grupos['Quilometragem'].agg([min, max])
# /tmp/ipykernel_32902/3748208663.py:2: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   grupos['Quilometragem'].agg([min, max])
#               min     max
# Fabricante
# BMW         11179   11179
# Honda       45698   87899
# Nissan      31600  213095
# Toyota      32549  150043

# %% [markdown]
# ### ORDENAÇÃO

# %%
notas = pd.DataFrame({
    'nome': ['João', 'Maria', 'José', 'Alice'],
    'idade': [20, 21, 19, 20],
    'nota_final': [5.0, 10.0, 6.0, 10.0]
})
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# .sort_values(): ordena valores ao longo de um eixo.

# %%
notas.sort_values(by='nota_final')
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 2   José     19         6.0
# 1  Maria     21        10.0
# 3  Alice     20        10.0

# %% [markdown]
# Por padrão, o método retorna uma cópia dos dados ordenados em ordem crescente (ascendente). Podemos alterar isso pelo argumento ascending.

# %%
notas.sort_values(by='nota_final', ascending=False)
# Out:
#     nome  idade  nota_final
# 1  Maria     21        10.0
# 3  Alice     20        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# Podemos ordenar a partir de mais de uma coluna:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True])
# Ordena os registros, primeiramente, pela coluna 'nota_final' em ordem descrente.
# Então, reordena os registros "empatados", ou seja, com a mesma nota final, em ordem alfabética (ordem crescente).
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %%
# Note que o dataframe original não foi alterado após a ordenação.
notas
# Out:
#     nome  idade  nota_final
# 0   João     20         5.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 3  Alice     20        10.0

# %% [markdown]
# Para alterá-lo, use o argumento inplace=True:

# %%
notas.sort_values(by=['nota_final', 'nome'], ascending=[False, True], inplace=True)
notas
# Out:
#     nome  idade  nota_final
# 3  Alice     20        10.0
# 1  Maria     21        10.0
# 2   José     19         6.0
# 0   João     20         5.0

# %% [markdown]
# # EXERCICIOS

# %%
data
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 106818   2019-06-23  2019-06-29      NORDESTE  RIO GRANDE DO NORTE
# 106819   2019-06-23  2019-06-29           SUL    RIO GRANDE DO SUL
# 106820   2019-06-23  2019-06-29           SUL       SANTA CATARINA
# 106821   2019-06-23  2019-06-29       SUDESTE            SAO PAULO
# 106822   2019-06-23  2019-06-29      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
# 1
df = data.query('ANO != 2019')
df
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO               ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE     DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE                GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE          MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE   MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE              ALAGOAS
# ...             ...         ...           ...                  ...
# 103064   2018-12-30  2019-01-05      NORDESTE  RIO GRANDE DO NORTE
# 103065   2018-12-30  2019-01-05           SUL    RIO GRANDE DO SUL
# 103066   2018-12-30  2019-01-05           SUL       SANTA CATARINA
# 103067   2018-12-30  2019-01-05       SUDESTE            SAO PAULO
# 103068   2018-12-30  2019-01-05      NORDESTE              SERGIPE
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
grupos = df.groupby('PRODUTO')
grupos['REGIÃO'].value_counts()
# Out:
# PRODUTO           REGIÃO
# ETANOL HIDRATADO  NORDESTE        6839
#                   NORTE           5244
#                   CENTRO OESTE    3040
#                   SUDESTE         3040
#                   SUL             2279
# GASOLINA COMUM    NORDESTE        6840
#                   NORTE           5319
#                   CENTRO OESTE    3040
#                   SUDESTE         3040
#                   SUL             2280
# GLP               NORDESTE        6836
#                   NORTE           5319
#                   SUDESTE         3039
#                   CENTRO OESTE    3037
#                   SUL             2280
# GNV               NORDESTE        5398
#                   SUDESTE         3036
#                   SUL             2269
#                   CENTRO OESTE    1493
#                   NORTE            444
# ÓLEO DIESEL       NORDESTE        6840
#                   NORTE           5319
#                   CENTRO OESTE    3040
# ...

# %%
dados_gasolina = df.query('PRODUTO == "GASOLINA COMUM" and ESTADO == "SAO PAULO" and ANO == 2018')
dados_gasolina['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count            52.000000
# mean              4.202769
# std               0.180672
# min               3.970000
# 25%               4.008000
# 50%               4.202000
# 75%               4.336250
# max               4.512000

# %%
dados_gasolina = df.query('PRODUTO in ["GASOLINA COMUM", "ETANOL HIDRATADO"] and ESTADO == "SAO PAULO" and ANO == 2018')
dados_gasolina['PREÇO MÉDIO REVENDA'].describe().to_frame()
# Out:
#        PREÇO MÉDIO REVENDA
# count           104.000000
# mean              3.457337
# std               0.766239
# min               2.393000
# 25%               2.726000
# 50%               3.431000
# 75%               4.199000
# max               4.512000

# %%
dados_gasolina.groupby('PRODUTO')['PREÇO MÉDIO REVENDA'].describe()
# Out:
#                   count      mean       std    min     25%    50%      75%  \
# PRODUTO
# ETANOL HIDRATADO   52.0  2.711904  0.141365  2.393  2.6315  2.720  2.83825
# GASOLINA COMUM     52.0  4.202769  0.180672  3.970  4.0080  4.202  4.33625
#
#                     max
# PRODUTO
# ETANOL HIDRATADO  2.892
# GASOLINA COMUM    4.512
